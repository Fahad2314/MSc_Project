# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
import csv
from pandas.tseries.offsets import MonthEnd
from datetime import datetime, timedelta, date
import requests
import json 
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
from sklearn.utils.multiclass import unique_labels

from scipy import stats
from IPython.display import display, HTML

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape
from keras.layers import Convolution1D, MaxPooling1D
from keras.utils import np_utils
import seaborn as sns

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
# Out:
# Using TensorFlow backend.

# %%
MSFT_98_train = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_98_train_flat_df.csv", index_col=0)
MSFT_98_train = MSFT_98_train.reset_index(drop=True)


MSFT_98_test = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_98_test_flat_df.csv", index_col=0)
MSFT_98_test = MSFT_98_test.reset_index(drop=True)


MSFT_02_train = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_02_train_flat_df.csv", index_col=0)
MSFT_02_train = MSFT_02_train.reset_index(drop=True)


MSFT_02_test = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_02_test_flat_df.csv", index_col=0)
MSFT_02_test = MSFT_02_test.reset_index(drop=True)


MSFT_06_train = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_06_train_flat_df.csv", index_col=0)
MSFT_06_train = MSFT_06_train.reset_index(drop=True)


MSFT_06_test = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_06_test_flat_df.csv", index_col=0)
MSFT_06_test = MSFT_06_test.reset_index(drop=True)

MSFT_10_train = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_10_train_flat_df.csv", index_col=0)
MSFT_10_train = MSFT_10_train.reset_index(drop=True)


MSFT_10_test = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_10_test_flat_df.csv", index_col=0)
MSFT_10_test = MSFT_10_test.reset_index(drop=True)


MSFT_14_train = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_14_train_flat_df.csv", index_col=0)
MSFT_14_train = MSFT_14_train.reset_index(drop=True)


MSFT_14_test = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_14_test_flat_df.csv", index_col=0)
MSFT_14_test = MSFT_14_test.reset_index(drop=True)

# %%
#get training and test labels for all the MSFT windows
y_train_98 = MSFT_98_train.Label
MSFT_98_train = MSFT_98_train.drop('Label', axis=1)


y_test_98 = MSFT_98_test.Label
MSFT_98_test = MSFT_98_test.drop('Label', axis=1)


y_train_02 = MSFT_02_train.Label
MSFT_02_train = MSFT_02_train.drop('Label', axis=1)


y_test_02 = MSFT_02_test.Label
MSFT_02_test = MSFT_02_test.drop('Label', axis=1)


y_train_06 = MSFT_06_train.Label
MSFT_06_train = MSFT_06_train.drop('Label', axis=1)


y_test_06 = MSFT_06_test.Label
MSFT_06_test = MSFT_06_test.drop('Label', axis=1)


y_train_10 = MSFT_10_train.Label
MSFT_10_train = MSFT_10_train.drop('Label', axis=1)



y_test_10 = MSFT_10_test.Label
MSFT_10_test = MSFT_10_test.drop('Label', axis=1)



y_train_14 = MSFT_14_train.Label
MSFT_14_train = MSFT_14_train.drop('Label', axis=1)


y_test_14 = MSFT_14_test.Label
MSFT_14_test = MSFT_14_test.drop('Label', axis=1)

# %% [markdown]
# # JOIN DATAFRAMES IN ORDER TO HAVE SUFFICIENT DATA TO TRAIN MODEL

# %%
MSFT_98_02_train = MSFT_98_train.append(MSFT_02_train, ignore_index=True)

y_train_98_02 = y_train_98.append(y_train_02, ignore_index=True)

MSFT_98_02_test = MSFT_98_test.append(MSFT_02_test, ignore_index=True)

y_test_98_02 = y_test_98.append(y_test_02, ignore_index=True)

# %%
def make_timeseries_classifier(sample_num,window_size, filter_length, nb_input_series=1, nb_outputs=1, nb_filter=16):
    """:Return: a Keras Model for predicting the next value in a timeseries given a fixed-size lookback window of previous values.
    The model can handle multiple input timeseries (`nb_input_series`) and multiple prediction targets (`nb_outputs`).
    :param int window_size: The number of previous timeseries values to use as input features.  Also called lag or lookback.
    :param int nb_input_series: The number of input timeseries; 1 for a single timeseries.
      The `X` input to ``fit()`` should be an array of shape ``(n_instances, window_size, nb_input_series)``; each instance is
      a 2D array of shape ``(window_size, nb_input_series)``.  For example, for `window_size` = 3 and `nb_input_series` = 1 (a
      single timeseries), one instance could be ``[[0], [1], [2]]``. See ``make_timeseries_instances()``.
    :param int nb_outputs: The output dimension, often equal to the number of inputs.
      For each input instance (array with shape ``(window_size, nb_input_series)``), the output is a vector of size `nb_outputs`,
      usually the value(s) predicted to come after the last value in that input instance, i.e., the next value
      in the sequence. The `y` input to ``fit()`` should be an array of shape ``(n_instances, nb_outputs)``.
    :param int filter_length: the size (along the `window_size` dimension) of the sliding window that gets convolved with
      each position along each instance. The difference between 1D and 2D convolution is that a 1D filter's "height" is fixed
      to the number of input timeseries (its "width" being `filter_length`), and it can only slide along the window
      dimension.  This is useful as generally the input timeseries have no spatial/ordinal relationship, so it's not
      meaningful to look for patterns that are invariant with respect to subsets of the timeseries.
    :param int nb_filter: The number of different filters to learn (roughly, input patterns to recognize).
    """
    model = Sequential((
        # The first conv layer learns `nb_filter` filters (aka kernels), each of size ``(filter_length, nb_input_series)``.
        # Its output will have shape (None, window_size - filter_length + 1, nb_filter), i.e., for each position in
        # the input timeseries, the activation of each filter at that position.
        Convolution1D(nb_filter=nb_filter, filter_length=filter_length, activation='relu', input_shape=(window_size,nb_input_series)),
        MaxPooling1D(),     # Downsample the output of convolution by 2X.
        Convolution1D(nb_filter=nb_filter, filter_length=filter_length, activation='relu'),
        MaxPooling1D(),
        Flatten(),
        Dense(nb_outputs, activation='sigmoid'),     # For binary classification, change the activation to 'sigmoid'
    ))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # To perform (binary) classification instead:
    # model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])
    
    return model

# %%
MSFT_98_train.shape
# Out:
# (51, 360)

# %%
model_1 = make_timeseries_classifier(MSFT_98_02_train.shape[0],MSFT_98_02_train.shape[1],3)
# Out:
# /Users/fahad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(activation="relu", input_shape=(360, 1), filters=16, kernel_size=3)`
# /Users/fahad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(activation="relu", filters=16, kernel_size=3)`

# %%
model_1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3 (Conv1D)            (None, 358, 16)           64
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 179, 16)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 177, 16)           784
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 88, 16)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1408)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1409
# =================================================================
# Total params: 2,257
# Trainable params: 2,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_acc', mode='max', verbose=0, patience=100)
mc = ModelCheckpoint('MSFT_98_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
cb_list = [es,mc]

# %%
X_train = np.array(MSFT_98_02_train).reshape((*MSFT_98_02_train.shape,1))
y_train = np.array(y_train_98_02).reshape((*y_train_98_02.shape,1))

# %%
history=model_1.fit(X_train, y_train,validation_split=0.10, epochs=1000,batch_size=1, verbose=1,
                    callbacks = cb_list)
# Out:
# Train on 81 samples, validate on 21 samples
# Epoch 1/100
# 81/81 [==============================] - 1s 6ms/step - loss: 0.6980 - acc: 0.5185 - val_loss: 0.6754 - val_acc: 0.5714
#
# Epoch 00001: val_acc improved from -inf to 0.57143, saving model to MSFT_98_model.h5
# Epoch 2/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.6843 - acc: 0.6049 - val_loss: 0.6733 - val_acc: 0.6667
#
# Epoch 00002: val_acc improved from 0.57143 to 0.66667, saving model to MSFT_98_model.h5
# Epoch 3/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.6573 - acc: 0.7407 - val_loss: 0.6400 - val_acc: 0.7143
#
# Epoch 00003: val_acc improved from 0.66667 to 0.71429, saving model to MSFT_98_model.h5
# Epoch 4/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.6370 - acc: 0.6420 - val_loss: 0.6234 - val_acc: 0.6667
#
# Epoch 00004: val_acc did not improve from 0.71429
# Epoch 5/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5731 - acc: 0.7160 - val_loss: 0.5852 - val_acc: 0.7143
#
# Epoch 00005: val_acc did not improve from 0.71429
# Epoch 6/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5154 - acc: 0.7654 - val_loss: 0.5461 - val_acc: 0.6667
#
# Epoch 00006: val_acc did not improve from 0.71429
# Epoch 7/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4850 - acc: 0.7407 - val_loss: 0.5494 - val_acc: 0.7619
#
# Epoch 00007: val_acc improved from 0.71429 to 0.76190, saving model to MSFT_98_model.h5
# Epoch 8/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4682 - acc: 0.7531 - val_loss: 0.5727 - val_acc: 0.7143
#
# Epoch 00008: val_acc did not improve from 0.76190
# Epoch 9/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4340 - acc: 0.8025 - val_loss: 0.6256 - val_acc: 0.6667
#
# Epoch 00009: val_acc did not improve from 0.76190
# Epoch 10/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3921 - acc: 0.8519 - val_loss: 0.7562 - val_acc: 0.6190
#
# Epoch 00010: val_acc did not improve from 0.76190
# Epoch 11/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3676 - acc: 0.7901 - val_loss: 0.8485 - val_acc: 0.5714
#
# Epoch 00011: val_acc did not improve from 0.76190
# Epoch 12/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3609 - acc: 0.7654 - val_loss: 0.8904 - val_acc: 0.5714
#
# Epoch 00012: val_acc did not improve from 0.76190
# Epoch 13/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3128 - acc: 0.8642 - val_loss: 0.7351 - val_acc: 0.6667
#
# Epoch 00013: val_acc did not improve from 0.76190
# Epoch 14/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3195 - acc: 0.8272 - val_loss: 0.9126 - val_acc: 0.6190
#
# Epoch 00014: val_acc did not improve from 0.76190
# Epoch 15/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3004 - acc: 0.8272 - val_loss: 1.2866 - val_acc: 0.4762
#
# Epoch 00015: val_acc did not improve from 0.76190
# Epoch 16/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2853 - acc: 0.9012 - val_loss: 1.0686 - val_acc: 0.6190
#
# Epoch 00016: val_acc did not improve from 0.76190
# Epoch 17/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2771 - acc: 0.8519 - val_loss: 0.8511 - val_acc: 0.6190
#
# Epoch 00017: val_acc did not improve from 0.76190
# Epoch 18/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2731 - acc: 0.8395 - val_loss: 1.2318 - val_acc: 0.6190
#
# Epoch 00018: val_acc did not improve from 0.76190
# Epoch 19/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2546 - acc: 0.8889 - val_loss: 1.2869 - val_acc: 0.6190
#
# Epoch 00019: val_acc did not improve from 0.76190
# Epoch 20/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2360 - acc: 0.8889 - val_loss: 1.3905 - val_acc: 0.6190
#
# Epoch 00020: val_acc did not improve from 0.76190
# Epoch 21/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2305 - acc: 0.9136 - val_loss: 1.2156 - val_acc: 0.6190
#
# Epoch 00021: val_acc did not improve from 0.76190
# Epoch 22/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2189 - acc: 0.8889 - val_loss: 1.2213 - val_acc: 0.6190
#
# Epoch 00022: val_acc did not improve from 0.76190
# Epoch 23/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1968 - acc: 0.9383 - val_loss: 1.3415 - val_acc: 0.6190
#
# Epoch 00023: val_acc did not improve from 0.76190
# Epoch 24/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.2050 - acc: 0.9383 - val_loss: 1.6851 - val_acc: 0.5714
#
# Epoch 00024: val_acc did not improve from 0.76190
# Epoch 25/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.1889 - acc: 0.9259 - val_loss: 1.6394 - val_acc: 0.6190
#
# Epoch 00025: val_acc did not improve from 0.76190
# Epoch 26/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.1775 - acc: 0.9383 - val_loss: 1.6435 - val_acc: 0.6190
#
# Epoch 00026: val_acc did not improve from 0.76190
# Epoch 27/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.1723 - acc: 0.9136 - val_loss: 1.7041 - val_acc: 0.6190
#
# Epoch 00027: val_acc did not improve from 0.76190
# Epoch 28/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1619 - acc: 0.9383 - val_loss: 2.0343 - val_acc: 0.4762
#
# Epoch 00028: val_acc did not improve from 0.76190
# Epoch 29/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1731 - acc: 0.9136 - val_loss: 2.2945 - val_acc: 0.4762
#
# Epoch 00029: val_acc did not improve from 0.76190
# Epoch 30/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1613 - acc: 0.9383 - val_loss: 1.9321 - val_acc: 0.5714
#
# Epoch 00030: val_acc did not improve from 0.76190
# Epoch 31/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1425 - acc: 0.9753 - val_loss: 1.6566 - val_acc: 0.6190
#
# Epoch 00031: val_acc did not improve from 0.76190
# Epoch 32/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1696 - acc: 0.9259 - val_loss: 1.7668 - val_acc: 0.6190
#
# Epoch 00032: val_acc did not improve from 0.76190
# Epoch 33/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1306 - acc: 0.9506 - val_loss: 1.9550 - val_acc: 0.6190
#
# Epoch 00033: val_acc did not improve from 0.76190
# Epoch 34/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1344 - acc: 0.9753 - val_loss: 2.1815 - val_acc: 0.5714
#
# Epoch 00034: val_acc did not improve from 0.76190
# Epoch 35/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1145 - acc: 0.9630 - val_loss: 2.4268 - val_acc: 0.5714
#
# Epoch 00035: val_acc did not improve from 0.76190
# Epoch 36/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1062 - acc: 0.9753 - val_loss: 2.4616 - val_acc: 0.5714
#
# Epoch 00036: val_acc did not improve from 0.76190
# Epoch 37/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1184 - acc: 0.9753 - val_loss: 2.5006 - val_acc: 0.5714
#
# Epoch 00037: val_acc did not improve from 0.76190
# Epoch 38/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1048 - acc: 0.9630 - val_loss: 2.5507 - val_acc: 0.5714
#
# Epoch 00038: val_acc did not improve from 0.76190
# Epoch 39/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0977 - acc: 0.9753 - val_loss: 2.5564 - val_acc: 0.5714
#
# Epoch 00039: val_acc did not improve from 0.76190
# Epoch 40/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1027 - acc: 0.9630 - val_loss: 2.6022 - val_acc: 0.5714
#
# Epoch 00040: val_acc did not improve from 0.76190
# Epoch 41/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0763 - acc: 0.9877 - val_loss: 3.0520 - val_acc: 0.4762
#
# Epoch 00041: val_acc did not improve from 0.76190
# Epoch 42/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0758 - acc: 0.9877 - val_loss: 2.7348 - val_acc: 0.5714
#
# Epoch 00042: val_acc did not improve from 0.76190
# Epoch 43/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0860 - acc: 0.9753 - val_loss: 2.8035 - val_acc: 0.5714
#
# Epoch 00043: val_acc did not improve from 0.76190
# Epoch 44/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0680 - acc: 1.0000 - val_loss: 2.9997 - val_acc: 0.5714
#
# Epoch 00044: val_acc did not improve from 0.76190
# Epoch 45/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0654 - acc: 1.0000 - val_loss: 3.0155 - val_acc: 0.5714
#
# Epoch 00045: val_acc did not improve from 0.76190
# Epoch 46/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0710 - acc: 0.9877 - val_loss: 2.7327 - val_acc: 0.5714
#
# Epoch 00046: val_acc did not improve from 0.76190
# Epoch 47/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0587 - acc: 1.0000 - val_loss: 2.8258 - val_acc: 0.5714
#
# Epoch 00047: val_acc did not improve from 0.76190
# Epoch 48/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0416 - acc: 1.0000 - val_loss: 3.5338 - val_acc: 0.5714
#
# Epoch 00048: val_acc did not improve from 0.76190
# Epoch 49/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0479 - acc: 1.0000 - val_loss: 2.9025 - val_acc: 0.5714
#
# Epoch 00049: val_acc did not improve from 0.76190
# Epoch 50/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0532 - acc: 1.0000 - val_loss: 3.2848 - val_acc: 0.5714
#
# Epoch 00050: val_acc did not improve from 0.76190
# Epoch 51/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0478 - acc: 1.0000 - val_loss: 3.2377 - val_acc: 0.5714
#
# Epoch 00051: val_acc did not improve from 0.76190
# Epoch 52/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0517 - acc: 1.0000 - val_loss: 3.5346 - val_acc: 0.5714
#
# Epoch 00052: val_acc did not improve from 0.76190
# Epoch 53/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0326 - acc: 1.0000 - val_loss: 3.8892 - val_acc: 0.5714
#
# Epoch 00053: val_acc did not improve from 0.76190
# Epoch 54/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0432 - acc: 0.9877 - val_loss: 3.5384 - val_acc: 0.5714
#
# Epoch 00054: val_acc did not improve from 0.76190
# Epoch 55/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0366 - acc: 1.0000 - val_loss: 3.4755 - val_acc: 0.5714
#
# Epoch 00055: val_acc did not improve from 0.76190
# Epoch 56/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0346 - acc: 1.0000 - val_loss: 4.0836 - val_acc: 0.5714
#
# Epoch 00056: val_acc did not improve from 0.76190
# Epoch 57/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0338 - acc: 1.0000 - val_loss: 3.7605 - val_acc: 0.5714
#
# Epoch 00057: val_acc did not improve from 0.76190
# Epoch 58/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0294 - acc: 1.0000 - val_loss: 3.8636 - val_acc: 0.5714
#
# Epoch 00058: val_acc did not improve from 0.76190
# Epoch 59/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0260 - acc: 1.0000 - val_loss: 4.3504 - val_acc: 0.5714
#
# Epoch 00059: val_acc did not improve from 0.76190
# Epoch 60/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0283 - acc: 1.0000 - val_loss: 3.9757 - val_acc: 0.5714
#
# Epoch 00060: val_acc did not improve from 0.76190
# Epoch 61/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0278 - acc: 1.0000 - val_loss: 4.1035 - val_acc: 0.5714
#
# Epoch 00061: val_acc did not improve from 0.76190
# Epoch 62/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0391 - acc: 1.0000 - val_loss: 4.2056 - val_acc: 0.5714
#
# Epoch 00062: val_acc did not improve from 0.76190
# Epoch 63/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0374 - acc: 0.9877 - val_loss: 4.7719 - val_acc: 0.4762
#
# Epoch 00063: val_acc did not improve from 0.76190
# Epoch 64/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0187 - acc: 1.0000 - val_loss: 4.5103 - val_acc: 0.5714
#
# Epoch 00064: val_acc did not improve from 0.76190
# Epoch 65/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0169 - acc: 1.0000 - val_loss: 4.5874 - val_acc: 0.5714
#
# Epoch 00065: val_acc did not improve from 0.76190
# Epoch 66/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0153 - acc: 1.0000 - val_loss: 4.5649 - val_acc: 0.5714
#
# Epoch 00066: val_acc did not improve from 0.76190
# Epoch 67/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0126 - acc: 1.0000 - val_loss: 4.3154 - val_acc: 0.5714
#
# Epoch 00067: val_acc did not improve from 0.76190
# Epoch 68/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0133 - acc: 1.0000 - val_loss: 5.1051 - val_acc: 0.4762
#
# Epoch 00068: val_acc did not improve from 0.76190
# Epoch 69/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0166 - acc: 1.0000 - val_loss: 4.3546 - val_acc: 0.5714
#
# Epoch 00069: val_acc did not improve from 0.76190
# Epoch 70/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0127 - acc: 1.0000 - val_loss: 5.0436 - val_acc: 0.5238
#
# Epoch 00070: val_acc did not improve from 0.76190
# Epoch 71/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0128 - acc: 1.0000 - val_loss: 4.8632 - val_acc: 0.5714
#
# Epoch 00071: val_acc did not improve from 0.76190
# Epoch 72/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0120 - acc: 1.0000 - val_loss: 4.4560 - val_acc: 0.5714
#
# Epoch 00072: val_acc did not improve from 0.76190
# Epoch 73/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0103 - acc: 1.0000 - val_loss: 4.9528 - val_acc: 0.5714
#
# Epoch 00073: val_acc did not improve from 0.76190
# Epoch 74/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0113 - acc: 1.0000 - val_loss: 4.6101 - val_acc: 0.5714
#
# Epoch 00074: val_acc did not improve from 0.76190
# Epoch 75/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0083 - acc: 1.0000 - val_loss: 4.8300 - val_acc: 0.5714
#
# Epoch 00075: val_acc did not improve from 0.76190
# Epoch 76/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0088 - acc: 1.0000 - val_loss: 4.5426 - val_acc: 0.5714
#
# Epoch 00076: val_acc did not improve from 0.76190
# Epoch 77/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0077 - acc: 1.0000 - val_loss: 4.8482 - val_acc: 0.5714
#
# Epoch 00077: val_acc did not improve from 0.76190
# Epoch 78/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0080 - acc: 1.0000 - val_loss: 5.0404 - val_acc: 0.5714
#
# Epoch 00078: val_acc did not improve from 0.76190
# Epoch 79/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0063 - acc: 1.0000 - val_loss: 4.7309 - val_acc: 0.5714
#
# Epoch 00079: val_acc did not improve from 0.76190
# Epoch 80/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0071 - acc: 1.0000 - val_loss: 4.7610 - val_acc: 0.5714
#
# Epoch 00080: val_acc did not improve from 0.76190
# Epoch 81/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0067 - acc: 1.0000 - val_loss: 5.2913 - val_acc: 0.5714
#
# Epoch 00081: val_acc did not improve from 0.76190
# Epoch 82/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0065 - acc: 1.0000 - val_loss: 5.1934 - val_acc: 0.5714
#
# Epoch 00082: val_acc did not improve from 0.76190
# Epoch 83/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0062 - acc: 1.0000 - val_loss: 5.1415 - val_acc: 0.5714
#
# Epoch 00083: val_acc did not improve from 0.76190
# Epoch 84/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0063 - acc: 1.0000 - val_loss: 5.2462 - val_acc: 0.5714
#
# Epoch 00084: val_acc did not improve from 0.76190
# Epoch 85/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0137 - acc: 1.0000 - val_loss: 4.8860 - val_acc: 0.5714
#
# Epoch 00085: val_acc did not improve from 0.76190
# Epoch 86/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0047 - acc: 1.0000 - val_loss: 4.6779 - val_acc: 0.5714
#
# Epoch 00086: val_acc did not improve from 0.76190
# Epoch 87/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0055 - acc: 1.0000 - val_loss: 5.2296 - val_acc: 0.5714
#
# Epoch 00087: val_acc did not improve from 0.76190
# Epoch 88/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0045 - acc: 1.0000 - val_loss: 5.1105 - val_acc: 0.5714
#
# Epoch 00088: val_acc did not improve from 0.76190
# Epoch 89/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0058 - acc: 1.0000 - val_loss: 5.1657 - val_acc: 0.5714
#
# Epoch 00089: val_acc did not improve from 0.76190
# Epoch 90/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0038 - acc: 1.0000 - val_loss: 5.0555 - val_acc: 0.5714
#
# Epoch 00090: val_acc did not improve from 0.76190
# Epoch 91/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0033 - acc: 1.0000 - val_loss: 4.8519 - val_acc: 0.5714
#
# Epoch 00091: val_acc did not improve from 0.76190
# Epoch 92/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0052 - acc: 1.0000 - val_loss: 5.2676 - val_acc: 0.5714
#
# Epoch 00092: val_acc did not improve from 0.76190
# Epoch 93/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0031 - acc: 1.0000 - val_loss: 5.0533 - val_acc: 0.5714
#
# Epoch 00093: val_acc did not improve from 0.76190
# Epoch 94/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0029 - acc: 1.0000 - val_loss: 5.1576 - val_acc: 0.5714
#
# Epoch 00094: val_acc did not improve from 0.76190
# Epoch 95/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0029 - acc: 1.0000 - val_loss: 5.1848 - val_acc: 0.5714
#
# Epoch 00095: val_acc did not improve from 0.76190
# Epoch 96/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0029 - acc: 1.0000 - val_loss: 5.6717 - val_acc: 0.5714
#
# Epoch 00096: val_acc did not improve from 0.76190
# Epoch 97/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0030 - acc: 1.0000 - val_loss: 5.5390 - val_acc: 0.5714
#
# Epoch 00097: val_acc did not improve from 0.76190
# Epoch 98/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0023 - acc: 1.0000 - val_loss: 5.4030 - val_acc: 0.5714
#
# Epoch 00098: val_acc did not improve from 0.76190
# Epoch 99/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0026 - acc: 1.0000 - val_loss: 5.5466 - val_acc: 0.5714
#
# Epoch 00099: val_acc did not improve from 0.76190
# Epoch 100/100
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0023 - acc: 1.0000 - val_loss: 5.5529 - val_acc: 0.5714
#
# Epoch 00100: val_acc did not improve from 0.76190

# %%
saved_model = load_model('MSFT_98_model.h5')

# %%
predictions = saved_model.predict_classes(np.array(MSFT_98_02_test).reshape((*MSFT_98_02_test.shape,1)),batch_size = MSFT_98_02_test.shape[0], verbose=1)
# Out:
# 33/33 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import accuracy_score
print ("saved model acc: %s" % accuracy_score(y_test_98_02, predictions))
# accuracy: (tp + tn) / (p + n)

# precision tp / (tp + fp)
precision = precision_score(y_test_98_02, predictions)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test_98_02, predictions)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test_98_02, predictions)
print('F1 score: %f' % f1)
 
# kappa
kappa = cohen_kappa_score(y_test_98_02, predictions)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(y_test_98_02, predictions)
print('ROC AUC: %f' % auc)
# Out:
# saved model acc: 0.7878787878787878
# Precision: 0.882353
# Recall: 0.750000
# F1 score: 0.810811
# Cohens kappa: 0.573013
# ROC AUC: 0.798077

# %%
#plot the accuracy of the training set  and the validation set of the model
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

plt.rc('font', **font)
axis_font = {'fontname':'Arial', 'size':'25'}

plt.figure(figsize=[20,20])
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.ylabel('Accuracy', **axis_font)
plt.xlabel('Epochs', **axis_font)

plt.show()
# Out:
# W0815 10:50:52.067407 4549211584 font_manager.py:1282] findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
# %matplotlib inline

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title="Confusion Matrix",
                          cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation="nearest", cmap=cmap)
    plt.title(title)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    if normalize:
        cm = cm.astype("float")/ cm.sum(axis=1)[:,np.newaxis]
        print ("Normalised confusion matrix")
    else:
        print ("Confusion matrix, without normalisation")
        
    print (cm)
    
    thresh = cm.max()/2
    for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
        plt.text(j, i, cm[i,j],
        horizontalalignment = "center",
        color="white" if cm[i,j] > thresh else "black" )
        
    plt.tight_layout()
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")

# %%
cm = confusion_matrix(y_test_98_02, predictions)
cm_labels = ['Sell', 'Buy']
plot_confusion_matrix(cm, cm_labels, title="Confusion Matrix")
# Out:
# W0815 10:51:58.856551 4549211584 font_manager.py:1282] findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# W0815 10:51:58.865958 4549211584 font_manager.py:1282] findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# W0815 10:51:58.969830 4549211584 font_manager.py:1282] findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Confusion matrix, without normalisation
# [[11  2]
#  [ 5 15]]

# %%
def make_timeseries_classifier(sample_num,window_size, filter_length, nb_input_series=1, nb_outputs=1, nb_filter=16):
    """:Return: a Keras Model for predicting the next value in a timeseries given a fixed-size lookback window of previous values.
    The model can handle multiple input timeseries (`nb_input_series`) and multiple prediction targets (`nb_outputs`).
    :param int window_size: The number of previous timeseries values to use as input features.  Also called lag or lookback.
    :param int nb_input_series: The number of input timeseries; 1 for a single timeseries.
      The `X` input to ``fit()`` should be an array of shape ``(n_instances, window_size, nb_input_series)``; each instance is
      a 2D array of shape ``(window_size, nb_input_series)``.  For example, for `window_size` = 3 and `nb_input_series` = 1 (a
      single timeseries), one instance could be ``[[0], [1], [2]]``. See ``make_timeseries_instances()``.
    :param int nb_outputs: The output dimension, often equal to the number of inputs.
      For each input instance (array with shape ``(window_size, nb_input_series)``), the output is a vector of size `nb_outputs`,
      usually the value(s) predicted to come after the last value in that input instance, i.e., the next value
      in the sequence. The `y` input to ``fit()`` should be an array of shape ``(n_instances, nb_outputs)``.
    :param int filter_length: the size (along the `window_size` dimension) of the sliding window that gets convolved with
      each position along each instance. The difference between 1D and 2D convolution is that a 1D filter's "height" is fixed
      to the number of input timeseries (its "width" being `filter_length`), and it can only slide along the window
      dimension.  This is useful as generally the input timeseries have no spatial/ordinal relationship, so it's not
      meaningful to look for patterns that are invariant with respect to subsets of the timeseries.
    :param int nb_filter: The number of different filters to learn (roughly, input patterns to recognize).
    """
    model = Sequential((
        # The first conv layer learns `nb_filter` filters (aka kernels), each of size ``(filter_length, nb_input_series)``.
        # Its output will have shape (None, window_size - filter_length + 1, nb_filter), i.e., for each position in
        # the input timeseries, the activation of each filter at that position.
        Convolution1D(nb_filter=nb_filter, filter_length=filter_length, activation='relu', input_shape=(window_size,nb_input_series)),
        MaxPooling1D(),     # Downsample the output of convolution by 2X.
        Convolution1D(nb_filter=nb_filter, filter_length=filter_length, activation='relu'),
        MaxPooling1D(),
        Flatten(),
        Dense(nb_outputs, activation='sigmoid'),     # For binary classification, change the activation to 'sigmoid'
    ))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # To perform (binary) classification instead:
    # model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])
    
    return model
