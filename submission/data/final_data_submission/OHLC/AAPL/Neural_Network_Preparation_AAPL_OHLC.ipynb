# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import csv
from pandas.tseries.offsets import MonthEnd
from datetime import datetime, timedelta, date
import requests
import json 
import ta

# %%
#data with feature engineering
fields = ['Date', 'Open','High','Low','Close','Volume','RSI','MACD','Ichimoku_Span_A','Ichimoku_Span_B','ATR',
         'BB_High_Indicator','BB_Low_Indicator']
AAPL_df = pd.read_csv(r"/Users/fahad/project_repo/data/interim/AAPL.csv", usecols=fields)

# %%
AAPL_df.head()
AAPL_df = AAPL_df.drop(['RSI','MACD','Ichimoku_Span_A','Ichimoku_Span_B','ATR',
                        'BB_High_Indicator','BB_Low_Indicator'], axis=1)

# %%
# /Users/fahad/project_repo/data/final/OHLC/AAPL

# %%
AAPL_df.head()
# Out:
#          Date      Open      High       Low     Close    Volume
# 0  2019-07-10  0.273940  0.275380  0.274980  0.275847  0.059225
# 1  2019-07-09  0.270097  0.272186  0.270933  0.273041  0.104122
# 2  2019-07-08  0.272432  0.272027  0.270350  0.271271  0.130448
# 3  2019-07-05  0.276116  0.277346  0.276887  0.277381  0.087701
# 4  2019-07-03  0.276015  0.276421  0.276582  0.277642  0.056442

# %%
AAPL_98_train = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/1998_AAPL_train.csv", index_col=1)

AAPL_98_test = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/1998_AAPL_test.csv", index_col=1)

AAPL_02_train = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/2002_AAPL_train.csv", index_col=1)

AAPL_02_test = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/2002_AAPL_test.csv", index_col=1)

AAPL_06_train = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/2006_AAPL_train.csv", index_col=1)

AAPL_06_test = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/2006_AAPL_test.csv", index_col=1)

AAPL_10_train = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/2010_AAPL_train.csv", index_col=1)

AAPL_10_test = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/2010_AAPL_test.csv", index_col=1)

AAPL_14_train = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/2014_AAPL_train.csv", index_col=1)

AAPL_14_test = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/2014_AAPL_test.csv", index_col=1)

# %%
#ADD LABELS TO THE TRAINING AND TEST DATAFRAMES AND RETURN DICTIONARIES WITH DATE:LABEL FORMAT
AAPL_98_train_labels = labelling(AAPL_98_train)

AAPL_98_test_labels  = labelling(AAPL_98_test)

AAPL_02_train_labels = labelling(AAPL_02_train)

AAPL_02_test_labels  = labelling(AAPL_02_test)

AAPL_06_train_labels = labelling(AAPL_06_train)

AAPL_06_test_labels  = labelling(AAPL_06_test)

AAPL_10_train_labels = labelling(AAPL_10_train)

AAPL_10_test_labels  = labelling(AAPL_10_test)

AAPL_14_train_labels = labelling(AAPL_14_train)

AAPL_14_test_labels  = labelling(AAPL_14_test)

# %%
#GET 30 DAY PERIODS FOR EACH MONTH AND CREATE DICTIONARY FOR 30DAYS PRIOR TO EACH DATE 
AAPL_98_train_flattened= get_ndays_monthly_flattened(AAPL_98_train,AAPL_df,30)

AAPL_98_test_flattened= get_ndays_monthly_flattened(AAPL_98_test,AAPL_df,30)

AAPL_02_train_flattened = get_ndays_monthly_flattened(AAPL_02_train,AAPL_df,30)

AAPL_02_test_flattened = get_ndays_monthly_flattened(AAPL_02_test,AAPL_df,30)

AAPL_06_train_flattened = get_ndays_monthly_flattened(AAPL_06_train,AAPL_df,30)

AAPL_06_test_flattened = get_ndays_monthly_flattened(AAPL_06_test,AAPL_df,30)

AAPL_10_train_flattened = get_ndays_monthly_flattened(AAPL_10_train,AAPL_df,30)

AAPL_10_test_flattened = get_ndays_monthly_flattened(AAPL_10_test,AAPL_df,30)

AAPL_14_train_flattened = get_ndays_monthly_flattened(AAPL_14_train,AAPL_df,30)

AAPL_14_test_flattened = get_ndays_monthly_flattened(AAPL_14_test,AAPL_df,30)

# %%
#assign labels to a dataframe object
AAPL_98_train_labels_df = pd.Series(AAPL_98_train_labels).to_frame("Label")

AAPL_98_test_labels_df  =  pd.Series(AAPL_98_test_labels).to_frame("Label")

AAPL_02_train_labels_df =  pd.Series(AAPL_02_train_labels).to_frame("Label")

AAPL_02_test_labels_df =  pd.Series(AAPL_02_test_labels).to_frame("Label")

AAPL_06_train_labels_df =  pd.Series(AAPL_06_train_labels).to_frame("Label")

AAPL_06_test_labels_df =  pd.Series(AAPL_06_test_labels).to_frame("Label")

AAPL_10_train_labels_df =  pd.Series(AAPL_10_train_labels).to_frame("Label")

AAPL_10_test_labels_df =  pd.Series(AAPL_10_test_labels).to_frame("Label")

AAPL_14_train_labels_df =  pd.Series(AAPL_14_train_labels).to_frame("Label")

AAPL_14_test_labels_df =  pd.Series(AAPL_14_test_labels).to_frame("Label")

# %%
#CREATE DATAFRAME FROM FLATTENED DICTIONARY OF ARRAYS FOR TRAINING AND TEST DATA
AAPL_98_train_flat_df = pd.DataFrame.from_dict(AAPL_98_train_flattened).T

AAPL_98_test_flat_df = pd.DataFrame.from_dict(AAPL_98_test_flattened).T

AAPL_02_train_flat_df = pd.DataFrame.from_dict(AAPL_02_train_flattened).T

AAPL_02_test_flat_df = pd.DataFrame.from_dict(AAPL_02_test_flattened).T

AAPL_06_train_flat_df = pd.DataFrame.from_dict(AAPL_06_train_flattened).T

AAPL_06_test_flat_df = pd.DataFrame.from_dict(AAPL_06_test_flattened).T

AAPL_10_train_flat_df = pd.DataFrame.from_dict(AAPL_10_train_flattened).T

AAPL_10_test_flat_df = pd.DataFrame.from_dict(AAPL_10_test_flattened).T

AAPL_14_train_flat_df = pd.DataFrame.from_dict(AAPL_14_train_flattened).T

AAPL_14_test_flat_df = pd.DataFrame.from_dict(AAPL_14_test_flattened).T

# %%
# Out:
#                    0         1         2         3         4         5  \
# 1998-03-31  0.013519  0.014988  0.013322  0.015066  0.024416  0.012068
# 1998-04-30  0.019959  0.020683  0.020427  0.020784  0.008133  0.019770
# 1998-05-29  0.020234  0.020596  0.020427  0.020146  0.005241  0.021583
# 1998-06-30  0.019959  0.021218  0.020427  0.020784  0.010392  0.018421
# 1998-07-31  0.022135  0.022576  0.022334  0.022599  0.004137  0.022497
# 1998-08-31  0.033100  0.034052  0.033166  0.033934  0.013408  0.030112
# 1998-09-30  0.035015  0.036581  0.031171  0.030581  0.040354  0.038090
# 1998-10-30  0.037814  0.038749  0.036995  0.038288  0.010706  0.038815
# 1998-11-30  0.034014  0.035049  0.033617  0.033847  0.012571  0.032288
# 1998-12-31  0.032012  0.031711  0.032074  0.031844  0.003519  0.033202
# 1999-01-29  0.039366  0.040383  0.039718  0.039101  0.007502  0.040817
# 1999-02-26  0.040454  0.040556  0.040169  0.040291  0.012178  0.040628
# 1999-03-31  0.035276  0.035411  0.034622  0.034573  0.008790  0.037452
# 1999-04-30  0.031925  0.033517  0.032438  0.033034  0.022496  0.029750
# 1999-05-28  0.043892  0.045080  0.042309  0.043368  0.033596  0.045894
# 1999-06-30  0.043805  0.044170  0.043634  0.044094  0.012201  0.041716
# 1999-07-30  0.043123  0.046786  0.043547  0.046823  0.014264  0.042717
# 1999-08-31  0.058585  0.060791  0.058834  0.059160  0.009304  0.059311
# 1999-09-30  0.075440  0.074883  0.071748  0.071033  0.012193  0.072177
# 1999-10-29  0.068550  0.069463  0.065924  0.066678  0.027354  0.070363
# 1999-11-30  0.092933  0.095118  0.092218  0.093980  0.020112  0.089031
# 1999-12-31  0.117867  0.125108  0.117245  0.118204  0.018224  0.118592
# 2000-01-31  0.129384  0.131425  0.126520  0.126549  0.006073  0.121580
# 2000-02-29  0.138087  0.141181  0.127976  0.128451  0.016295  0.138986
# 2000-03-31  0.140887  0.147150  0.139259  0.145331  0.011803  0.147689
# 2000-04-28  0.174886  0.179944  0.164112  0.163474  0.015872  0.183328
# 2000-05-31  0.151142  0.164494  0.151212  0.164925  0.011721  0.164820
# 2000-06-30  0.108250  0.108299  0.100502  0.108044  0.029991  0.108802
# 2000-07-31  0.058121  0.058897  0.055820  0.055343  0.015537  0.058484
# 2000-08-31  0.056990  0.056816  0.049734  0.051076  0.018774  0.053683
# 2000-09-29  0.066737  0.067656  0.066943  0.067317  0.023265  0.065113
# 2000-10-31  0.052682  0.058710  0.051554  0.058608  0.088903  0.056221
# 2000-11-30  0.008892  0.009756  0.008779  0.008984  0.056718  0.008529
# 2000-12-29  0.007398  0.007400  0.006595  0.006444  0.042815  0.008268
# 2001-01-31  0.002016  0.002529  0.002315  0.002453  0.025136  0.001958
# 2001-02-28  0.012431  0.012733  0.011866  0.012526  0.061751  0.009530
# 2001-03-30  0.009124  0.009033  0.008692  0.009071  0.029234  0.008805
# 2001-04-30  0.012735  0.014829  0.012783  0.013658  0.054248  0.013185
# 2001-05-31  0.017711  0.018934  0.017515  0.018985  0.039114  0.017667
# 2001-06-29  0.011270  0.010941  0.009580  0.009666  0.069756  0.013533
# 2001-07-31  0.014592  0.015494  0.014880  0.015124  0.029224  0.015723
# 2001-08-31  0.008892  0.008918  0.008430  0.008433  0.019291  0.008355
# 2001-09-28  0.006890  0.007212  0.006639  0.006836  0.031141  0.007905
# 2001-10-31  0.003278  0.003700  0.003611  0.003469  0.026749  0.004090
# 2001-11-30  0.006368  0.006952  0.006319  0.006502  0.022449  0.008094
# 2001-12-31  0.011038  0.010854  0.010876  0.010595  0.015452  0.011401
# 2002-01-31  0.013025  0.014179  0.013453  0.013513  0.024563  0.012460
# 2002-02-28  0.014621  0.015826  0.014880  0.015922  0.040869  0.014839
# 2002-03-28  0.015883  0.015985  0.011968  0.012831  0.093685  0.015839
# 2002-04-30  0.015027  0.015219  0.015345  0.015022  0.008355  0.014810
# 2002-05-31  0.014752  0.015711  0.015098  0.015733  0.022026  0.016376
#
#                    6         7         8         9  ...       141       142  \
# 1998-03-31  0.013817  0.011968  0.013339  0.029973  ...  0.009481  0.008590
# 1998-04-30  0.020408  0.019873  0.020059  0.008364  ...  0.010927  0.009959
# 1998-05-29  0.021405  0.019699  0.020059  0.007493  ...  0.019873  0.020150
# 1998-06-30  0.019685  0.018781  0.019783  0.013782  ...  0.022302  0.021795
# 1998-07-31  0.022302  0.021883  0.021873  0.001533  ...  0.023487  0.023426
# 1998-08-31  0.032795  0.030531  0.031946  0.017447  ...  0.020596  0.020427
# 1998-09-30  0.037665  0.033355  0.035386  0.048958  ...  0.034413  0.033253
# 1998-10-30  0.039024  0.036806  0.037650  0.015447  ...  0.044170  0.041173
# 1998-11-30  0.034413  0.032627  0.034384  0.013475  ...  0.034327  0.032889
# 1998-12-31  0.033055  0.032351  0.031946  0.010643  ...  0.035946  0.033719
# 1999-01-29  0.040918  0.040082  0.040190  0.014593  ...  0.032968  0.032263
# 1999-02-26  0.040744  0.039630  0.039203  0.013534  ...  0.030352  0.028987
# 1999-03-31  0.037304  0.035903  0.035299  0.006339  ...  0.047422  0.041261
# 1999-04-30  0.032159  0.030167  0.032309  0.023175  ...  0.035685  0.033253
# 1999-05-28  0.046973  0.045003  0.044907  0.041429  ...  0.032968  0.029351
# 1999-06-30  0.045080  0.041537  0.044907  0.016966  ...  0.032968  0.030254
# 1999-07-30  0.042999  0.043183  0.042730  0.009409  ...  0.047060  0.044813
# 1999-08-31  0.060979  0.058645  0.059886  0.011830  ...  0.049228  0.047274
# 1999-09-30  0.074883  0.072752  0.074937  0.017405  ...  0.061066  0.058470
# 1999-10-29  0.070547  0.065109  0.067506  0.063175  ...  0.068379  0.066739
# 1999-11-30  0.091678  0.088404  0.091802  0.017227  ...  0.096736  0.093397
# 1999-12-31  0.118966  0.118512  0.118929  0.002524  ...  0.089336  0.081124
# 2000-01-31  0.128635  0.120521  0.127101  0.009731  ...  0.112635  0.110242
# 2000-02-29  0.144259  0.137264  0.140614  0.012361  ...  0.128360  0.124889
# 2000-03-31  0.150040  0.141807  0.141151  0.008059  ...  0.134142  0.127713
# 2000-04-28  0.182474  0.176327  0.178264  0.007619  ...  0.147685  0.142899
# 2000-05-31  0.165939  0.156191  0.157029  0.013627  ...  0.161603  0.155638
# 2000-06-30  0.110828  0.105598  0.106317  0.004844  ...  0.164306  0.155274
# 2000-07-31  0.060979  0.056461  0.059973  0.023363  ...  0.124386  0.117420
# 2000-08-31  0.057900  0.054102  0.056431  0.024172  ...  0.122391  0.112237
# 2000-09-29  0.066847  0.065473  0.066867  0.021529  ...  0.061340  0.058557
# 2000-10-31  0.057178  0.051729  0.051990  0.034315  ...  0.055819  0.054102
# 2000-11-30  0.008672  0.007498  0.007896  0.066675  ...  0.069738  0.066739
# 2000-12-29  0.008397  0.007600  0.007126  0.021727  ...  0.009568  0.008139
# 2001-01-31  0.002341  0.002140  0.002453  0.027054  ...  0.009568  0.008954
# 2001-02-28  0.012372  0.009959  0.012439  0.077173  ...  0.002081  0.001776
# 2001-03-30  0.009395  0.008503  0.009260  0.015800  ...  0.006316  0.005503
# 2001-04-30  0.013456  0.012783  0.013135  0.051562  ...  0.009120  0.008779
# 2001-05-31  0.018659  0.017413  0.016793  0.071894  ...  0.010739  0.009871
# 2001-06-29  0.013456  0.011778  0.012119  0.045069  ...  0.018153  0.015840
# 2001-07-31  0.015624  0.014239  0.014834  0.031656  ...  0.015104  0.015142
# 2001-08-31  0.008759  0.008415  0.008476  0.027874  ...  0.011866  0.010614
# 2001-09-28  0.008152  0.007440  0.006836  0.018970  ...  0.010565  0.009886
# 2001-10-31  0.003902  0.003218  0.002946  0.042970  ...  0.008874  0.008794
# 2001-11-30  0.007920  0.007105  0.006546  0.018896  ...  0.005434  0.004047
# 2001-12-31  0.011592  0.011196  0.010755  0.019976  ...  0.007530  0.007513
# 2002-01-31  0.013095  0.012899  0.012990  0.014388  ...  0.008817  0.008270
# 2002-02-28  0.014959  0.014748  0.014442  0.019004  ...  0.011765  0.010919
# 2002-03-28  0.016159  0.015331  0.015312  0.020877  ...  0.011881  0.011327
# 2002-04-30  0.015104  0.014967  0.015008  0.020660  ...  0.017402  0.016976
# 2002-05-31  0.016159  0.014967  0.014355  0.025117  ...  0.017503  0.016860
#
#                  143       144       145       146       147       148  \
# 1998-03-31  0.008810  0.022721  0.009979  0.009756  0.009507  0.009623
# 1998-04-30  0.010799  0.019663  0.009443  0.009481  0.009871  0.009434
# 1998-05-29  0.019783  0.003847  0.018871  0.019873  0.019335  0.020059
# 1998-06-30  0.021510  0.024276  0.023585  0.023747  0.022523  0.022497
# 1998-07-31  0.023586  0.006599  0.023759  0.023660  0.022785  0.022323
# 1998-08-31  0.020233  0.002784  0.021409  0.021492  0.021067  0.020596
# 1998-09-30  0.032671  0.011858  0.034188  0.033879  0.033166  0.033571
# 1998-10-30  0.040466  0.019256  0.042717  0.043635  0.042993  0.042730
# 1998-11-30  0.034573  0.010268  0.033463  0.034052  0.033253  0.034297
# 1998-12-31  0.035386  0.018773  0.035015  0.035946  0.034622  0.034210
# 1999-01-29  0.032396  0.011866  0.033013  0.032694  0.032074  0.031481
# 1999-02-26  0.028578  0.013978  0.028662  0.029543  0.029162  0.029667
# 1999-03-31  0.041017  0.077779  0.043355  0.049315  0.042993  0.048448
# 1999-04-30  0.033209  0.019927  0.036465  0.036856  0.035262  0.034660
# 1999-05-28  0.029580  0.021644  0.031026  0.032433  0.031346  0.032483
# 1999-06-30  0.030131  0.039861  0.033202  0.033055  0.032802  0.032396
# 1999-07-30  0.046547  0.010382  0.046155  0.047422  0.046094  0.046634
# 1999-08-31  0.049363  0.006117  0.050245  0.050312  0.048089  0.048274
# 1999-09-30  0.059421  0.030233  0.060297  0.061152  0.058281  0.057708
# 1999-10-29  0.066228  0.022283  0.068275  0.070547  0.068297  0.068231
# 1999-11-30  0.095707  0.017870  0.093296  0.093311  0.092495  0.092630
# 1999-12-31  0.080380  0.044625  0.088306  0.088252  0.085026  0.087274
# 2000-01-31  0.111034  0.013526  0.112703  0.117882  0.112514  0.111948
# 2000-02-29  0.126099  0.019683  0.123307  0.123114  0.118337  0.123647
# 2000-03-31  0.131818  0.017989  0.126208  0.128722  0.126156  0.126738
# 2000-04-28  0.142428  0.007317  0.148241  0.147872  0.146175  0.147682
# 2000-05-31  0.162385  0.010702  0.151316  0.157267  0.148184  0.157392
# 2000-06-30  0.165099  0.014762  0.139987  0.160071  0.140264  0.160745
# 2000-07-31  0.117391  0.031297  0.130559  0.132610  0.127976  0.127188
# 2000-08-31  0.121194  0.014907  0.116779  0.116436  0.111145  0.113312
# 2000-09-29  0.058695  0.014835  0.060935  0.063407  0.060290  0.060974
# 2000-10-31  0.053528  0.014262  0.051333  0.056729  0.051816  0.055618
# 2000-11-30  0.069567  0.017781  0.067825  0.068379  0.066739  0.067956
# 2000-12-29  0.008447  0.138746  0.009356  0.011375  0.008779  0.010160
# 2001-01-31  0.008534  0.018914  0.010211  0.010117  0.009507  0.009797
# 2001-02-28  0.001640  0.027086  0.002277  0.002168  0.001864  0.001364
# 2001-03-30  0.005356  0.075788  0.006455  0.007313  0.006231  0.005806
# 2001-04-30  0.008534  0.021234  0.009718  0.010652  0.010148  0.010073
# 2001-05-31  0.010799  0.029942  0.008717  0.010291  0.008954  0.009434
# 2001-06-29  0.018288  0.173442  0.012445  0.015740  0.012172  0.014035
# 2001-07-31  0.015109  0.011319  0.016304  0.016101  0.015331  0.015138
# 2001-08-31  0.010262  0.026640  0.010763  0.011071  0.010599  0.010465
# 2001-09-28  0.009318  0.019102  0.009733  0.009929  0.009857  0.009957
# 2001-10-31  0.008665  0.010274  0.008775  0.008860  0.008546  0.008563
# 2001-11-30  0.003716  0.035158  0.005091  0.005651  0.004193  0.005661
# 2001-12-31  0.007518  0.012051  0.006237  0.007285  0.006654  0.007083
# 2002-01-31  0.008491  0.018090  0.009370  0.009698  0.009478  0.009187
# 2002-02-28  0.011452  0.018523  0.010748  0.011288  0.010876  0.010886
# 2002-03-28  0.011118  0.049882  0.012083  0.012387  0.012361  0.012453
# 2002-04-30  0.016662  0.020880  0.017029  0.017416  0.017369  0.017257
# 2002-05-31  0.017025  0.019195  0.017348  0.017142  0.016889  0.016866
#
#                  149  Label
# 1998-03-31  0.024139      1
# 1998-04-30  0.004920      0
# 1998-05-29  0.009376      0
# 1998-06-30  0.083172      1
# 1998-07-31  0.007267      1
# 1998-08-31  0.001953      0
# 1998-09-30  0.014429      1
# 1998-10-30  0.024928      0
# 1998-11-30  0.010703      0
# 1998-12-31  0.025382      1
# 1999-01-29  0.006243      1
# 1999-02-26  0.008795      0
# 1999-03-31  0.045817      1
# 1999-04-30  0.010277      1
# 1999-05-28  0.007016      0
# 1999-06-30  0.020023      1
# 1999-07-30  0.016060      1
# 1999-08-31  0.006889      1
# 1999-09-30  0.017180      0
# 1999-10-29  0.018433      1
# 1999-11-30  0.009389      1
# 1999-12-31  0.032986      1
# 2000-01-31  0.013516      1
# 2000-02-29  0.018208      1
# 2000-03-31  0.014736      1
# 2000-04-28  0.009967      0
# 2000-05-31  0.014156      0
# 2000-06-30  0.015643      0
# 2000-07-31  0.013951      0
# 2000-08-31  0.010632      1
# 2000-09-29  0.040302      0
# 2000-10-31  0.021895      0
# 2000-11-30  0.021952      0
# 2000-12-29  0.075163      0
# 2001-01-31  0.022978      1
# 2001-02-28  0.044875      0
# 2001-03-30  0.025225      1
# 2001-04-30  0.025726      1
# 2001-05-31  0.040750      0
# 2001-06-29  0.100368      1
# 2001-07-31  0.027683      0
# 2001-08-31  0.028987      0
# 2001-09-28  0.038317      0
# 2001-10-31  0.013958      1
# 2001-11-30  0.031579      1
# 2001-12-31  0.054201      1
# 2002-01-31  0.016423      1
# 2002-02-28  0.012705      0
# 2002-03-28  0.023731      1
# 2002-04-30  0.025863      1
# 2002-05-31  0.025077      0
#
# [51 rows x 151 columns]

# %%
#JOIN THE LABEL DATAFRAME AND THE FLATTENED DATAFRAME ON THE INDEX WHICH IS THE DATE
AAPL_98_train_flat_df = AAPL_98_train_flat_df.merge(AAPL_98_train_labels_df, left_index=True, right_index=True)

AAPL_98_test_flat_df  = AAPL_98_test_flat_df.merge(AAPL_98_test_labels_df, left_index=True, right_index=True)

AAPL_02_train_flat_df = AAPL_02_train_flat_df.merge(AAPL_02_train_labels_df, left_index=True, right_index=True)

AAPL_02_test_flat_df = AAPL_02_test_flat_df.merge(AAPL_02_test_labels_df, left_index=True, right_index=True)

AAPL_06_train_flat_df = AAPL_06_train_flat_df.merge(AAPL_06_train_labels_df, left_index=True, right_index=True)

AAPL_06_test_flat_df =AAPL_06_test_flat_df.merge(AAPL_06_test_labels_df, left_index=True, right_index=True)

AAPL_10_train_flat_df =AAPL_10_train_flat_df.merge(AAPL_10_train_labels_df, left_index=True, right_index=True)

AAPL_10_test_flat_df =AAPL_10_test_flat_df.merge(AAPL_10_test_labels_df, left_index=True, right_index=True)

AAPL_14_train_flat_df =AAPL_14_train_flat_df.merge(AAPL_14_train_labels_df, left_index=True, right_index=True)

AAPL_14_test_flat_df =AAPL_14_test_flat_df.merge(AAPL_14_test_labels_df, left_index=True, right_index=True)

# %%
AAPL_98_train_flat_df.head()
# Out:
#                    0         1         2         3         4         5  \
# 1998-03-31  0.013519  0.014988  0.013322  0.015066  0.024416  0.012068
# 1998-04-30  0.019959  0.020683  0.020427  0.020784  0.008133  0.019770
# 1998-05-29  0.020234  0.020596  0.020427  0.020146  0.005241  0.021583
# 1998-06-30  0.019959  0.021218  0.020427  0.020784  0.010392  0.018421
# 1998-07-31  0.022135  0.022576  0.022334  0.022599  0.004137  0.022497
#
#                    6         7         8         9  ...       141       142  \
# 1998-03-31  0.013817  0.011968  0.013339  0.029973  ...  0.009481  0.008590
# 1998-04-30  0.020408  0.019873  0.020059  0.008364  ...  0.010927  0.009959
# 1998-05-29  0.021405  0.019699  0.020059  0.007493  ...  0.019873  0.020150
# 1998-06-30  0.019685  0.018781  0.019783  0.013782  ...  0.022302  0.021795
# 1998-07-31  0.022302  0.021883  0.021873  0.001533  ...  0.023487  0.023426
#
#                  143       144       145       146       147       148  \
# 1998-03-31  0.008810  0.022721  0.009979  0.009756  0.009507  0.009623
# 1998-04-30  0.010799  0.019663  0.009443  0.009481  0.009871  0.009434
# 1998-05-29  0.019783  0.003847  0.018871  0.019873  0.019335  0.020059
# 1998-06-30  0.021510  0.024276  0.023585  0.023747  0.022523  0.022497
# 1998-07-31  0.023586  0.006599  0.023759  0.023660  0.022785  0.022323
#
#                  149  Label
# 1998-03-31  0.024139      1
# 1998-04-30  0.004920      0
# 1998-05-29  0.009376      0
# 1998-06-30  0.083172      1
# 1998-07-31  0.007267      1
#
# [5 rows x 151 columns]

# %%
#export dataframes which are now ready to be used by the model 
AAPL_list_of_names = ['AAPL_98_train_flat_df_OHLC', 'AAPL_98_test_flat_df_OHLC', 'AAPL_02_train_flat_df_OHLC', 'AAPL_02_test_flat_df_OHLC'
                     ,'AAPL_06_train_flat_df_OHLC','AAPL_06_test_flat_df_OHLC','AAPL_10_train_flat_df_OHLC','AAPL_10_test_flat_df_OHLC',
                     'AAPL_14_train_flat_df_OHLC','AAPL_14_test_flat_df_OHLC']

AAPL_list = [AAPL_98_train_flat_df, AAPL_98_test_flat_df, AAPL_02_train_flat_df, AAPL_02_test_flat_df,
            AAPL_06_train_flat_df, AAPL_06_test_flat_df, AAPL_10_train_flat_df, AAPL_10_test_flat_df,
            AAPL_14_train_flat_df, AAPL_14_test_flat_df]

for i in range(len(AAPL_list)):
    
    str_name = AAPL_list_of_names[i]
    
    export_AAPL = AAPL_list[i].to_csv("/Users/fahad/project_repo/data/final/OHLC/AAPL/{}.csv".format(str_name))

# %%
def labelling(dataframe):
    """This generates labels for the dataframes we wish to predict price.
    A label of 1 suggests an increase in price between months while a label of 0 indicates
    a decrease in price. If the current price is greater than the previous price then a"""
    empty_dict = dict()
    prev_close =0
    counter = 0
    for index,cols in dataframe.iterrows():
        counter +=1
        current_close = cols['Close']
        if float(prev_close) <= float(current_close):
            #signals an increase in price between last month and next month
            empty_dict[index] = 1
        elif float(prev_close) >= float(current_close):
            empty_dict[index]=0

        #reassign prev close to the current close     
        prev_close = current_close
    
    return empty_dict

# %%
def get_ndays_monthly_flattened(dataframe_period_end,dataframe_subperiod,n):
    """returns a dictionary which contains key value pair of the month-end date as key and
    value is the proceeding n days. Returns it as a dictionary of dataframes.
    dataframe period end refers to the dataframe which will act as the period end i.e monthly end date
    sub_period dataframe refers to the dataframe with the preceeding n days, i.e daily"""
    empty_dict = dict()
    count = 0
    for end in dataframe_period_end.index:
#         print ("month end/:%s" % end)
        
        month_key = dataframe_period_end.index[count+1]
        
#         print ("month key:%s" % month_key)
        
        last_index = dataframe_period_end.index[-1]
        
#         print ("last index:%s " % last_index)
        
        if (month_key != last_index):
            temp_df = dataframe_subperiod.loc[dataframe_subperiod['Date']<end].head(n)
#             print ("\n")
#             print (temp_df.head(5))
            temp_df = temp_df.drop(['Date'], axis=1)
            
            empty_dict[month_key]= temp_df.values.flatten()
            count +=1
        else:
            pass
       
    return empty_dict
