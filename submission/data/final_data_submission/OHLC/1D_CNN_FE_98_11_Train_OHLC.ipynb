# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
import csv
from pandas.tseries.offsets import MonthEnd
from datetime import datetime, timedelta, date
import requests
import json 
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
from sklearn.utils.multiclass import unique_labels

from scipy import stats
from IPython.display import display, HTML

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape
from keras.layers import Convolution1D, MaxPooling1D
from keras.utils import np_utils
import seaborn as sns

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 1998_2011 data MSFT

# %%
MSFT_98_train = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/MSFT/MSFT_98_train_flat_df_OHLC.csv", index_col=0)
MSFT_98_train = MSFT_98_train.reset_index(drop=True)


MSFT_98_test = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/MSFT/MSFT_98_test_flat_df_OHLC.csv", index_col=0)
MSFT_98_test = MSFT_98_test.reset_index(drop=True)


MSFT_02_train = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/MSFT/MSFT_02_train_flat_df_OHLC.csv", index_col=0)
MSFT_02_train = MSFT_02_train.reset_index(drop=True)


MSFT_02_test = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/MSFT/MSFT_02_test_flat_df_OHLC.csv", index_col=0)
MSFT_02_test = MSFT_02_test.reset_index(drop=True)


MSFT_06_train = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/MSFT/MSFT_06_train_flat_df_OHLC.csv", index_col=0)
MSFT_06_train = MSFT_06_train.reset_index(drop=True)


MSFT_06_test = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/MSFT/MSFT_06_test_flat_df_OHLC.csv", index_col=0)
MSFT_06_test = MSFT_06_test.reset_index(drop=True)

# %% [markdown]
# # 1998_2011 data AAPL

# %%
AAPL_98_train = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/AAPL/AAPL_98_train_flat_df_OHLC.csv", index_col=0)
AAPL_98_train = AAPL_98_train.reset_index(drop=True)


AAPL_98_test = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/AAPL/AAPL_98_test_flat_df_OHLC.csv", index_col=0)
AAPL_98_test = AAPL_98_test.reset_index(drop=True)


AAPL_02_train = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/AAPL/AAPL_02_train_flat_df_OHLC.csv", index_col=0)
AAPL_02_train = AAPL_02_train.reset_index(drop=True)


AAPL_02_test = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/AAPL/AAPL_02_test_flat_df_OHLC.csv", index_col=0)
AAPL_02_test = AAPL_02_test.reset_index(drop=True)


AAPL_06_train = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/AAPL/AAPL_06_train_flat_df_OHLC.csv", index_col=0)
AAPL_06_train = AAPL_06_train.reset_index(drop=True)


AAPL_06_test = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/AAPL/AAPL_06_test_flat_df_OHLC.csv", index_col=0)
AAPL_06_test = AAPL_06_test.reset_index(drop=True)

# %% [markdown]
# #  1998_2011 data AMZN

# %%
AMZN_98_train = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/AMZN/AMZN_98_train_flat_df_OHLC.csv", index_col=0)
AMZN_98_train = AMZN_98_train.reset_index(drop=True)


AMZN_98_test = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/AMZN/AMZN_98_test_flat_df_OHLC.csv", index_col=0)
AMZN_98_test = AMZN_98_test.reset_index(drop=True)


AMZN_02_train = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/AMZN/AMZN_02_train_flat_df_OHLC.csv", index_col=0)
AMZN_02_train = AMZN_02_train.reset_index(drop=True)


AMZN_02_test = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/AMZN/AMZN_02_test_flat_df_OHLC.csv", index_col=0)
AMZN_02_test = AMZN_02_test.reset_index(drop=True)


AMZN_06_train = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/AMZN/AMZN_06_train_flat_df_OHLC.csv", index_col=0)
AMZN_06_train = AMZN_06_train.reset_index(drop=True)


AMZN_06_test = pd.read_csv("/Users/fahad/project_repo/data/final/OHLC/AMZN/AMZN_06_test_flat_df_OHLC.csv", index_col=0)
AMZN_06_test = AMZN_06_test.reset_index(drop=True)

# %%
X_train= pd.concat([MSFT_98_train,MSFT_98_test,MSFT_02_train,MSFT_02_test,MSFT_06_train,MSFT_06_test,
               AAPL_98_train,AAPL_98_test,AAPL_02_train,AAPL_02_test,AAPL_06_train,AAPL_06_test,
                AMZN_98_train,AMZN_98_test,AMZN_02_train,AMZN_02_test,AMZN_06_train,AMZN_06_test])

# %%
#assign the training labels to y_train
y_train = X_train.Label
y_train_df = pd.DataFrame(y_train)
#drop the labels from the X_train dataframe
X_train = X_train.drop("Label", axis=1)

export_X_train = X_train.to_csv("/Users/fahad/project_repo/data/final/OHLC/X_train_OHLC.csv")
export_y_train = y_train_df.to_csv("/Users/fahad/project_repo/data/final/OHLC/y_train_OHLC.csv")

# %%
def make_timeseries_classifier(sample_num,window_size, filter_length, nb_input_series=1, nb_outputs=1, nb_filter=16):
    """:Return: a Keras Model for predicting the next value in a timeseries given a fixed-size lookback window of previous values.
    The model can handle multiple input timeseries (`nb_input_series`) and multiple prediction targets (`nb_outputs`).
    :param int window_size: The number of previous timeseries values to use as input features.  Also called lag or lookback.
    :param int nb_input_series: The number of input timeseries; 1 for a single timeseries.
      The `X` input to ``fit()`` should be an array of shape ``(n_instances, window_size, nb_input_series)``; each instance is
      a 2D array of shape ``(window_size, nb_input_series)``.  For example, for `window_size` = 3 and `nb_input_series` = 1 (a
      single timeseries), one instance could be ``[[0], [1], [2]]``. See ``make_timeseries_instances()``.
    :param int nb_outputs: The output dimension, often equal to the number of inputs.
      For each input instance (array with shape ``(window_size, nb_input_series)``), the output is a vector of size `nb_outputs`,
      usually the value(s) predicted to come after the last value in that input instance, i.e., the next value
      in the sequence. The `y` input to ``fit()`` should be an array of shape ``(n_instances, nb_outputs)``.
    :param int filter_length: the size (along the `window_size` dimension) of the sliding window that gets convolved with
      each position along each instance. The difference between 1D and 2D convolution is that a 1D filter's "height" is fixed
      to the number of input timeseries (its "width" being `filter_length`), and it can only slide along the window
      dimension.  This is useful as generally the input timeseries have no spatial/ordinal relationship, so it's not
      meaningful to look for patterns that are invariant with respect to subsets of the timeseries.
    :param int nb_filter: The number of different filters to learn (roughly, input patterns to recognize).
    """
    model = Sequential((
        # The first conv layer learns `nb_filter` filters (aka kernels), each of size ``(filter_length, nb_input_series)``.
        # Its output will have shape (None, window_size - filter_length + 1, nb_filter), i.e., for each position in
        # the input timeseries, the activation of each filter at that position.
        Convolution1D(nb_filter=nb_filter, filter_length=filter_length, activation='relu', input_shape=(window_size,nb_input_series)),
        MaxPooling1D(),     # Downsample the output of convolution by 2X.
        Convolution1D(nb_filter=nb_filter, filter_length=filter_length, activation='relu'),
        MaxPooling1D(),
        Flatten(),
        Dense(nb_outputs, activation='sigmoid'),     # For binary classification, change the activation to 'sigmoid'
    ))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # To perform (binary) classification instead:
    # model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])
    
    return model

# %%
model_1 = make_timeseries_classifier(X_train.shape[0],X_train.shape[1],3)
# Out:
# /Users/fahad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(activation="relu", input_shape=(150, 1), filters=16, kernel_size=3)`
# WARNING: Logging before flag parsing goes to stderr.
# W0818 11:16:22.172845 4425348544 deprecation_wrapper.py:119] From /Users/fahad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# /Users/fahad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(activation="relu", filters=16, kernel_size=3)`
# W0818 11:16:22.268724 4425348544 deprecation_wrapper.py:119] From /Users/fahad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0818 11:16:22.342487 4425348544 deprecation_wrapper.py:119] From /Users/fahad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0818 11:16:22.420847 4425348544 deprecation_wrapper.py:119] From /Users/fahad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0818 11:16:22.468805 4425348544 deprecation_wrapper.py:119] From /Users/fahad/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0818 11:16:22.493236 4425348544 deprecation_wrapper.py:119] From /Users/fahad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0818 11:16:22.497865 4425348544 deprecation.py:323] From /Users/fahad/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model_1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 148, 16)           64
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 74, 16)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 72, 16)            784
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 36, 16)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 577
# =================================================================
# Total params: 1,425
# Trainable params: 1,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_acc', mode='max', verbose=0, patience=150)
mc = ModelCheckpoint('1D_CNN_FE_98_11_model_OHLC.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
cb_list = [es,mc]

# %%
X_train = np.array(X_train).reshape(*X_train.shape,1)

# %%
# Out:
# (609, 150, 1)

# %%
history=model_1.fit(X_train, y_train,validation_split=0.10, epochs=1000,batch_size=1, verbose=1,
                    callbacks = cb_list)
# Out:
# W0818 11:18:05.248803 4425348544 deprecation_wrapper.py:119] From /Users/fahad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 548 samples, validate on 61 samples
# Epoch 1/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.6935 - acc: 0.5639 - val_loss: 0.6566 - val_acc: 0.6885
#
# Epoch 00001: val_acc improved from -inf to 0.68852, saving model to 1D_CNN_FE_98_11_model_OHLC.h5
# Epoch 2/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6860 - acc: 0.5620 - val_loss: 0.6533 - val_acc: 0.6885
#
# Epoch 00002: val_acc did not improve from 0.68852
# Epoch 3/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6851 - acc: 0.5730 - val_loss: 0.6475 - val_acc: 0.6885
#
# Epoch 00003: val_acc did not improve from 0.68852
# Epoch 4/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.6807 - acc: 0.5858 - val_loss: 0.6414 - val_acc: 0.6885
#
# Epoch 00004: val_acc did not improve from 0.68852
# Epoch 5/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6750 - acc: 0.5858 - val_loss: 0.6428 - val_acc: 0.7377
#
# Epoch 00005: val_acc improved from 0.68852 to 0.73770, saving model to 1D_CNN_FE_98_11_model_OHLC.h5
# Epoch 6/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6681 - acc: 0.6004 - val_loss: 0.6272 - val_acc: 0.7049
#
# Epoch 00006: val_acc did not improve from 0.73770
# Epoch 7/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6636 - acc: 0.6004 - val_loss: 0.6204 - val_acc: 0.7705
#
# Epoch 00007: val_acc improved from 0.73770 to 0.77049, saving model to 1D_CNN_FE_98_11_model_OHLC.h5
# Epoch 8/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6610 - acc: 0.6204 - val_loss: 0.6088 - val_acc: 0.7541
#
# Epoch 00008: val_acc did not improve from 0.77049
# Epoch 9/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6533 - acc: 0.6277 - val_loss: 0.6083 - val_acc: 0.7541
#
# Epoch 00009: val_acc did not improve from 0.77049
# Epoch 10/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6504 - acc: 0.6296 - val_loss: 0.5988 - val_acc: 0.7541
#
# Epoch 00010: val_acc did not improve from 0.77049
# Epoch 11/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6428 - acc: 0.6350 - val_loss: 0.5881 - val_acc: 0.7377
#
# Epoch 00011: val_acc did not improve from 0.77049
# Epoch 12/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6399 - acc: 0.6113 - val_loss: 0.6004 - val_acc: 0.7541
#
# Epoch 00012: val_acc did not improve from 0.77049
# Epoch 13/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6366 - acc: 0.6259 - val_loss: 0.5960 - val_acc: 0.7541
#
# Epoch 00013: val_acc did not improve from 0.77049
# Epoch 14/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6345 - acc: 0.6314 - val_loss: 0.5901 - val_acc: 0.7377
#
# Epoch 00014: val_acc did not improve from 0.77049
# Epoch 15/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6325 - acc: 0.6314 - val_loss: 0.5824 - val_acc: 0.7377
#
# Epoch 00015: val_acc did not improve from 0.77049
# Epoch 16/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6263 - acc: 0.6277 - val_loss: 0.5773 - val_acc: 0.7377
#
# Epoch 00016: val_acc did not improve from 0.77049
# Epoch 17/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6255 - acc: 0.6350 - val_loss: 0.5698 - val_acc: 0.7377
#
# Epoch 00017: val_acc did not improve from 0.77049
# Epoch 18/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6251 - acc: 0.6332 - val_loss: 0.5840 - val_acc: 0.7377
#
# Epoch 00018: val_acc did not improve from 0.77049
# Epoch 19/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6214 - acc: 0.6314 - val_loss: 0.5750 - val_acc: 0.7377
#
# Epoch 00019: val_acc did not improve from 0.77049
# Epoch 20/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6201 - acc: 0.6223 - val_loss: 0.5768 - val_acc: 0.7049
#
# Epoch 00020: val_acc did not improve from 0.77049
# Epoch 21/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6189 - acc: 0.6223 - val_loss: 0.5887 - val_acc: 0.7377
#
# Epoch 00021: val_acc did not improve from 0.77049
# Epoch 22/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6184 - acc: 0.6350 - val_loss: 0.5915 - val_acc: 0.6230
#
# Epoch 00022: val_acc did not improve from 0.77049
# Epoch 23/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6163 - acc: 0.6423 - val_loss: 0.5933 - val_acc: 0.6557
#
# Epoch 00023: val_acc did not improve from 0.77049
# Epoch 24/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6131 - acc: 0.6387 - val_loss: 0.5868 - val_acc: 0.6885
#
# Epoch 00024: val_acc did not improve from 0.77049
# Epoch 25/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6102 - acc: 0.6442 - val_loss: 0.5855 - val_acc: 0.6885
#
# Epoch 00025: val_acc did not improve from 0.77049
# Epoch 26/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6090 - acc: 0.6332 - val_loss: 0.5929 - val_acc: 0.6393
#
# Epoch 00026: val_acc did not improve from 0.77049
# Epoch 27/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6108 - acc: 0.6314 - val_loss: 0.5800 - val_acc: 0.7049
#
# Epoch 00027: val_acc did not improve from 0.77049
# Epoch 28/1000
# 548/548 [==============================] - ETA: 0s - loss: 0.6037 - acc: 0.659 - 1s 1ms/step - loss: 0.6053 - acc: 0.6588 - val_loss: 0.5825 - val_acc: 0.6721
#
# Epoch 00028: val_acc did not improve from 0.77049
# Epoch 29/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6069 - acc: 0.6241 - val_loss: 0.5978 - val_acc: 0.6557
#
# Epoch 00029: val_acc did not improve from 0.77049
# Epoch 30/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5988 - acc: 0.6350 - val_loss: 0.5880 - val_acc: 0.6885
#
# Epoch 00030: val_acc did not improve from 0.77049
# Epoch 31/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5997 - acc: 0.6350 - val_loss: 0.5952 - val_acc: 0.6393
#
# Epoch 00031: val_acc did not improve from 0.77049
# Epoch 32/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5974 - acc: 0.6277 - val_loss: 0.5865 - val_acc: 0.6721
#
# Epoch 00032: val_acc did not improve from 0.77049
# Epoch 33/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5936 - acc: 0.6478 - val_loss: 0.6127 - val_acc: 0.6230
#
# Epoch 00033: val_acc did not improve from 0.77049
# Epoch 34/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5940 - acc: 0.6423 - val_loss: 0.5989 - val_acc: 0.6557
#
# Epoch 00034: val_acc did not improve from 0.77049
# Epoch 35/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5896 - acc: 0.6460 - val_loss: 0.6037 - val_acc: 0.6885
#
# Epoch 00035: val_acc did not improve from 0.77049
# Epoch 36/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5900 - acc: 0.6606 - val_loss: 0.6026 - val_acc: 0.6066
#
# Epoch 00036: val_acc did not improve from 0.77049
# Epoch 37/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5884 - acc: 0.6624 - val_loss: 0.5970 - val_acc: 0.6721
#
# Epoch 00037: val_acc did not improve from 0.77049
# Epoch 38/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5850 - acc: 0.6588 - val_loss: 0.5795 - val_acc: 0.6885
#
# Epoch 00038: val_acc did not improve from 0.77049
# Epoch 39/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5840 - acc: 0.6624 - val_loss: 0.6070 - val_acc: 0.6721
#
# Epoch 00039: val_acc did not improve from 0.77049
# Epoch 40/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5804 - acc: 0.6569 - val_loss: 0.5977 - val_acc: 0.6885
#
# Epoch 00040: val_acc did not improve from 0.77049
# Epoch 41/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5799 - acc: 0.6679 - val_loss: 0.6047 - val_acc: 0.6557
#
# Epoch 00041: val_acc did not improve from 0.77049
# Epoch 42/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5760 - acc: 0.6697 - val_loss: 0.6040 - val_acc: 0.6557
#
# Epoch 00042: val_acc did not improve from 0.77049
# Epoch 43/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5723 - acc: 0.6752 - val_loss: 0.5904 - val_acc: 0.6721
#
# Epoch 00043: val_acc did not improve from 0.77049
# Epoch 44/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5688 - acc: 0.6807 - val_loss: 0.5969 - val_acc: 0.6885
#
# Epoch 00044: val_acc did not improve from 0.77049
# Epoch 45/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5660 - acc: 0.6752 - val_loss: 0.5965 - val_acc: 0.6721
#
# Epoch 00045: val_acc did not improve from 0.77049
# Epoch 46/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5609 - acc: 0.6880 - val_loss: 0.5990 - val_acc: 0.6721
#
# Epoch 00046: val_acc did not improve from 0.77049
# Epoch 47/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5639 - acc: 0.6807 - val_loss: 0.5960 - val_acc: 0.6885
#
# Epoch 00047: val_acc did not improve from 0.77049
# Epoch 48/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.5578 - acc: 0.6788 - val_loss: 0.5911 - val_acc: 0.6885
#
# Epoch 00048: val_acc did not improve from 0.77049
# Epoch 49/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5563 - acc: 0.6825 - val_loss: 0.5940 - val_acc: 0.6721
#
# Epoch 00049: val_acc did not improve from 0.77049
# Epoch 50/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5512 - acc: 0.6898 - val_loss: 0.6013 - val_acc: 0.6885
#
# Epoch 00050: val_acc did not improve from 0.77049
# Epoch 51/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5501 - acc: 0.7062 - val_loss: 0.5776 - val_acc: 0.6885
#
# Epoch 00051: val_acc did not improve from 0.77049
# Epoch 52/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5479 - acc: 0.6916 - val_loss: 0.6021 - val_acc: 0.6885
#
# Epoch 00052: val_acc did not improve from 0.77049
# Epoch 53/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5418 - acc: 0.7153 - val_loss: 0.5890 - val_acc: 0.6721
#
# Epoch 00053: val_acc did not improve from 0.77049
# Epoch 54/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5374 - acc: 0.7117 - val_loss: 0.5863 - val_acc: 0.7213
#
# Epoch 00054: val_acc did not improve from 0.77049
# Epoch 55/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5366 - acc: 0.7208 - val_loss: 0.5888 - val_acc: 0.7049
#
# Epoch 00055: val_acc did not improve from 0.77049
# Epoch 56/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5356 - acc: 0.7226 - val_loss: 0.6009 - val_acc: 0.6721
#
# Epoch 00056: val_acc did not improve from 0.77049
# Epoch 57/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5315 - acc: 0.7099 - val_loss: 0.6168 - val_acc: 0.7049
#
# Epoch 00057: val_acc did not improve from 0.77049
# Epoch 58/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5283 - acc: 0.7226 - val_loss: 0.5932 - val_acc: 0.7213
#
# Epoch 00058: val_acc did not improve from 0.77049
# Epoch 59/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5219 - acc: 0.7391 - val_loss: 0.6004 - val_acc: 0.7213
#
# Epoch 00059: val_acc did not improve from 0.77049
# Epoch 60/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5211 - acc: 0.7391 - val_loss: 0.5975 - val_acc: 0.7213
#
# Epoch 00060: val_acc did not improve from 0.77049
# Epoch 61/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5158 - acc: 0.7299 - val_loss: 0.6142 - val_acc: 0.7049
#
# Epoch 00061: val_acc did not improve from 0.77049
# Epoch 62/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5106 - acc: 0.7372 - val_loss: 0.6374 - val_acc: 0.7049
#
# Epoch 00062: val_acc did not improve from 0.77049
# Epoch 63/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5083 - acc: 0.7464 - val_loss: 0.5870 - val_acc: 0.7213
#
# Epoch 00063: val_acc did not improve from 0.77049
# Epoch 64/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5037 - acc: 0.7500 - val_loss: 0.6352 - val_acc: 0.7377
#
# Epoch 00064: val_acc did not improve from 0.77049
# Epoch 65/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4997 - acc: 0.7500 - val_loss: 0.6229 - val_acc: 0.7213
#
# Epoch 00065: val_acc did not improve from 0.77049
# Epoch 66/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4974 - acc: 0.7555 - val_loss: 0.6153 - val_acc: 0.7213
#
# Epoch 00066: val_acc did not improve from 0.77049
# Epoch 67/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4948 - acc: 0.7555 - val_loss: 0.6237 - val_acc: 0.7377
#
# Epoch 00067: val_acc did not improve from 0.77049
# Epoch 68/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4848 - acc: 0.7555 - val_loss: 0.6222 - val_acc: 0.6885
#
# Epoch 00068: val_acc did not improve from 0.77049
# Epoch 69/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4882 - acc: 0.7737 - val_loss: 0.6487 - val_acc: 0.7213
#
# Epoch 00069: val_acc did not improve from 0.77049
# Epoch 70/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4802 - acc: 0.7591 - val_loss: 0.6177 - val_acc: 0.7049
#
# Epoch 00070: val_acc did not improve from 0.77049
# Epoch 71/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4756 - acc: 0.7701 - val_loss: 0.6212 - val_acc: 0.7213
#
# Epoch 00071: val_acc did not improve from 0.77049
# Epoch 72/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4756 - acc: 0.7628 - val_loss: 0.6450 - val_acc: 0.6885
#
# Epoch 00072: val_acc did not improve from 0.77049
# Epoch 73/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4675 - acc: 0.7774 - val_loss: 0.6501 - val_acc: 0.7213
#
# Epoch 00073: val_acc did not improve from 0.77049
# Epoch 74/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4645 - acc: 0.7847 - val_loss: 0.6240 - val_acc: 0.6885
#
# Epoch 00074: val_acc did not improve from 0.77049
# Epoch 75/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4657 - acc: 0.7755 - val_loss: 0.6423 - val_acc: 0.7049
#
# Epoch 00075: val_acc did not improve from 0.77049
# Epoch 76/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4621 - acc: 0.7920 - val_loss: 0.6537 - val_acc: 0.7049
#
# Epoch 00076: val_acc did not improve from 0.77049
# Epoch 77/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4590 - acc: 0.7701 - val_loss: 0.6250 - val_acc: 0.7049
#
# Epoch 00077: val_acc did not improve from 0.77049
# Epoch 78/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4528 - acc: 0.7828 - val_loss: 0.6801 - val_acc: 0.6885
#
# Epoch 00078: val_acc did not improve from 0.77049
# Epoch 79/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4486 - acc: 0.7810 - val_loss: 0.6323 - val_acc: 0.6885
#
# Epoch 00079: val_acc did not improve from 0.77049
# Epoch 80/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4474 - acc: 0.7883 - val_loss: 0.6444 - val_acc: 0.7049
#
# Epoch 00080: val_acc did not improve from 0.77049
# Epoch 81/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4409 - acc: 0.7956 - val_loss: 0.6783 - val_acc: 0.7049
#
# Epoch 00081: val_acc did not improve from 0.77049
# Epoch 82/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4403 - acc: 0.8066 - val_loss: 0.6511 - val_acc: 0.7049
#
# Epoch 00082: val_acc did not improve from 0.77049
# Epoch 83/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4347 - acc: 0.8175 - val_loss: 0.6448 - val_acc: 0.6885
#
# Epoch 00083: val_acc did not improve from 0.77049
# Epoch 84/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4321 - acc: 0.7938 - val_loss: 0.6484 - val_acc: 0.7049
#
# Epoch 00084: val_acc did not improve from 0.77049
# Epoch 85/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4260 - acc: 0.8193 - val_loss: 0.6772 - val_acc: 0.6885
#
# Epoch 00085: val_acc did not improve from 0.77049
# Epoch 86/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4261 - acc: 0.8066 - val_loss: 0.7039 - val_acc: 0.7377
#
# Epoch 00086: val_acc did not improve from 0.77049
# Epoch 87/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4202 - acc: 0.8011 - val_loss: 0.7323 - val_acc: 0.7377
#
# Epoch 00087: val_acc did not improve from 0.77049
# Epoch 88/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4196 - acc: 0.8120 - val_loss: 0.6954 - val_acc: 0.6885
#
# Epoch 00088: val_acc did not improve from 0.77049
# Epoch 89/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4193 - acc: 0.8047 - val_loss: 0.6789 - val_acc: 0.7049
#
# Epoch 00089: val_acc did not improve from 0.77049
# Epoch 90/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4061 - acc: 0.8139 - val_loss: 0.6807 - val_acc: 0.7049
#
# Epoch 00090: val_acc did not improve from 0.77049
# Epoch 91/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4184 - acc: 0.8047 - val_loss: 0.7065 - val_acc: 0.7049
#
# Epoch 00091: val_acc did not improve from 0.77049
# Epoch 92/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4028 - acc: 0.8303 - val_loss: 0.6841 - val_acc: 0.7049
#
# Epoch 00092: val_acc did not improve from 0.77049
# Epoch 93/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3990 - acc: 0.8339 - val_loss: 0.7095 - val_acc: 0.6885
#
# Epoch 00093: val_acc did not improve from 0.77049
# Epoch 94/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4031 - acc: 0.8175 - val_loss: 0.6983 - val_acc: 0.7049
#
# Epoch 00094: val_acc did not improve from 0.77049
# Epoch 95/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4000 - acc: 0.8193 - val_loss: 0.7032 - val_acc: 0.7049
#
# Epoch 00095: val_acc did not improve from 0.77049
# Epoch 96/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3943 - acc: 0.8230 - val_loss: 0.7287 - val_acc: 0.7213
#
# Epoch 00096: val_acc did not improve from 0.77049
# Epoch 97/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3924 - acc: 0.8431 - val_loss: 0.7268 - val_acc: 0.6885
#
# Epoch 00097: val_acc did not improve from 0.77049
# Epoch 98/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3827 - acc: 0.8212 - val_loss: 0.7141 - val_acc: 0.7049
#
# Epoch 00098: val_acc did not improve from 0.77049
# Epoch 99/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3823 - acc: 0.8303 - val_loss: 0.7024 - val_acc: 0.7213
#
# Epoch 00099: val_acc did not improve from 0.77049
# Epoch 100/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3863 - acc: 0.8266 - val_loss: 0.7367 - val_acc: 0.6721
#
# Epoch 00100: val_acc did not improve from 0.77049
# Epoch 101/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3862 - acc: 0.8376 - val_loss: 0.7075 - val_acc: 0.6885
#
# Epoch 00101: val_acc did not improve from 0.77049
# Epoch 102/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3777 - acc: 0.8175 - val_loss: 0.7342 - val_acc: 0.7049
#
# Epoch 00102: val_acc did not improve from 0.77049
# Epoch 103/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3765 - acc: 0.8248 - val_loss: 0.7287 - val_acc: 0.7049
#
# Epoch 00103: val_acc did not improve from 0.77049
# Epoch 104/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3785 - acc: 0.8266 - val_loss: 0.7145 - val_acc: 0.6721
#
# Epoch 00104: val_acc did not improve from 0.77049
# Epoch 105/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3715 - acc: 0.8358 - val_loss: 0.7450 - val_acc: 0.7049
#
# Epoch 00105: val_acc did not improve from 0.77049
# Epoch 106/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3692 - acc: 0.8485 - val_loss: 0.7151 - val_acc: 0.7213
#
# Epoch 00106: val_acc did not improve from 0.77049
# Epoch 107/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3666 - acc: 0.8339 - val_loss: 0.7461 - val_acc: 0.6721
#
# Epoch 00107: val_acc did not improve from 0.77049
# Epoch 108/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3583 - acc: 0.8467 - val_loss: 0.7400 - val_acc: 0.6885
#
# Epoch 00108: val_acc did not improve from 0.77049
# Epoch 109/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3660 - acc: 0.8303 - val_loss: 0.7391 - val_acc: 0.7049
#
# Epoch 00109: val_acc did not improve from 0.77049
# Epoch 110/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3559 - acc: 0.8558 - val_loss: 0.7378 - val_acc: 0.7213
#
# Epoch 00110: val_acc did not improve from 0.77049
# Epoch 111/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3592 - acc: 0.8504 - val_loss: 0.7819 - val_acc: 0.6885
#
# Epoch 00111: val_acc did not improve from 0.77049
# Epoch 112/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3514 - acc: 0.8376 - val_loss: 0.7971 - val_acc: 0.7049
#
# Epoch 00112: val_acc did not improve from 0.77049
# Epoch 113/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3489 - acc: 0.8376 - val_loss: 0.7813 - val_acc: 0.7213
#
# Epoch 00113: val_acc did not improve from 0.77049
# Epoch 114/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3586 - acc: 0.8376 - val_loss: 0.7933 - val_acc: 0.6885
#
# Epoch 00114: val_acc did not improve from 0.77049
# Epoch 115/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3455 - acc: 0.8485 - val_loss: 0.8303 - val_acc: 0.6557
#
# Epoch 00115: val_acc did not improve from 0.77049
# Epoch 116/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3443 - acc: 0.8485 - val_loss: 0.8127 - val_acc: 0.7049
#
# Epoch 00116: val_acc did not improve from 0.77049
# Epoch 117/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3446 - acc: 0.8467 - val_loss: 0.8043 - val_acc: 0.6885
#
# Epoch 00117: val_acc did not improve from 0.77049
# Epoch 118/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3328 - acc: 0.8631 - val_loss: 0.8404 - val_acc: 0.6885
#
# Epoch 00118: val_acc did not improve from 0.77049
# Epoch 119/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3419 - acc: 0.8522 - val_loss: 0.7938 - val_acc: 0.6885
#
# Epoch 00119: val_acc did not improve from 0.77049
# Epoch 120/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3409 - acc: 0.8577 - val_loss: 0.8053 - val_acc: 0.6885
#
# Epoch 00120: val_acc did not improve from 0.77049
# Epoch 121/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3289 - acc: 0.8668 - val_loss: 0.8065 - val_acc: 0.6721
#
# Epoch 00121: val_acc did not improve from 0.77049
# Epoch 122/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3336 - acc: 0.8631 - val_loss: 0.8432 - val_acc: 0.6885
#
# Epoch 00122: val_acc did not improve from 0.77049
# Epoch 123/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3253 - acc: 0.8558 - val_loss: 0.8285 - val_acc: 0.7213
#
# Epoch 00123: val_acc did not improve from 0.77049
# Epoch 124/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3261 - acc: 0.8522 - val_loss: 0.8706 - val_acc: 0.6721
#
# Epoch 00124: val_acc did not improve from 0.77049
# Epoch 125/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3206 - acc: 0.8686 - val_loss: 0.8688 - val_acc: 0.6721
#
# Epoch 00125: val_acc did not improve from 0.77049
# Epoch 126/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3224 - acc: 0.8613 - val_loss: 0.8450 - val_acc: 0.7213
#
# Epoch 00126: val_acc did not improve from 0.77049
# Epoch 127/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3170 - acc: 0.8668 - val_loss: 0.8564 - val_acc: 0.6721
#
# Epoch 00127: val_acc did not improve from 0.77049
# Epoch 128/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3140 - acc: 0.8631 - val_loss: 0.9140 - val_acc: 0.6557
#
# Epoch 00128: val_acc did not improve from 0.77049
# Epoch 129/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3089 - acc: 0.8686 - val_loss: 0.8723 - val_acc: 0.6721
#
# Epoch 00129: val_acc did not improve from 0.77049
# Epoch 130/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3088 - acc: 0.8796 - val_loss: 0.8928 - val_acc: 0.6885
#
# Epoch 00130: val_acc did not improve from 0.77049
# Epoch 131/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3173 - acc: 0.8631 - val_loss: 0.9180 - val_acc: 0.6885
#
# Epoch 00131: val_acc did not improve from 0.77049
# Epoch 132/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3186 - acc: 0.8686 - val_loss: 0.8987 - val_acc: 0.7049
#
# Epoch 00132: val_acc did not improve from 0.77049
# Epoch 133/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3021 - acc: 0.8704 - val_loss: 0.9033 - val_acc: 0.6885
#
# Epoch 00133: val_acc did not improve from 0.77049
# Epoch 134/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3096 - acc: 0.8723 - val_loss: 0.9385 - val_acc: 0.7049
#
# Epoch 00134: val_acc did not improve from 0.77049
# Epoch 135/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2967 - acc: 0.8723 - val_loss: 0.9304 - val_acc: 0.7049
#
# Epoch 00135: val_acc did not improve from 0.77049
# Epoch 136/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3005 - acc: 0.8759 - val_loss: 0.9543 - val_acc: 0.7049
#
# Epoch 00136: val_acc did not improve from 0.77049
# Epoch 137/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2973 - acc: 0.8759 - val_loss: 0.9471 - val_acc: 0.6721
#
# Epoch 00137: val_acc did not improve from 0.77049
# Epoch 138/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2916 - acc: 0.8741 - val_loss: 1.0092 - val_acc: 0.6393
#
# Epoch 00138: val_acc did not improve from 0.77049
# Epoch 139/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2952 - acc: 0.8796 - val_loss: 1.0081 - val_acc: 0.6721
#
# Epoch 00139: val_acc did not improve from 0.77049
# Epoch 140/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3050 - acc: 0.8686 - val_loss: 1.0130 - val_acc: 0.6721
#
# Epoch 00140: val_acc did not improve from 0.77049
# Epoch 141/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2835 - acc: 0.8887 - val_loss: 0.9986 - val_acc: 0.7049
#
# Epoch 00141: val_acc did not improve from 0.77049
# Epoch 142/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2950 - acc: 0.8887 - val_loss: 0.9955 - val_acc: 0.6885
#
# Epoch 00142: val_acc did not improve from 0.77049
# Epoch 143/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2836 - acc: 0.8887 - val_loss: 1.0039 - val_acc: 0.6721
#
# Epoch 00143: val_acc did not improve from 0.77049
# Epoch 144/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2806 - acc: 0.8759 - val_loss: 1.0151 - val_acc: 0.7049
#
# Epoch 00144: val_acc did not improve from 0.77049
# Epoch 145/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2828 - acc: 0.8850 - val_loss: 1.0167 - val_acc: 0.6721
#
# Epoch 00145: val_acc did not improve from 0.77049
# Epoch 146/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2848 - acc: 0.8832 - val_loss: 1.0416 - val_acc: 0.6885
#
# Epoch 00146: val_acc did not improve from 0.77049
# Epoch 147/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2803 - acc: 0.8814 - val_loss: 1.0408 - val_acc: 0.6393
#
# Epoch 00147: val_acc did not improve from 0.77049
# Epoch 148/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2777 - acc: 0.8723 - val_loss: 1.0252 - val_acc: 0.6885
#
# Epoch 00148: val_acc did not improve from 0.77049
# Epoch 149/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2710 - acc: 0.8796 - val_loss: 1.0193 - val_acc: 0.6885
#
# Epoch 00149: val_acc did not improve from 0.77049
# Epoch 150/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2729 - acc: 0.8869 - val_loss: 1.0494 - val_acc: 0.7049
#
# Epoch 00150: val_acc did not improve from 0.77049
# Epoch 151/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2731 - acc: 0.8960 - val_loss: 1.0736 - val_acc: 0.7049
#
# Epoch 00151: val_acc did not improve from 0.77049
# Epoch 152/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2642 - acc: 0.8942 - val_loss: 1.0789 - val_acc: 0.6885
#
# Epoch 00152: val_acc did not improve from 0.77049
# Epoch 153/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2773 - acc: 0.8850 - val_loss: 1.0719 - val_acc: 0.7049
#
# Epoch 00153: val_acc did not improve from 0.77049
# Epoch 154/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2616 - acc: 0.8905 - val_loss: 1.0413 - val_acc: 0.6885
#
# Epoch 00154: val_acc did not improve from 0.77049
# Epoch 155/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2647 - acc: 0.9069 - val_loss: 1.0696 - val_acc: 0.7049
#
# Epoch 00155: val_acc did not improve from 0.77049
# Epoch 156/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2665 - acc: 0.8887 - val_loss: 1.0751 - val_acc: 0.7049
#
# Epoch 00156: val_acc did not improve from 0.77049
# Epoch 157/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2600 - acc: 0.8996 - val_loss: 1.1072 - val_acc: 0.7049
#
# Epoch 00157: val_acc did not improve from 0.77049

# %%
#plot the accuracy of the training set  and the validation set of the model
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

plt.rc('font', **font)
axis_font = {'fontname':'Arial', 'size':'25'}

plt.figure(figsize=[20,20])
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.ylabel('Accuracy', **axis_font)
plt.xlabel('Epochs', **axis_font)

plt.show()
# Out:
# W0818 11:20:17.999308 4425348544 font_manager.py:1282] findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
