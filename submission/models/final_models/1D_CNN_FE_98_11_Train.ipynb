# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
import csv
from pandas.tseries.offsets import MonthEnd
from datetime import datetime, timedelta, date
import requests
import json 
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
from sklearn.utils.multiclass import unique_labels

from scipy import stats
from IPython.display import display, HTML

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape
from keras.layers import Convolution1D, MaxPooling1D
from keras.utils import np_utils
import seaborn as sns

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 1998_2011 data MSFT

# %%
MSFT_98_train = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_98_train_flat_df.csv", index_col=0)
MSFT_98_train = MSFT_98_train.reset_index(drop=True)


MSFT_98_test = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_98_test_flat_df.csv", index_col=0)
MSFT_98_test = MSFT_98_test.reset_index(drop=True)


MSFT_02_train = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_02_train_flat_df.csv", index_col=0)
MSFT_02_train = MSFT_02_train.reset_index(drop=True)


MSFT_02_test = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_02_test_flat_df.csv", index_col=0)
MSFT_02_test = MSFT_02_test.reset_index(drop=True)


MSFT_06_train = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_06_train_flat_df.csv", index_col=0)
MSFT_06_train = MSFT_06_train.reset_index(drop=True)


MSFT_06_test = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_06_test_flat_df.csv", index_col=0)
MSFT_06_test = MSFT_06_test.reset_index(drop=True)

# %% [markdown]
# # 1998_2011 data AAPL

# %%
AAPL_98_train = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/AAPL_98_train_flat_df.csv", index_col=0)
AAPL_98_train = AAPL_98_train.reset_index(drop=True)


AAPL_98_test = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/AAPL_98_test_flat_df.csv", index_col=0)
AAPL_98_test = AAPL_98_test.reset_index(drop=True)


AAPL_02_train = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/AAPL_02_train_flat_df.csv", index_col=0)
AAPL_02_train = AAPL_02_train.reset_index(drop=True)


AAPL_02_test = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/AAPL_02_test_flat_df.csv", index_col=0)
AAPL_02_test = AAPL_02_test.reset_index(drop=True)


AAPL_06_train = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/AAPL_06_train_flat_df.csv", index_col=0)
AAPL_06_train = AAPL_06_train.reset_index(drop=True)


AAPL_06_test = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/AAPL_06_test_flat_df.csv", index_col=0)
AAPL_06_test = AAPL_06_test.reset_index(drop=True)

# %% [markdown]
# # 1998_2011 data AMZN

# %%
AMZN_98_train = pd.read_csv("/Users/fahad/project_repo/data/final/AMZN/AMZN_98_train_flat_df.csv", index_col=0)
AMZN_98_train = AMZN_98_train.reset_index(drop=True)


AMZN_98_test = pd.read_csv("/Users/fahad/project_repo/data/final/AMZN/AMZN_98_test_flat_df.csv", index_col=0)
AMZN_98_test = AMZN_98_test.reset_index(drop=True)


AMZN_02_train = pd.read_csv("/Users/fahad/project_repo/data/final/AMZN/AMZN_02_train_flat_df.csv", index_col=0)
AMZN_02_train = AMZN_02_train.reset_index(drop=True)


AMZN_02_test = pd.read_csv("/Users/fahad/project_repo/data/final/AMZN/AMZN_02_test_flat_df.csv", index_col=0)
AMZN_02_test = AMZN_02_test.reset_index(drop=True)


AMZN_06_train = pd.read_csv("/Users/fahad/project_repo/data/final/AMZN/AMZN_06_train_flat_df.csv", index_col=0)
AMZN_06_train = AMZN_06_train.reset_index(drop=True)


AMZN_06_test = pd.read_csv("/Users/fahad/project_repo/data/final/AMZN/AMZN_06_test_flat_df.csv", index_col=0)
AMZN_06_test = AMZN_06_test.reset_index(drop=True)

# %% [markdown]
# # JOIN DATAFRAMES IN ORDER TO HAVE SUFFICIENT DATA TO TRAIN MODEL

# %%
X_train= pd.concat([MSFT_98_train,MSFT_98_test,MSFT_02_train,MSFT_02_test,MSFT_06_train,MSFT_06_test,
               AAPL_98_train,AAPL_98_test,AAPL_02_train,AAPL_02_test,AAPL_06_train,AAPL_06_test,
                AMZN_98_train,AMZN_98_test,AMZN_02_train,AMZN_02_test,AMZN_06_train,AMZN_06_test])

# %%
X_train.shape
# Out:
# (609, 361)

# %%
#assign the training labels to y_train
y_train = X_train.Label
y_train_df = pd.DataFrame(y_train)
#drop the labels from the X_train dataframe
X_train = X_train.drop("Label", axis=1)

export_X_train = X_train.to_csv("/Users/fahad/project_repo/data/final/X_train.csv")
export_y_train = y_train_df.to_csv("/Users/fahad/project_repo/data/final/y_train.csv")

# %%
def make_timeseries_classifier(sample_num,window_size, filter_length, nb_input_series=1, nb_outputs=1, nb_filter=16):
    """:Return: a Keras Model for predicting the next value in a timeseries given a fixed-size lookback window of previous values.
    The model can handle multiple input timeseries (`nb_input_series`) and multiple prediction targets (`nb_outputs`).
    :param int window_size: The number of previous timeseries values to use as input features.  Also called lag or lookback.
    :param int nb_input_series: The number of input timeseries; 1 for a single timeseries.
      The `X` input to ``fit()`` should be an array of shape ``(n_instances, window_size, nb_input_series)``; each instance is
      a 2D array of shape ``(window_size, nb_input_series)``.  For example, for `window_size` = 3 and `nb_input_series` = 1 (a
      single timeseries), one instance could be ``[[0], [1], [2]]``. See ``make_timeseries_instances()``.
    :param int nb_outputs: The output dimension, often equal to the number of inputs.
      For each input instance (array with shape ``(window_size, nb_input_series)``), the output is a vector of size `nb_outputs`,
      usually the value(s) predicted to come after the last value in that input instance, i.e., the next value
      in the sequence. The `y` input to ``fit()`` should be an array of shape ``(n_instances, nb_outputs)``.
    :param int filter_length: the size (along the `window_size` dimension) of the sliding window that gets convolved with
      each position along each instance. The difference between 1D and 2D convolution is that a 1D filter's "height" is fixed
      to the number of input timeseries (its "width" being `filter_length`), and it can only slide along the window
      dimension.  This is useful as generally the input timeseries have no spatial/ordinal relationship, so it's not
      meaningful to look for patterns that are invariant with respect to subsets of the timeseries.
    :param int nb_filter: The number of different filters to learn (roughly, input patterns to recognize).
    """
    model = Sequential((
        # The first conv layer learns `nb_filter` filters (aka kernels), each of size ``(filter_length, nb_input_series)``.
        # Its output will have shape (None, window_size - filter_length + 1, nb_filter), i.e., for each position in
        # the input timeseries, the activation of each filter at that position.
        Convolution1D(nb_filter=nb_filter, filter_length=filter_length, activation='relu', input_shape=(window_size,nb_input_series)),
        MaxPooling1D(),     # Downsample the output of convolution by 2X.
        Convolution1D(nb_filter=nb_filter, filter_length=filter_length, activation='relu'),
        MaxPooling1D(),
        Flatten(),
        Dense(nb_outputs, activation='sigmoid'),     # For binary classification, change the activation to 'sigmoid'
    ))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # To perform (binary) classification instead:
    # model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])
    
    return model

# %%
model_1 = make_timeseries_classifier(X_train.shape[0],X_train.shape[1],3)
# Out:
# /Users/fahad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(activation="relu", input_shape=(360, 1), filters=16, kernel_size=3)`
# WARNING: Logging before flag parsing goes to stderr.
# W0820 19:57:05.262503 4520363456 deprecation_wrapper.py:119] From /Users/fahad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# /Users/fahad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(activation="relu", filters=16, kernel_size=3)`
# W0820 19:57:05.279832 4520363456 deprecation_wrapper.py:119] From /Users/fahad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0820 19:57:05.284508 4520363456 deprecation_wrapper.py:119] From /Users/fahad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0820 19:57:05.307189 4520363456 deprecation_wrapper.py:119] From /Users/fahad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0820 19:57:05.353920 4520363456 deprecation_wrapper.py:119] From /Users/fahad/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0820 19:57:05.375517 4520363456 deprecation_wrapper.py:119] From /Users/fahad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0820 19:57:05.381068 4520363456 deprecation.py:323] From /Users/fahad/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model_1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 358, 16)           64
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 179, 16)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 177, 16)           784
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 88, 16)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1408)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1409
# =================================================================
# Total params: 2,257
# Trainable params: 2,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train.shape
y_train.shape
X_train = np.array(X_train)

# %%
X_train = X_train.reshape(609,360,1)

# %%
es = EarlyStopping(monitor='val_acc', mode='max', verbose=0, patience=150)
mc = ModelCheckpoint('1D_CNN_FE_98_11_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
cb_list = [es,mc]

# %%
history=model_1.fit(X_train, y_train,validation_split=0.10, epochs=1000,batch_size=1, verbose=1,
                    callbacks = cb_list)
# Out:
# W0820 19:57:05.764426 4520363456 deprecation_wrapper.py:119] From /Users/fahad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 548 samples, validate on 61 samples
# Epoch 1/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.6797 - acc: 0.5858 - val_loss: 0.5983 - val_acc: 0.6885
#
# Epoch 00001: val_acc improved from -inf to 0.68852, saving model to 1D_CNN_FE_98_11_model.h5
# Epoch 2/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.5997 - acc: 0.6934 - val_loss: 0.5872 - val_acc: 0.6721
#
# Epoch 00002: val_acc did not improve from 0.68852
# Epoch 3/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.5388 - acc: 0.7464 - val_loss: 0.5767 - val_acc: 0.6721
#
# Epoch 00003: val_acc did not improve from 0.68852
# Epoch 4/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.5044 - acc: 0.7354 - val_loss: 0.5933 - val_acc: 0.7049
#
# Epoch 00004: val_acc improved from 0.68852 to 0.70492, saving model to 1D_CNN_FE_98_11_model.h5
# Epoch 5/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.4774 - acc: 0.7774 - val_loss: 0.6041 - val_acc: 0.7049
#
# Epoch 00005: val_acc did not improve from 0.70492
# Epoch 6/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4542 - acc: 0.7883 - val_loss: 0.5842 - val_acc: 0.6721
#
# Epoch 00006: val_acc did not improve from 0.70492
# Epoch 7/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4370 - acc: 0.7810 - val_loss: 0.5981 - val_acc: 0.6885
#
# Epoch 00007: val_acc did not improve from 0.70492
# Epoch 8/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4243 - acc: 0.8139 - val_loss: 0.6416 - val_acc: 0.6885
#
# Epoch 00008: val_acc did not improve from 0.70492
# Epoch 9/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4163 - acc: 0.7938 - val_loss: 0.6018 - val_acc: 0.6885
#
# Epoch 00009: val_acc did not improve from 0.70492
# Epoch 10/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3997 - acc: 0.8084 - val_loss: 0.6128 - val_acc: 0.7541
#
# Epoch 00010: val_acc improved from 0.70492 to 0.75410, saving model to 1D_CNN_FE_98_11_model.h5
# Epoch 11/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3901 - acc: 0.8266 - val_loss: 0.5642 - val_acc: 0.6885
#
# Epoch 00011: val_acc did not improve from 0.75410
# Epoch 12/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3760 - acc: 0.8139 - val_loss: 0.6587 - val_acc: 0.7541
#
# Epoch 00012: val_acc did not improve from 0.75410
# Epoch 13/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3686 - acc: 0.8230 - val_loss: 0.6002 - val_acc: 0.7541
#
# Epoch 00013: val_acc did not improve from 0.75410
# Epoch 14/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3623 - acc: 0.8285 - val_loss: 0.5753 - val_acc: 0.7377
#
# Epoch 00014: val_acc did not improve from 0.75410
# Epoch 15/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3500 - acc: 0.8522 - val_loss: 0.6918 - val_acc: 0.6393
#
# Epoch 00015: val_acc did not improve from 0.75410
# Epoch 16/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3335 - acc: 0.8467 - val_loss: 0.5838 - val_acc: 0.7541
#
# Epoch 00016: val_acc did not improve from 0.75410
# Epoch 17/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3310 - acc: 0.8558 - val_loss: 0.6148 - val_acc: 0.7377
#
# Epoch 00017: val_acc did not improve from 0.75410
# Epoch 18/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3163 - acc: 0.8631 - val_loss: 0.6022 - val_acc: 0.7541
#
# Epoch 00018: val_acc did not improve from 0.75410
# Epoch 19/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3217 - acc: 0.8522 - val_loss: 0.6238 - val_acc: 0.7705
#
# Epoch 00019: val_acc improved from 0.75410 to 0.77049, saving model to 1D_CNN_FE_98_11_model.h5
# Epoch 20/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3136 - acc: 0.8704 - val_loss: 0.5929 - val_acc: 0.7541
#
# Epoch 00020: val_acc did not improve from 0.77049
# Epoch 21/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3044 - acc: 0.8595 - val_loss: 0.7360 - val_acc: 0.6230
#
# Epoch 00021: val_acc did not improve from 0.77049
# Epoch 22/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3160 - acc: 0.8540 - val_loss: 0.6935 - val_acc: 0.6721
#
# Epoch 00022: val_acc did not improve from 0.77049
# Epoch 23/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2992 - acc: 0.8759 - val_loss: 0.6273 - val_acc: 0.7377
#
# Epoch 00023: val_acc did not improve from 0.77049
# Epoch 24/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2911 - acc: 0.8777 - val_loss: 0.6081 - val_acc: 0.7869
#
# Epoch 00024: val_acc improved from 0.77049 to 0.78689, saving model to 1D_CNN_FE_98_11_model.h5
# Epoch 25/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2931 - acc: 0.8631 - val_loss: 0.6212 - val_acc: 0.7213
#
# Epoch 00025: val_acc did not improve from 0.78689
# Epoch 26/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2856 - acc: 0.8869 - val_loss: 0.6505 - val_acc: 0.7377
#
# Epoch 00026: val_acc did not improve from 0.78689
# Epoch 27/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2805 - acc: 0.8978 - val_loss: 0.6235 - val_acc: 0.7541
#
# Epoch 00027: val_acc did not improve from 0.78689
# Epoch 28/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2683 - acc: 0.8960 - val_loss: 0.6746 - val_acc: 0.7213
#
# Epoch 00028: val_acc did not improve from 0.78689
# Epoch 29/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2873 - acc: 0.8759 - val_loss: 0.6978 - val_acc: 0.7049
#
# Epoch 00029: val_acc did not improve from 0.78689
# Epoch 30/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2657 - acc: 0.9015 - val_loss: 0.6569 - val_acc: 0.7705
#
# Epoch 00030: val_acc did not improve from 0.78689
# Epoch 31/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.2674 - acc: 0.8923 - val_loss: 0.6457 - val_acc: 0.7869
#
# Epoch 00031: val_acc did not improve from 0.78689
# Epoch 32/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2537 - acc: 0.9033 - val_loss: 0.7128 - val_acc: 0.7869
#
# Epoch 00032: val_acc did not improve from 0.78689
# Epoch 33/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2721 - acc: 0.8832 - val_loss: 0.7041 - val_acc: 0.7869
#
# Epoch 00033: val_acc did not improve from 0.78689
# Epoch 34/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2453 - acc: 0.8960 - val_loss: 0.7143 - val_acc: 0.7541
#
# Epoch 00034: val_acc did not improve from 0.78689
# Epoch 35/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2414 - acc: 0.9051 - val_loss: 0.6975 - val_acc: 0.7705
#
# Epoch 00035: val_acc did not improve from 0.78689
# Epoch 36/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2367 - acc: 0.8996 - val_loss: 0.7218 - val_acc: 0.6557
#
# Epoch 00036: val_acc did not improve from 0.78689
# Epoch 37/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2354 - acc: 0.9106 - val_loss: 0.6628 - val_acc: 0.7705
#
# Epoch 00037: val_acc did not improve from 0.78689
# Epoch 38/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2379 - acc: 0.9033 - val_loss: 0.7349 - val_acc: 0.7377
#
# Epoch 00038: val_acc did not improve from 0.78689
# Epoch 39/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2302 - acc: 0.9088 - val_loss: 0.7197 - val_acc: 0.7541
#
# Epoch 00039: val_acc did not improve from 0.78689
# Epoch 40/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2387 - acc: 0.8978 - val_loss: 0.7230 - val_acc: 0.7705
#
# Epoch 00040: val_acc did not improve from 0.78689
# Epoch 41/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2215 - acc: 0.9106 - val_loss: 0.6969 - val_acc: 0.7869
#
# Epoch 00041: val_acc did not improve from 0.78689
# Epoch 42/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2048 - acc: 0.9197 - val_loss: 0.7992 - val_acc: 0.6721
#
# Epoch 00042: val_acc did not improve from 0.78689
# Epoch 43/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2185 - acc: 0.9161 - val_loss: 0.7476 - val_acc: 0.7213
# Epoch 00043: val_acc did not improve from 0.78689
# Epoch 44/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.2151 - acc: 0.9234 - val_loss: 0.7393 - val_acc: 0.7869
#
# Epoch 00044: val_acc did not improve from 0.78689
# Epoch 45/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.2147 - acc: 0.9270 - val_loss: 0.7754 - val_acc: 0.7869
#
# Epoch 00045: val_acc did not improve from 0.78689
# Epoch 46/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.2147 - acc: 0.9124 - val_loss: 0.9141 - val_acc: 0.6721
#
# Epoch 00046: val_acc did not improve from 0.78689
# Epoch 47/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.2090 - acc: 0.9161 - val_loss: 0.8359 - val_acc: 0.7377
#
# Epoch 00047: val_acc did not improve from 0.78689
# Epoch 48/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2021 - acc: 0.9142 - val_loss: 0.8577 - val_acc: 0.7213
#
# Epoch 00048: val_acc did not improve from 0.78689
# Epoch 49/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.2062 - acc: 0.9215 - val_loss: 0.7521 - val_acc: 0.7705
#
# Epoch 00049: val_acc did not improve from 0.78689
# Epoch 50/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1933 - acc: 0.9234 - val_loss: 0.8661 - val_acc: 0.7049
#
# Epoch 00050: val_acc did not improve from 0.78689
# Epoch 51/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2011 - acc: 0.9215 - val_loss: 0.9817 - val_acc: 0.6885
#
# Epoch 00051: val_acc did not improve from 0.78689
# Epoch 52/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1869 - acc: 0.9343 - val_loss: 0.8810 - val_acc: 0.7049
#
# Epoch 00052: val_acc did not improve from 0.78689
# Epoch 53/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1739 - acc: 0.9307 - val_loss: 0.9128 - val_acc: 0.7377
#
# Epoch 00053: val_acc did not improve from 0.78689
# Epoch 54/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1775 - acc: 0.9307 - val_loss: 0.9400 - val_acc: 0.6885
#
# Epoch 00054: val_acc did not improve from 0.78689
# Epoch 55/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1676 - acc: 0.9307 - val_loss: 0.9977 - val_acc: 0.7377
#
# Epoch 00055: val_acc did not improve from 0.78689
# Epoch 56/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1793 - acc: 0.9288 - val_loss: 1.1801 - val_acc: 0.6393
#
# Epoch 00056: val_acc did not improve from 0.78689
# Epoch 57/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1731 - acc: 0.9398 - val_loss: 0.9648 - val_acc: 0.7377
#
# Epoch 00057: val_acc did not improve from 0.78689
# Epoch 58/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1659 - acc: 0.9307 - val_loss: 0.9712 - val_acc: 0.7049
#
# Epoch 00058: val_acc did not improve from 0.78689
# Epoch 59/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1728 - acc: 0.9252 - val_loss: 0.9371 - val_acc: 0.7213
#
# Epoch 00059: val_acc did not improve from 0.78689
# Epoch 60/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1679 - acc: 0.9288 - val_loss: 0.9255 - val_acc: 0.7213
#
# Epoch 00060: val_acc did not improve from 0.78689
# Epoch 61/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1668 - acc: 0.9343 - val_loss: 1.1246 - val_acc: 0.6721
#
# Epoch 00061: val_acc did not improve from 0.78689
# Epoch 62/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1681 - acc: 0.9380 - val_loss: 0.8997 - val_acc: 0.7541
#
# Epoch 00062: val_acc did not improve from 0.78689
# Epoch 63/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1494 - acc: 0.9507 - val_loss: 0.9523 - val_acc: 0.7541
#
# Epoch 00063: val_acc did not improve from 0.78689
# Epoch 64/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1436 - acc: 0.9507 - val_loss: 0.9352 - val_acc: 0.7705
#
# Epoch 00064: val_acc did not improve from 0.78689
# Epoch 65/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1463 - acc: 0.9434 - val_loss: 0.9754 - val_acc: 0.7541
#
# Epoch 00065: val_acc did not improve from 0.78689
# Epoch 66/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1398 - acc: 0.9489 - val_loss: 0.9892 - val_acc: 0.7377
#
# Epoch 00066: val_acc did not improve from 0.78689
# Epoch 67/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1450 - acc: 0.9453 - val_loss: 1.0441 - val_acc: 0.6885
#
# Epoch 00067: val_acc did not improve from 0.78689
# Epoch 68/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1391 - acc: 0.9507 - val_loss: 1.1068 - val_acc: 0.7049
#
# Epoch 00068: val_acc did not improve from 0.78689
# Epoch 69/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1356 - acc: 0.9434 - val_loss: 1.0485 - val_acc: 0.6885
#
# Epoch 00069: val_acc did not improve from 0.78689
# Epoch 70/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1400 - acc: 0.9471 - val_loss: 1.0610 - val_acc: 0.7377
#
# Epoch 00070: val_acc did not improve from 0.78689
# Epoch 71/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1418 - acc: 0.9489 - val_loss: 1.0021 - val_acc: 0.7705
#
# Epoch 00071: val_acc did not improve from 0.78689
# Epoch 72/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1229 - acc: 0.9580 - val_loss: 1.0830 - val_acc: 0.7541
#
# Epoch 00072: val_acc did not improve from 0.78689
# Epoch 73/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1183 - acc: 0.9690 - val_loss: 1.0401 - val_acc: 0.7705
#
# Epoch 00073: val_acc did not improve from 0.78689
# Epoch 74/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.1285 - acc: 0.9544 - val_loss: 1.0899 - val_acc: 0.7377
#
# Epoch 00074: val_acc did not improve from 0.78689
# Epoch 75/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1116 - acc: 0.9507 - val_loss: 1.0091 - val_acc: 0.7705
#
# Epoch 00075: val_acc did not improve from 0.78689
# Epoch 76/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1251 - acc: 0.9562 - val_loss: 1.0311 - val_acc: 0.7377
#
# Epoch 00076: val_acc did not improve from 0.78689
# Epoch 77/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1083 - acc: 0.9599 - val_loss: 1.0292 - val_acc: 0.7705
#
# Epoch 00077: val_acc did not improve from 0.78689
# Epoch 78/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1035 - acc: 0.9635 - val_loss: 1.1137 - val_acc: 0.7541
#
# Epoch 00078: val_acc did not improve from 0.78689
# Epoch 79/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1131 - acc: 0.9599 - val_loss: 1.2726 - val_acc: 0.6885
#
# Epoch 00079: val_acc did not improve from 0.78689
# Epoch 80/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1069 - acc: 0.9690 - val_loss: 1.1500 - val_acc: 0.7049
#
# Epoch 00080: val_acc did not improve from 0.78689
# Epoch 81/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1125 - acc: 0.9599 - val_loss: 1.2555 - val_acc: 0.6885
#
# Epoch 00081: val_acc did not improve from 0.78689
# Epoch 82/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1178 - acc: 0.9544 - val_loss: 1.0458 - val_acc: 0.7541
#
# Epoch 00082: val_acc did not improve from 0.78689
# Epoch 83/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0966 - acc: 0.9653 - val_loss: 1.1401 - val_acc: 0.7377
#
# Epoch 00083: val_acc did not improve from 0.78689
# Epoch 84/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0913 - acc: 0.9690 - val_loss: 1.2066 - val_acc: 0.7541
#
# Epoch 00084: val_acc did not improve from 0.78689
# Epoch 85/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0954 - acc: 0.9672 - val_loss: 1.3816 - val_acc: 0.7049
#
# Epoch 00085: val_acc did not improve from 0.78689
# Epoch 86/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0940 - acc: 0.9708 - val_loss: 1.1220 - val_acc: 0.7541
#
# Epoch 00086: val_acc did not improve from 0.78689
# Epoch 87/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1015 - acc: 0.9653 - val_loss: 1.2124 - val_acc: 0.7213
#
# Epoch 00087: val_acc did not improve from 0.78689
# Epoch 88/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0799 - acc: 0.9763 - val_loss: 1.1969 - val_acc: 0.7213
#
# Epoch 00088: val_acc did not improve from 0.78689
# Epoch 89/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0948 - acc: 0.9653 - val_loss: 1.2983 - val_acc: 0.7049
#
# Epoch 00089: val_acc did not improve from 0.78689
# Epoch 90/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0795 - acc: 0.9726 - val_loss: 1.4247 - val_acc: 0.7213
#
# Epoch 00090: val_acc did not improve from 0.78689
# Epoch 91/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0708 - acc: 0.9781 - val_loss: 1.3755 - val_acc: 0.7049
#
# Epoch 00091: val_acc did not improve from 0.78689
# Epoch 92/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.0863 - acc: 0.9672 - val_loss: 1.3997 - val_acc: 0.7049
#
# Epoch 00092: val_acc did not improve from 0.78689
# Epoch 93/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0773 - acc: 0.9763 - val_loss: 1.4291 - val_acc: 0.7049
#
# Epoch 00093: val_acc did not improve from 0.78689
# Epoch 94/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0793 - acc: 0.9726 - val_loss: 1.6248 - val_acc: 0.7049
#
# Epoch 00094: val_acc did not improve from 0.78689
# Epoch 95/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0832 - acc: 0.9708 - val_loss: 1.5160 - val_acc: 0.7213
#
# Epoch 00095: val_acc did not improve from 0.78689
# Epoch 96/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0676 - acc: 0.9745 - val_loss: 1.3123 - val_acc: 0.6721
#
# Epoch 00096: val_acc did not improve from 0.78689
# Epoch 97/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0760 - acc: 0.9763 - val_loss: 1.3786 - val_acc: 0.7049
#
# Epoch 00097: val_acc did not improve from 0.78689
# Epoch 98/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0808 - acc: 0.9799 - val_loss: 1.4102 - val_acc: 0.7377
#
# Epoch 00098: val_acc did not improve from 0.78689
# Epoch 99/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0616 - acc: 0.9781 - val_loss: 1.3217 - val_acc: 0.7705
#
# Epoch 00099: val_acc did not improve from 0.78689
# Epoch 100/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0837 - acc: 0.9653 - val_loss: 1.3957 - val_acc: 0.7213
#
# Epoch 00100: val_acc did not improve from 0.78689
# Epoch 101/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0679 - acc: 0.9708 - val_loss: 1.3096 - val_acc: 0.7213
#
# Epoch 00101: val_acc did not improve from 0.78689
# Epoch 102/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0505 - acc: 0.9927 - val_loss: 1.4783 - val_acc: 0.7377
#
# Epoch 00102: val_acc did not improve from 0.78689
# Epoch 103/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0827 - acc: 0.9745 - val_loss: 1.3158 - val_acc: 0.7541
#
# Epoch 00103: val_acc did not improve from 0.78689
# Epoch 104/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0640 - acc: 0.9745 - val_loss: 1.4358 - val_acc: 0.7705
#
# Epoch 00104: val_acc did not improve from 0.78689
# Epoch 105/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0577 - acc: 0.9854 - val_loss: 1.5239 - val_acc: 0.7049
#
# Epoch 00105: val_acc did not improve from 0.78689
# Epoch 106/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0476 - acc: 0.9872 - val_loss: 1.5663 - val_acc: 0.7213
#
# Epoch 00106: val_acc did not improve from 0.78689
# Epoch 107/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0469 - acc: 0.9891 - val_loss: 1.5478 - val_acc: 0.6885
#
# Epoch 00107: val_acc did not improve from 0.78689
# Epoch 108/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.0563 - acc: 0.9781 - val_loss: 1.4935 - val_acc: 0.7377
#
# Epoch 00108: val_acc did not improve from 0.78689
# Epoch 109/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0525 - acc: 0.9799 - val_loss: 1.4059 - val_acc: 0.7705
#
# Epoch 00109: val_acc did not improve from 0.78689
# Epoch 110/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0491 - acc: 0.9927 - val_loss: 1.3915 - val_acc: 0.7377
#
# Epoch 00110: val_acc did not improve from 0.78689
# Epoch 111/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0657 - acc: 0.9745 - val_loss: 1.7507 - val_acc: 0.7213
#
# Epoch 00111: val_acc did not improve from 0.78689
# Epoch 112/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0596 - acc: 0.9818 - val_loss: 1.8355 - val_acc: 0.7377
#
# Epoch 00112: val_acc did not improve from 0.78689
# Epoch 113/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0753 - acc: 0.9745 - val_loss: 1.4216 - val_acc: 0.7541
#
# Epoch 00113: val_acc did not improve from 0.78689
# Epoch 114/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0348 - acc: 0.9945 - val_loss: 1.5396 - val_acc: 0.7213
#
# Epoch 00114: val_acc did not improve from 0.78689
# Epoch 115/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0453 - acc: 0.9818 - val_loss: 1.6607 - val_acc: 0.6885
#
# Epoch 00115: val_acc did not improve from 0.78689
# Epoch 116/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0407 - acc: 0.9891 - val_loss: 1.4978 - val_acc: 0.7705
#
# Epoch 00116: val_acc did not improve from 0.78689
# Epoch 117/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0405 - acc: 0.9891 - val_loss: 1.6386 - val_acc: 0.7377
#
# Epoch 00117: val_acc did not improve from 0.78689
# Epoch 118/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0427 - acc: 0.9909 - val_loss: 2.0455 - val_acc: 0.6885
#
# Epoch 00118: val_acc did not improve from 0.78689
# Epoch 119/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0484 - acc: 0.9872 - val_loss: 1.7212 - val_acc: 0.7213
#
# Epoch 00119: val_acc did not improve from 0.78689
# Epoch 120/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0429 - acc: 0.9854 - val_loss: 1.5576 - val_acc: 0.7213
#
# Epoch 00120: val_acc did not improve from 0.78689
# Epoch 121/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0360 - acc: 0.9927 - val_loss: 1.5324 - val_acc: 0.7541
#
# Epoch 00121: val_acc did not improve from 0.78689
# Epoch 122/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0269 - acc: 0.9964 - val_loss: 1.6305 - val_acc: 0.6885
#
# Epoch 00122: val_acc did not improve from 0.78689
# Epoch 123/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0476 - acc: 0.9872 - val_loss: 1.9890 - val_acc: 0.6885
#
# Epoch 00123: val_acc did not improve from 0.78689
# Epoch 124/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0285 - acc: 0.9927 - val_loss: 1.7347 - val_acc: 0.7213
#
# Epoch 00124: val_acc did not improve from 0.78689
# Epoch 125/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0379 - acc: 0.9909 - val_loss: 1.5733 - val_acc: 0.7213
#
# Epoch 00125: val_acc did not improve from 0.78689
# Epoch 126/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0288 - acc: 0.9909 - val_loss: 1.6870 - val_acc: 0.7541
#
# Epoch 00126: val_acc did not improve from 0.78689
# Epoch 127/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0237 - acc: 0.9982 - val_loss: 1.6645 - val_acc: 0.7213
#
# Epoch 00127: val_acc did not improve from 0.78689
# Epoch 128/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0261 - acc: 0.9945 - val_loss: 1.8169 - val_acc: 0.7213
#
# Epoch 00128: val_acc did not improve from 0.78689
# Epoch 129/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0534 - acc: 0.9854 - val_loss: 1.8925 - val_acc: 0.7213
#
# Epoch 00129: val_acc did not improve from 0.78689
# Epoch 130/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0260 - acc: 0.9964 - val_loss: 1.7315 - val_acc: 0.7213
#
# Epoch 00130: val_acc did not improve from 0.78689
# Epoch 131/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0230 - acc: 0.9964 - val_loss: 1.8091 - val_acc: 0.7377
#
# Epoch 00131: val_acc did not improve from 0.78689
# Epoch 132/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0238 - acc: 0.9927 - val_loss: 1.7946 - val_acc: 0.7377
#
# Epoch 00132: val_acc did not improve from 0.78689
# Epoch 133/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0218 - acc: 0.9964 - val_loss: 1.6278 - val_acc: 0.7377
#
# Epoch 00133: val_acc did not improve from 0.78689
# Epoch 134/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0396 - acc: 0.9909 - val_loss: 1.5787 - val_acc: 0.7213
#
# Epoch 00134: val_acc did not improve from 0.78689
# Epoch 135/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0460 - acc: 0.9854 - val_loss: 1.8802 - val_acc: 0.7377
#
# Epoch 00135: val_acc did not improve from 0.78689
# Epoch 136/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0229 - acc: 0.9982 - val_loss: 1.8853 - val_acc: 0.7213
#
# Epoch 00136: val_acc did not improve from 0.78689
# Epoch 137/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0177 - acc: 0.9945 - val_loss: 1.7647 - val_acc: 0.7541
#
# Epoch 00137: val_acc did not improve from 0.78689
# Epoch 138/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0120 - acc: 0.9982 - val_loss: 1.8627 - val_acc: 0.7049
#
# Epoch 00138: val_acc did not improve from 0.78689
# Epoch 139/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0565 - acc: 0.9891 - val_loss: 1.6099 - val_acc: 0.7541
#
# Epoch 00139: val_acc did not improve from 0.78689
# Epoch 140/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0301 - acc: 0.9909 - val_loss: 1.8484 - val_acc: 0.7377
#
# Epoch 00140: val_acc did not improve from 0.78689
# Epoch 141/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0288 - acc: 0.9891 - val_loss: 2.1417 - val_acc: 0.7049
#
# Epoch 00141: val_acc did not improve from 0.78689
# Epoch 142/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0117 - acc: 1.0000 - val_loss: 2.0329 - val_acc: 0.7049
#
# Epoch 00142: val_acc did not improve from 0.78689
# Epoch 143/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0143 - acc: 0.9964 - val_loss: 1.8262 - val_acc: 0.7377
#
# Epoch 00143: val_acc did not improve from 0.78689
# Epoch 144/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0486 - acc: 0.9854 - val_loss: 2.0288 - val_acc: 0.7049
#
# Epoch 00144: val_acc did not improve from 0.78689
# Epoch 145/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0111 - acc: 0.9982 - val_loss: 1.9045 - val_acc: 0.7705
#
# Epoch 00145: val_acc did not improve from 0.78689
# Epoch 146/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0187 - acc: 0.9945 - val_loss: 1.9100 - val_acc: 0.7541
#
# Epoch 00146: val_acc did not improve from 0.78689
# Epoch 147/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0141 - acc: 1.0000 - val_loss: 1.9523 - val_acc: 0.7213
#
# Epoch 00147: val_acc did not improve from 0.78689
# Epoch 148/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0199 - acc: 0.9927 - val_loss: 1.9030 - val_acc: 0.7705
#
# Epoch 00148: val_acc did not improve from 0.78689
# Epoch 149/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0247 - acc: 0.9964 - val_loss: 1.9484 - val_acc: 0.7541
#
# Epoch 00149: val_acc did not improve from 0.78689
# Epoch 150/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0078 - acc: 1.0000 - val_loss: 1.9492 - val_acc: 0.7541
#
# Epoch 00150: val_acc did not improve from 0.78689
# Epoch 151/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0102 - acc: 1.0000 - val_loss: 1.7648 - val_acc: 0.7377
#
# Epoch 00151: val_acc did not improve from 0.78689
# Epoch 152/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0378 - acc: 0.9872 - val_loss: 2.3467 - val_acc: 0.7049
#
# Epoch 00152: val_acc did not improve from 0.78689
# Epoch 153/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0201 - acc: 0.9964 - val_loss: 2.0414 - val_acc: 0.7541
#
# Epoch 00153: val_acc did not improve from 0.78689
# Epoch 154/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0431 - acc: 0.9836 - val_loss: 1.9590 - val_acc: 0.7377
#
# Epoch 00154: val_acc did not improve from 0.78689
# Epoch 155/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0092 - acc: 1.0000 - val_loss: 1.9996 - val_acc: 0.7541
#
# Epoch 00155: val_acc did not improve from 0.78689
# Epoch 156/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0063 - acc: 1.0000 - val_loss: 1.8750 - val_acc: 0.7705
#
# Epoch 00156: val_acc did not improve from 0.78689
# Epoch 157/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0077 - acc: 1.0000 - val_loss: 1.8910 - val_acc: 0.7377
#
# Epoch 00157: val_acc did not improve from 0.78689
# Epoch 158/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0343 - acc: 0.9891 - val_loss: 1.8530 - val_acc: 0.7541
#
# Epoch 00158: val_acc did not improve from 0.78689
# Epoch 159/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0089 - acc: 1.0000 - val_loss: 2.0824 - val_acc: 0.7049
#
# Epoch 00159: val_acc did not improve from 0.78689
# Epoch 160/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0060 - acc: 1.0000 - val_loss: 2.0261 - val_acc: 0.7377
#
# Epoch 00160: val_acc did not improve from 0.78689
# Epoch 161/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0092 - acc: 1.0000 - val_loss: 2.0276 - val_acc: 0.7541
#
# Epoch 00161: val_acc did not improve from 0.78689
# Epoch 162/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0537 - acc: 0.9836 - val_loss: 2.0328 - val_acc: 0.8033
#
# Epoch 00162: val_acc improved from 0.78689 to 0.80328, saving model to 1D_CNN_FE_98_11_model.h5
# Epoch 163/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0224 - acc: 0.9945 - val_loss: 1.8453 - val_acc: 0.7541
#
# Epoch 00163: val_acc did not improve from 0.80328
# Epoch 164/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0107 - acc: 0.9982 - val_loss: 1.8566 - val_acc: 0.7541
#
# Epoch 00164: val_acc did not improve from 0.80328
# Epoch 165/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0052 - acc: 1.0000 - val_loss: 1.8911 - val_acc: 0.7705
#
# Epoch 00165: val_acc did not improve from 0.80328
# Epoch 166/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0044 - acc: 1.0000 - val_loss: 1.9660 - val_acc: 0.7705
#
# Epoch 00166: val_acc did not improve from 0.80328
# Epoch 167/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0037 - acc: 1.0000 - val_loss: 1.9139 - val_acc: 0.7705
#
# Epoch 00167: val_acc did not improve from 0.80328
# Epoch 168/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0047 - acc: 1.0000 - val_loss: 2.1017 - val_acc: 0.7377
#
# Epoch 00168: val_acc did not improve from 0.80328
# Epoch 169/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0512 - acc: 0.9818 - val_loss: 2.1385 - val_acc: 0.7541
#
# Epoch 00169: val_acc did not improve from 0.80328
# Epoch 170/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0094 - acc: 1.0000 - val_loss: 2.1050 - val_acc: 0.7541
#
# Epoch 00170: val_acc did not improve from 0.80328
# Epoch 171/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0053 - acc: 1.0000 - val_loss: 2.1125 - val_acc: 0.7377
#
# Epoch 00171: val_acc did not improve from 0.80328
# Epoch 172/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0030 - acc: 1.0000 - val_loss: 2.1586 - val_acc: 0.7377
#
# Epoch 00172: val_acc did not improve from 0.80328
# Epoch 173/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.0032 - acc: 1.0000 - val_loss: 2.0935 - val_acc: 0.7377
#
# Epoch 00173: val_acc did not improve from 0.80328
# Epoch 174/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0129 - acc: 0.9964 - val_loss: 2.0778 - val_acc: 0.7213
#
# Epoch 00174: val_acc did not improve from 0.80328
# Epoch 175/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0637 - acc: 0.9781 - val_loss: 2.2935 - val_acc: 0.7213
# Epoch 00175: val_acc did not improve from 0.80328
# Epoch 176/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0171 - acc: 0.9945 - val_loss: 2.3241 - val_acc: 0.7377
#
# Epoch 00176: val_acc did not improve from 0.80328
# Epoch 177/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.0048 - acc: 1.0000 - val_loss: 2.3601 - val_acc: 0.7213
#
# Epoch 00177: val_acc did not improve from 0.80328
# Epoch 178/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0028 - acc: 1.0000 - val_loss: 2.2126 - val_acc: 0.7213
#
# Epoch 00178: val_acc did not improve from 0.80328
# Epoch 179/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0026 - acc: 1.0000 - val_loss: 2.2606 - val_acc: 0.7213
#
# Epoch 00179: val_acc did not improve from 0.80328
# Epoch 180/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0025 - acc: 1.0000 - val_loss: 2.2830 - val_acc: 0.7213
#
# Epoch 00180: val_acc did not improve from 0.80328
# Epoch 181/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0026 - acc: 1.0000 - val_loss: 2.2753 - val_acc: 0.7377
#
# Epoch 00181: val_acc did not improve from 0.80328
# Epoch 182/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0034 - acc: 1.0000 - val_loss: 2.1573 - val_acc: 0.7377
#
# Epoch 00182: val_acc did not improve from 0.80328
# Epoch 183/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0708 - acc: 0.9708 - val_loss: 2.1207 - val_acc: 0.7541
#
# Epoch 00183: val_acc did not improve from 0.80328
# Epoch 184/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0182 - acc: 0.9945 - val_loss: 2.2150 - val_acc: 0.7541
#
# Epoch 00184: val_acc did not improve from 0.80328
# Epoch 185/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0053 - acc: 0.9982 - val_loss: 2.0973 - val_acc: 0.7705
#
# Epoch 00185: val_acc did not improve from 0.80328
# Epoch 186/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0024 - acc: 1.0000 - val_loss: 2.2276 - val_acc: 0.7377
#
# Epoch 00186: val_acc did not improve from 0.80328
# Epoch 187/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0024 - acc: 1.0000 - val_loss: 2.1520 - val_acc: 0.7541
#
# Epoch 00187: val_acc did not improve from 0.80328
# Epoch 188/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0018 - acc: 1.0000 - val_loss: 2.1771 - val_acc: 0.7541
#
# Epoch 00188: val_acc did not improve from 0.80328
# Epoch 189/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0018 - acc: 1.0000 - val_loss: 2.2425 - val_acc: 0.7377
#
# Epoch 00189: val_acc did not improve from 0.80328
# Epoch 190/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 2.1572 - val_acc: 0.7541
#
# Epoch 00190: val_acc did not improve from 0.80328
# Epoch 191/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 2.1126 - val_acc: 0.7541
#
# Epoch 00191: val_acc did not improve from 0.80328
# Epoch 192/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1207 - acc: 0.9708 - val_loss: 2.8311 - val_acc: 0.6721
#
# Epoch 00192: val_acc did not improve from 0.80328
# Epoch 193/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.0288 - acc: 0.9909 - val_loss: 2.0232 - val_acc: 0.7705
#
# Epoch 00193: val_acc did not improve from 0.80328
# Epoch 194/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0069 - acc: 1.0000 - val_loss: 2.1451 - val_acc: 0.7705
#
# Epoch 00194: val_acc did not improve from 0.80328
# Epoch 195/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0029 - acc: 1.0000 - val_loss: 2.1778 - val_acc: 0.7705
#
# Epoch 00195: val_acc did not improve from 0.80328
# Epoch 196/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0023 - acc: 1.0000 - val_loss: 2.2726 - val_acc: 0.7377
#
# Epoch 00196: val_acc did not improve from 0.80328
# Epoch 197/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0021 - acc: 1.0000 - val_loss: 2.1755 - val_acc: 0.7705
#
# Epoch 00197: val_acc did not improve from 0.80328
# Epoch 198/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0018 - acc: 1.0000 - val_loss: 2.1023 - val_acc: 0.7541
#
# Epoch 00198: val_acc did not improve from 0.80328
# Epoch 199/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0034 - acc: 1.0000 - val_loss: 2.2554 - val_acc: 0.7377
#
# Epoch 00199: val_acc did not improve from 0.80328
# Epoch 200/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0815 - acc: 0.9836 - val_loss: 2.4205 - val_acc: 0.7541
#
# Epoch 00200: val_acc did not improve from 0.80328
# Epoch 201/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0589 - acc: 0.9799 - val_loss: 2.1905 - val_acc: 0.7541
#
# Epoch 00201: val_acc did not improve from 0.80328
# Epoch 202/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0026 - acc: 1.0000 - val_loss: 2.2383 - val_acc: 0.7541
#
# Epoch 00202: val_acc did not improve from 0.80328
# Epoch 203/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 2.1861 - val_acc: 0.7541
#
# Epoch 00203: val_acc did not improve from 0.80328
# Epoch 204/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0018 - acc: 1.0000 - val_loss: 2.1921 - val_acc: 0.7541
#
# Epoch 00204: val_acc did not improve from 0.80328
# Epoch 205/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 2.2460 - val_acc: 0.7541
#
# Epoch 00205: val_acc did not improve from 0.80328
# Epoch 206/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 2.2689 - val_acc: 0.7705
#
# Epoch 00206: val_acc did not improve from 0.80328
# Epoch 207/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 2.3303 - val_acc: 0.7377
#
# Epoch 00207: val_acc did not improve from 0.80328
# Epoch 208/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 2.3947 - val_acc: 0.7377
#
# Epoch 00208: val_acc did not improve from 0.80328
# Epoch 209/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 2.1480 - val_acc: 0.7377
#
# Epoch 00209: val_acc did not improve from 0.80328
# Epoch 210/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0431 - acc: 0.9945 - val_loss: 3.5680 - val_acc: 0.6393
#
# Epoch 00210: val_acc did not improve from 0.80328
# Epoch 211/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0581 - acc: 0.9891 - val_loss: 2.1281 - val_acc: 0.7705
#
# Epoch 00211: val_acc did not improve from 0.80328
# Epoch 212/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0023 - acc: 1.0000 - val_loss: 2.2059 - val_acc: 0.7541
#
# Epoch 00212: val_acc did not improve from 0.80328
# Epoch 213/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0016 - acc: 1.0000 - val_loss: 2.3010 - val_acc: 0.7541
#
# Epoch 00213: val_acc did not improve from 0.80328
# Epoch 214/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 2.2766 - val_acc: 0.7541
#
# Epoch 00214: val_acc did not improve from 0.80328
# Epoch 215/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 2.2729 - val_acc: 0.7541
#
# Epoch 00215: val_acc did not improve from 0.80328
# Epoch 216/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 2.3196 - val_acc: 0.7541
#
# Epoch 00216: val_acc did not improve from 0.80328
# Epoch 217/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0010 - acc: 1.0000 - val_loss: 2.3450 - val_acc: 0.7541
#
# Epoch 00217: val_acc did not improve from 0.80328
# Epoch 218/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 9.3059e-04 - acc: 1.0000 - val_loss: 2.3304 - val_acc: 0.7541
#
# Epoch 00218: val_acc did not improve from 0.80328
# Epoch 219/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 9.4099e-04 - acc: 1.0000 - val_loss: 2.4339 - val_acc: 0.7377
#
# Epoch 00219: val_acc did not improve from 0.80328
# Epoch 220/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0197 - acc: 0.9927 - val_loss: 2.1987 - val_acc: 0.7869
#
# Epoch 00220: val_acc did not improve from 0.80328
# Epoch 221/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0869 - acc: 0.9690 - val_loss: 2.8401 - val_acc: 0.7213
#
# Epoch 00221: val_acc did not improve from 0.80328
# Epoch 222/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0094 - acc: 0.9964 - val_loss: 2.2564 - val_acc: 0.7541
#
# Epoch 00222: val_acc did not improve from 0.80328
# Epoch 223/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 2.3886 - val_acc: 0.7213
#
# Epoch 00223: val_acc did not improve from 0.80328
# Epoch 224/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 2.3481 - val_acc: 0.7213
#
# Epoch 00224: val_acc did not improve from 0.80328
# Epoch 225/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.0010 - acc: 1.0000 - val_loss: 2.3302 - val_acc: 0.7213
#
# Epoch 00225: val_acc did not improve from 0.80328
# Epoch 226/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 9.1715e-04 - acc: 1.0000 - val_loss: 2.3815 - val_acc: 0.7377
#
# Epoch 00226: val_acc did not improve from 0.80328
# Epoch 227/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 8.4044e-04 - acc: 1.0000 - val_loss: 2.3532 - val_acc: 0.7377
#
# Epoch 00227: val_acc did not improve from 0.80328
# Epoch 228/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 8.2778e-04 - acc: 1.0000 - val_loss: 2.3938 - val_acc: 0.7377
#
# Epoch 00228: val_acc did not improve from 0.80328
# Epoch 229/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 7.7331e-04 - acc: 1.0000 - val_loss: 2.4306 - val_acc: 0.7377
#
# Epoch 00229: val_acc did not improve from 0.80328
# Epoch 230/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 7.5797e-04 - acc: 1.0000 - val_loss: 2.4376 - val_acc: 0.7377
#
# Epoch 00230: val_acc did not improve from 0.80328
# Epoch 231/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 7.5378e-04 - acc: 1.0000 - val_loss: 2.4676 - val_acc: 0.7377
#
# Epoch 00231: val_acc did not improve from 0.80328
# Epoch 232/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0577 - acc: 0.9818 - val_loss: 2.6091 - val_acc: 0.7541
#
# Epoch 00232: val_acc did not improve from 0.80328
# Epoch 233/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0413 - acc: 0.9872 - val_loss: 2.4606 - val_acc: 0.7213
#
# Epoch 00233: val_acc did not improve from 0.80328
# Epoch 234/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0036 - acc: 1.0000 - val_loss: 2.2802 - val_acc: 0.7213
#
# Epoch 00234: val_acc did not improve from 0.80328
# Epoch 235/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0023 - acc: 1.0000 - val_loss: 2.4731 - val_acc: 0.7213
#
# Epoch 00235: val_acc did not improve from 0.80328
# Epoch 236/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 2.4687 - val_acc: 0.7213
#
# Epoch 00236: val_acc did not improve from 0.80328
# Epoch 237/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 9.2019e-04 - acc: 1.0000 - val_loss: 2.5053 - val_acc: 0.7213
#
# Epoch 00237: val_acc did not improve from 0.80328
# Epoch 238/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 8.2563e-04 - acc: 1.0000 - val_loss: 2.4914 - val_acc: 0.7213
#
# Epoch 00238: val_acc did not improve from 0.80328
# Epoch 239/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 7.4364e-04 - acc: 1.0000 - val_loss: 2.4936 - val_acc: 0.7213
#
# Epoch 00239: val_acc did not improve from 0.80328
# Epoch 240/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 6.6534e-04 - acc: 1.0000 - val_loss: 2.5195 - val_acc: 0.7213
#
# Epoch 00240: val_acc did not improve from 0.80328
# Epoch 241/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 6.0432e-04 - acc: 1.0000 - val_loss: 2.5720 - val_acc: 0.7377
#
# Epoch 00241: val_acc did not improve from 0.80328
# Epoch 242/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 5.7804e-04 - acc: 1.0000 - val_loss: 2.4901 - val_acc: 0.7213
#
# Epoch 00242: val_acc did not improve from 0.80328
# Epoch 243/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 6.3250e-04 - acc: 1.0000 - val_loss: 2.5357 - val_acc: 0.7377
#
# Epoch 00243: val_acc did not improve from 0.80328
# Epoch 244/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 7.0148e-04 - acc: 1.0000 - val_loss: 2.4477 - val_acc: 0.7541
#
# Epoch 00244: val_acc did not improve from 0.80328
# Epoch 245/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0812 - acc: 0.9854 - val_loss: 2.2676 - val_acc: 0.7541
#
# Epoch 00245: val_acc did not improve from 0.80328
# Epoch 246/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0227 - acc: 0.9927 - val_loss: 2.7458 - val_acc: 0.7377
#
# Epoch 00246: val_acc did not improve from 0.80328
# Epoch 247/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0021 - acc: 1.0000 - val_loss: 2.7864 - val_acc: 0.7377
#
# Epoch 00247: val_acc did not improve from 0.80328
# Epoch 248/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 9.5691e-04 - acc: 1.0000 - val_loss: 2.6930 - val_acc: 0.7377
#
# Epoch 00248: val_acc did not improve from 0.80328
# Epoch 249/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 7.7915e-04 - acc: 1.0000 - val_loss: 2.7049 - val_acc: 0.7377
#
# Epoch 00249: val_acc did not improve from 0.80328
# Epoch 250/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 6.8324e-04 - acc: 1.0000 - val_loss: 2.6613 - val_acc: 0.7213
#
# Epoch 00250: val_acc did not improve from 0.80328
# Epoch 251/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 5.8886e-04 - acc: 1.0000 - val_loss: 2.6126 - val_acc: 0.7213
#
# Epoch 00251: val_acc did not improve from 0.80328
# Epoch 252/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 5.5726e-04 - acc: 1.0000 - val_loss: 2.6608 - val_acc: 0.7213
#
# Epoch 00252: val_acc did not improve from 0.80328
# Epoch 253/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 5.3106e-04 - acc: 1.0000 - val_loss: 2.5841 - val_acc: 0.7213
#
# Epoch 00253: val_acc did not improve from 0.80328
# Epoch 254/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 5.7466e-04 - acc: 1.0000 - val_loss: 2.6251 - val_acc: 0.7213
#
# Epoch 00254: val_acc did not improve from 0.80328
# Epoch 255/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 5.1174e-04 - acc: 1.0000 - val_loss: 2.7281 - val_acc: 0.7541
#
# Epoch 00255: val_acc did not improve from 0.80328
# Epoch 256/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0733 - acc: 0.9836 - val_loss: 2.2949 - val_acc: 0.7377
#
# Epoch 00256: val_acc did not improve from 0.80328
# Epoch 257/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0486 - acc: 0.9818 - val_loss: 2.2993 - val_acc: 0.7049
#
# Epoch 00257: val_acc did not improve from 0.80328
# Epoch 258/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 2.4142 - val_acc: 0.7049
#
# Epoch 00258: val_acc did not improve from 0.80328
# Epoch 259/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 9.7144e-04 - acc: 1.0000 - val_loss: 2.3574 - val_acc: 0.7049
#
# Epoch 00259: val_acc did not improve from 0.80328
# Epoch 260/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 7.8267e-04 - acc: 1.0000 - val_loss: 2.4432 - val_acc: 0.7049
#
# Epoch 00260: val_acc did not improve from 0.80328
# Epoch 261/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 6.5688e-04 - acc: 1.0000 - val_loss: 2.3991 - val_acc: 0.7213
#
# Epoch 00261: val_acc did not improve from 0.80328
# Epoch 262/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 5.9329e-04 - acc: 1.0000 - val_loss: 2.4620 - val_acc: 0.7049
#
# Epoch 00262: val_acc did not improve from 0.80328
# Epoch 263/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 5.2974e-04 - acc: 1.0000 - val_loss: 2.5390 - val_acc: 0.7049
#
# Epoch 00263: val_acc did not improve from 0.80328
# Epoch 264/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 5.0445e-04 - acc: 1.0000 - val_loss: 2.4815 - val_acc: 0.7213
#
# Epoch 00264: val_acc did not improve from 0.80328
# Epoch 265/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 4.2273e-04 - acc: 1.0000 - val_loss: 2.4735 - val_acc: 0.7213
#
# Epoch 00265: val_acc did not improve from 0.80328
# Epoch 266/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 4.2448e-04 - acc: 1.0000 - val_loss: 2.6021 - val_acc: 0.7377
#
# Epoch 00266: val_acc did not improve from 0.80328
# Epoch 267/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 4.4515e-04 - acc: 1.0000 - val_loss: 2.4990 - val_acc: 0.7213
#
# Epoch 00267: val_acc did not improve from 0.80328
# Epoch 268/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 4.1820e-04 - acc: 1.0000 - val_loss: 2.6560 - val_acc: 0.7377
#
# Epoch 00268: val_acc did not improve from 0.80328
# Epoch 269/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0726 - acc: 0.9836 - val_loss: 2.9008 - val_acc: 0.7213
#
# Epoch 00269: val_acc did not improve from 0.80328
# Epoch 270/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0307 - acc: 0.9927 - val_loss: 2.4468 - val_acc: 0.7541
#
# Epoch 00270: val_acc did not improve from 0.80328
# Epoch 271/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 2.6071 - val_acc: 0.7377
#
# Epoch 00271: val_acc did not improve from 0.80328
# Epoch 272/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 7.9760e-04 - acc: 1.0000 - val_loss: 2.6304 - val_acc: 0.7377
#
# Epoch 00272: val_acc did not improve from 0.80328
# Epoch 273/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 6.3176e-04 - acc: 1.0000 - val_loss: 2.6332 - val_acc: 0.7377
#
# Epoch 00273: val_acc did not improve from 0.80328
# Epoch 274/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 5.3570e-04 - acc: 1.0000 - val_loss: 2.6424 - val_acc: 0.7377
#
# Epoch 00274: val_acc did not improve from 0.80328
# Epoch 275/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 4.8041e-04 - acc: 1.0000 - val_loss: 2.6416 - val_acc: 0.7377
#
# Epoch 00275: val_acc did not improve from 0.80328
# Epoch 276/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 4.2952e-04 - acc: 1.0000 - val_loss: 2.6445 - val_acc: 0.7377
#
# Epoch 00276: val_acc did not improve from 0.80328
# Epoch 277/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 3.9186e-04 - acc: 1.0000 - val_loss: 2.6204 - val_acc: 0.7541
#
# Epoch 00277: val_acc did not improve from 0.80328
# Epoch 278/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 3.5654e-04 - acc: 1.0000 - val_loss: 2.6485 - val_acc: 0.7377
#
# Epoch 00278: val_acc did not improve from 0.80328
# Epoch 279/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 3.4576e-04 - acc: 1.0000 - val_loss: 2.6354 - val_acc: 0.7377
#
# Epoch 00279: val_acc did not improve from 0.80328
# Epoch 280/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 3.3927e-04 - acc: 1.0000 - val_loss: 2.6328 - val_acc: 0.7213
#
# Epoch 00280: val_acc did not improve from 0.80328
# Epoch 281/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 3.0764e-04 - acc: 1.0000 - val_loss: 2.7006 - val_acc: 0.7213
#
# Epoch 00281: val_acc did not improve from 0.80328
# Epoch 282/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 8.1981e-04 - acc: 1.0000 - val_loss: 2.6939 - val_acc: 0.7213
#
# Epoch 00282: val_acc did not improve from 0.80328
# Epoch 283/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1164 - acc: 0.9653 - val_loss: 2.5804 - val_acc: 0.7377
#
# Epoch 00283: val_acc did not improve from 0.80328
# Epoch 284/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0272 - acc: 0.9927 - val_loss: 2.6549 - val_acc: 0.7869
#
# Epoch 00284: val_acc did not improve from 0.80328
# Epoch 285/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0034 - acc: 0.9982 - val_loss: 2.4580 - val_acc: 0.7869
#
# Epoch 00285: val_acc did not improve from 0.80328
# Epoch 286/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0010 - acc: 1.0000 - val_loss: 2.6567 - val_acc: 0.7541
#
# Epoch 00286: val_acc did not improve from 0.80328
# Epoch 287/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 6.5363e-04 - acc: 1.0000 - val_loss: 2.5788 - val_acc: 0.7705
#
# Epoch 00287: val_acc did not improve from 0.80328
# Epoch 288/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 5.0651e-04 - acc: 1.0000 - val_loss: 2.5791 - val_acc: 0.7705
#
# Epoch 00288: val_acc did not improve from 0.80328
# Epoch 289/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 4.3239e-04 - acc: 1.0000 - val_loss: 2.6057 - val_acc: 0.7705
#
# Epoch 00289: val_acc did not improve from 0.80328
# Epoch 290/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 3.8977e-04 - acc: 1.0000 - val_loss: 2.5667 - val_acc: 0.7541
#
# Epoch 00290: val_acc did not improve from 0.80328
# Epoch 291/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 3.5719e-04 - acc: 1.0000 - val_loss: 2.6007 - val_acc: 0.7705
#
# Epoch 00291: val_acc did not improve from 0.80328
# Epoch 292/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 3.1932e-04 - acc: 1.0000 - val_loss: 2.6034 - val_acc: 0.7705
#
# Epoch 00292: val_acc did not improve from 0.80328
# Epoch 293/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 2.9529e-04 - acc: 1.0000 - val_loss: 2.5975 - val_acc: 0.7541
#
# Epoch 00293: val_acc did not improve from 0.80328
# Epoch 294/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 2.6637e-04 - acc: 1.0000 - val_loss: 2.5913 - val_acc: 0.7541
#
# Epoch 00294: val_acc did not improve from 0.80328
# Epoch 295/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 2.4397e-04 - acc: 1.0000 - val_loss: 2.6343 - val_acc: 0.7541
#
# Epoch 00295: val_acc did not improve from 0.80328
# Epoch 296/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 2.2729e-04 - acc: 1.0000 - val_loss: 2.6181 - val_acc: 0.7541
#
# Epoch 00296: val_acc did not improve from 0.80328
# Epoch 297/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 2.3150e-04 - acc: 1.0000 - val_loss: 2.7059 - val_acc: 0.7541
#
# Epoch 00297: val_acc did not improve from 0.80328
# Epoch 298/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0497 - acc: 0.9927 - val_loss: 2.8526 - val_acc: 0.7049
#
# Epoch 00298: val_acc did not improve from 0.80328
# Epoch 299/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1431 - acc: 0.9726 - val_loss: 2.0709 - val_acc: 0.7869
#
# Epoch 00299: val_acc did not improve from 0.80328
# Epoch 300/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0042 - acc: 0.9982 - val_loss: 2.3966 - val_acc: 0.7541
#
# Epoch 00300: val_acc did not improve from 0.80328
# Epoch 301/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 2.4210 - val_acc: 0.7541
#
# Epoch 00301: val_acc did not improve from 0.80328
# Epoch 302/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 7.1851e-04 - acc: 1.0000 - val_loss: 2.4318 - val_acc: 0.7541
#
# Epoch 00302: val_acc did not improve from 0.80328
# Epoch 303/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 5.7291e-04 - acc: 1.0000 - val_loss: 2.4678 - val_acc: 0.7541
#
# Epoch 00303: val_acc did not improve from 0.80328
# Epoch 304/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 4.9952e-04 - acc: 1.0000 - val_loss: 2.4597 - val_acc: 0.7541
#
# Epoch 00304: val_acc did not improve from 0.80328
# Epoch 305/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 4.1446e-04 - acc: 1.0000 - val_loss: 2.4487 - val_acc: 0.7541
#
# Epoch 00305: val_acc did not improve from 0.80328
# Epoch 306/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 3.7285e-04 - acc: 1.0000 - val_loss: 2.4921 - val_acc: 0.7377
#
# Epoch 00306: val_acc did not improve from 0.80328
# Epoch 307/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 3.4347e-04 - acc: 1.0000 - val_loss: 2.4947 - val_acc: 0.7377
#
# Epoch 00307: val_acc did not improve from 0.80328
# Epoch 308/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 3.0329e-04 - acc: 1.0000 - val_loss: 2.5430 - val_acc: 0.7377
#
# Epoch 00308: val_acc did not improve from 0.80328
# Epoch 309/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 2.8306e-04 - acc: 1.0000 - val_loss: 2.5650 - val_acc: 0.7377
#
# Epoch 00309: val_acc did not improve from 0.80328
# Epoch 310/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 2.5667e-04 - acc: 1.0000 - val_loss: 2.5076 - val_acc: 0.7377
#
# Epoch 00310: val_acc did not improve from 0.80328
# Epoch 311/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 2.6609e-04 - acc: 1.0000 - val_loss: 2.6539 - val_acc: 0.7705
#
# Epoch 00311: val_acc did not improve from 0.80328
# Epoch 312/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1095 - acc: 0.9763 - val_loss: 2.4083 - val_acc: 0.7541
#
# Epoch 00312: val_acc did not improve from 0.80328

# %%
plt.style.use('ggplot')

# %%
#plot the accuracy of the training set  and the validation set of the model
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 30}

plt.rc('font', **font)
axis_font = {'fontname':'Arial', 'size':'25'}

plt.figure(figsize=[20,20])
plt.plot(history.history['acc'], linewidth =4, color='red')
plt.plot(history.history['val_acc'], linewidth =4, color='green')
plt.ylabel('Accuracy', **axis_font, fontsize=50)
plt.xlabel('Epochs', **axis_font, fontsize=50)

plt.show()

# %%
#EXPORT THE X_train data as a dataframe so it can be used easily in the other classifiers
#export the y_train data labels for the same reason
export_X_train = X_train.to_csv("/Users/fahad/project_repo/data/final/X_train.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-66a9ec39b2a8> in <module>
#       1 #EXPORT THE X_train data as a dataframe so it can be used easily in the other classifiers
#       2 #export the y_train data labels for the same reason
# ----> 3 export_X_train = X_train.to_csv("/Users/fahad/project_repo/data/final/X_train.csv")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_csv'

# %%
from keras.utils.vis_utils import plot_model
plot_model(model_1, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
