# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
import csv
from pandas.tseries.offsets import MonthEnd
from datetime import datetime, timedelta, date
import requests
import json 
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
from sklearn.utils.multiclass import unique_labels

from scipy import stats
from IPython.display import display, HTML

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from sklearn.utils import resample


import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape
from keras.layers import Convolution1D, MaxPooling1D
from keras.utils import np_utils
import seaborn as sns

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
# Out:
# Using TensorFlow backend.

# %%
#### read in the flattened dataframes with the labels for the 98 to 2015 data
MSFT_df_98_to_15_df = pd.read_csv(r"/Users/fahad/project_repo/data/external/multiclass_MSFT_98_15.csv")
AAPL_df_98_to_15_df = pd.read_csv(r"/Users/fahad/project_repo/data/external/multiclass_AAPL_98_15.csv")
AMZN_df_98_to_15_df = pd.read_csv(r"/Users/fahad/project_repo/data/external/multiclass_AMZN_98_15.csv")

# %%
###read in the flattened dataframes with the labels for 2015 to 2019
MSFT_df_15_to_19_df = pd.read_csv(r"/Users/fahad/project_repo/data/external/multiclass_MSFT_15_19.csv")
AAPL_df_15_to_19_df = pd.read_csv(r"/Users/fahad/project_repo/data/external/multiclass_AAPL_15_19.csv")
AMZN_df_15_to_19_df = pd.read_csv(r"/Users/fahad/project_repo/data/external/multiclass_AMZN_15_19.csv")

# %%
#vertically stack the MSFT and AAPL dataframes on top of eachother
df = pd.concat([MSFT_df_98_to_15_df, AAPL_df_98_to_15_df], axis=0)
#vertically stack the MSFT&AAPL df and the AMZN dataframe ontop of eachother
df = pd.concat([df,AMZN_df_98_to_15_df],axis = 0)

df.Label.value_counts()
# #drop the dates column
# df = df.drop(['Unnamed: 0'], axis = 1)
# #store the labels as the y_train array object 
# y_train = df['Label']
# #drop the labels from the instances
# df = df.drop(['Label'], axis =1)
# #assign the remaining columns in the dataframe
# X_train = df
# Out:
# 1    228
# 0    155
# 2    125
# 3    104
# Name: Label, dtype: int64

# %%
df_2 = pd.concat([MSFT_df_15_to_19_df, AAPL_df_15_to_19_df], axis=0)
df_2 = pd.concat([df_2,AMZN_df_15_to_19_df],axis = 0)
dates = df_2['Unnamed: 0']

df_2 = df_2.drop(['Unnamed: 0'], axis = 1)

#get labels for the prediction data
y_test = df_2['Label']

#drop the labelss
df_2 = df_2.drop(['Label'], axis=1)

#X_test to predict the values
X_test = df_2

# %%
#prev 50 and 150
es = EarlyStopping(monitor='val_acc', mode='max', verbose=0, patience=100)
mc = ModelCheckpoint('1dconv_feature_engineered_model_chronological_multiclass.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
cb_list = [es,mc]

# %% [markdown]
# # X_Train

# %%
#list which will become the array of shape 
list_1 = list()
#transform each row into a (30,12) array append to the list
for index, row in df.iterrows():
    arr = np.array(row).reshape(30,12)
#     print (arr)
#     print (arr.shape)
    list_1.append(arr)

arr1 = np.asarray(list_1)

#arr1 is an array of all the arrays needed to utilise the 
X_train = arr1
    

X_train.shape
# Out:
# (612, 30, 12)

# %% [markdown]
# # X_test

# %%
list_2 = list()

for index, row in df_2.iterrows():
    arr_2 = np.array(row).reshape(30,12)
    list_2.append(arr_2)
    
arr2 = np.asarray(list_2)

X_test = arr2

X_test.shape
# Out:
# (150, 30, 12)

# %%
def make_timeseries_classifier(X_train, y_train, X_test, y_test):
    """:Return: a Keras Model for predicting the next value in a timeseries given a fixed-size lookback window of previous values.
    The model can handle multiple input timeseries (`nb_input_series`) and multiple prediction targets (`nb_outputs`).
    :param int window_size: The number of previous timeseries values to use as input features.  Also called lag or lookback.
    :param int nb_input_series: The number of input timeseries; 1 for a single timeseries.
      The `X` input to ``fit()`` should be an array of shape ``(n_instances, window_size, nb_input_series)``; each instance is
      a 2D array of shape ``(window_size, nb_input_series)``.  For example, for `window_size` = 3 and `nb_input_series` = 1 (a
      single timeseries), one instance could be ``[[0], [1], [2]]``. See ``make_timeseries_instances()``.
    :param int nb_outputs: The output dimension, often equal to the number of inputs.
      For each input instance (array with shape ``(window_size, nb_input_series)``), the output is a vector of size `nb_outputs`,
      usually the value(s) predicted to come after the last value in that input instance, i.e., the next value
      in the sequence. The `y` input to ``fit()`` should be an array of shape ``(n_instances, nb_outputs)``.
    :param int filter_length: the size (along the `window_size` dimension) of the sliding window that gets convolved with
      each position along each instance. The difference between 1D and 2D convolution is that a 1D filter's "height" is fixed
      to the number of input timeseries (its "width" being `filter_length`), and it can only slide along the window
      dimension.  This is useful as generally the input timeseries have no spatial/ordinal relationship, so it's not
      meaningful to look for patterns that are invariant with respect to subsets of the timeseries.
    :param int nb_filter: The number of different filters to learn (roughly, input patterns to recognize).
    """
    verbose, epochs, batch_size = 0, 10, 32
    
    #number of timesteps for each prediction is 30, number of features is 12, number of outputs is 1
    n_timesteps, n_features, n_outputs =30,12, 4
    
    model = Sequential()
    model.add(Convolution1D(filters=64, kernel_size=3, activation='relu',
    input_shape=(n_timesteps,n_features)))
    model.add(Convolution1D(filters=64, kernel_size=3, activation='relu')) 
    model.add(Dropout(0.5))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(4, activation='softmax')) 
    adam = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    model.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy']) # fit network
    
    return model

# %%
model_1 = make_timeseries_classifier(X_train, y_train, X_test, y_test)
verbose, epochs, batch_size = 0, 10, 32
model_1.summary()
print (model_1.inputs)

es = EarlyStopping(monitor='val_acc', mode='max', verbose=0, patience=75)
mc = ModelCheckpoint('1dconv_feature_engineered_model_chronological_multiclass.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
cb_list = [es,mc]
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_15 (Conv1D)           (None, 28, 64)            2368
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 26, 64)            12352
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 26, 64)            0
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 13, 64)            0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 832)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 100)               83300
# _________________________________________________________________
# dense_16 (Dense)             (None, 4)                 404
# =================================================================
# Total params: 98,424
# Trainable params: 98,424
# Non-trainable params: 0
# _________________________________________________________________
# [<tf.Tensor 'conv1d_15_input:0' shape=(?, 30, 12) dtype=float32>]

# %%
model_1.fit(X_train, y_train, batch_size=128,
          validation_split=0.10, epochs=400
            , verbose=1, callbacks = cb_list)
# Out:
# Train on 550 samples, validate on 62 samples
# Epoch 1/400
# 550/550 [==============================] - 1s 2ms/step - loss: 1.3853 - acc: 0.2709 - val_loss: 1.3323 - val_acc: 0.5323
#
# Epoch 00001: val_acc improved from -inf to 0.53226, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 2/400
# 550/550 [==============================] - 0s 128us/step - loss: 1.3617 - acc: 0.3473 - val_loss: 1.2886 - val_acc: 0.5323
#
# Epoch 00002: val_acc did not improve from 0.53226
# Epoch 3/400
# 550/550 [==============================] - 0s 117us/step - loss: 1.3538 - acc: 0.3545 - val_loss: 1.2628 - val_acc: 0.5323
#
# Epoch 00003: val_acc did not improve from 0.53226
# Epoch 4/400
# 550/550 [==============================] - 0s 106us/step - loss: 1.3515 - acc: 0.3545 - val_loss: 1.2575 - val_acc: 0.5323
#
# Epoch 00004: val_acc did not improve from 0.53226
# Epoch 5/400
# 550/550 [==============================] - 0s 102us/step - loss: 1.3487 - acc: 0.3545 - val_loss: 1.2632 - val_acc: 0.5323
#
# Epoch 00005: val_acc did not improve from 0.53226
# Epoch 6/400
# 550/550 [==============================] - 0s 109us/step - loss: 1.3415 - acc: 0.3545 - val_loss: 1.2730 - val_acc: 0.5323
#
# Epoch 00006: val_acc did not improve from 0.53226
# Epoch 7/400
# 550/550 [==============================] - 0s 98us/step - loss: 1.3332 - acc: 0.3564 - val_loss: 1.2812 - val_acc: 0.5323
#
# Epoch 00007: val_acc did not improve from 0.53226
# Epoch 8/400
# 550/550 [==============================] - 0s 82us/step - loss: 1.3311 - acc: 0.3600 - val_loss: 1.2862 - val_acc: 0.5323
#
# Epoch 00008: val_acc did not improve from 0.53226
# Epoch 9/400
# 550/550 [==============================] - 0s 77us/step - loss: 1.3230 - acc: 0.3727 - val_loss: 1.2859 - val_acc: 0.5323
#
# Epoch 00009: val_acc did not improve from 0.53226
# Epoch 10/400
# 550/550 [==============================] - 0s 82us/step - loss: 1.3202 - acc: 0.3655 - val_loss: 1.2810 - val_acc: 0.5323
#
# Epoch 00010: val_acc did not improve from 0.53226
# Epoch 11/400
# 550/550 [==============================] - 0s 82us/step - loss: 1.3127 - acc: 0.3636 - val_loss: 1.2716 - val_acc: 0.5323
#
# Epoch 00011: val_acc did not improve from 0.53226
# Epoch 12/400
# 550/550 [==============================] - 0s 83us/step - loss: 1.3032 - acc: 0.3636 - val_loss: 1.2596 - val_acc: 0.5323
#
# Epoch 00012: val_acc did not improve from 0.53226
# Epoch 13/400
# 550/550 [==============================] - 0s 82us/step - loss: 1.2983 - acc: 0.3764 - val_loss: 1.2495 - val_acc: 0.5323
#
# Epoch 00013: val_acc did not improve from 0.53226
# Epoch 14/400
# 550/550 [==============================] - 0s 85us/step - loss: 1.2836 - acc: 0.3800 - val_loss: 1.2433 - val_acc: 0.5000
#
# Epoch 00014: val_acc did not improve from 0.53226
# Epoch 15/400
# 550/550 [==============================] - 0s 78us/step - loss: 1.2857 - acc: 0.3909 - val_loss: 1.2437 - val_acc: 0.5161
#
# Epoch 00015: val_acc did not improve from 0.53226
# Epoch 16/400
# 550/550 [==============================] - 0s 82us/step - loss: 1.2837 - acc: 0.3945 - val_loss: 1.2498 - val_acc: 0.5161
#
# Epoch 00016: val_acc did not improve from 0.53226
# Epoch 17/400
# 550/550 [==============================] - 0s 85us/step - loss: 1.2659 - acc: 0.4218 - val_loss: 1.2556 - val_acc: 0.5161
#
# Epoch 00017: val_acc did not improve from 0.53226
# Epoch 18/400
# 550/550 [==============================] - 0s 103us/step - loss: 1.2495 - acc: 0.4455 - val_loss: 1.2576 - val_acc: 0.5161
#
# Epoch 00018: val_acc did not improve from 0.53226
# Epoch 19/400
# 550/550 [==============================] - 0s 96us/step - loss: 1.2516 - acc: 0.4364 - val_loss: 1.2547 - val_acc: 0.5161
#
# Epoch 00019: val_acc did not improve from 0.53226
# Epoch 20/400
# 550/550 [==============================] - 0s 98us/step - loss: 1.2341 - acc: 0.4236 - val_loss: 1.2473 - val_acc: 0.5161
#
# Epoch 00020: val_acc did not improve from 0.53226
# Epoch 21/400
# 550/550 [==============================] - 0s 89us/step - loss: 1.2250 - acc: 0.4400 - val_loss: 1.2401 - val_acc: 0.5161
#
# Epoch 00021: val_acc did not improve from 0.53226
# Epoch 22/400
# 550/550 [==============================] - 0s 74us/step - loss: 1.2233 - acc: 0.4382 - val_loss: 1.2367 - val_acc: 0.5000
#
# Epoch 00022: val_acc did not improve from 0.53226
# Epoch 23/400
# 550/550 [==============================] - 0s 77us/step - loss: 1.2108 - acc: 0.4582 - val_loss: 1.2363 - val_acc: 0.5323
#
# Epoch 00023: val_acc did not improve from 0.53226
# Epoch 24/400
# 550/550 [==============================] - 0s 82us/step - loss: 1.1897 - acc: 0.4709 - val_loss: 1.2407 - val_acc: 0.5161
#
# Epoch 00024: val_acc did not improve from 0.53226
# Epoch 25/400
# 550/550 [==============================] - 0s 94us/step - loss: 1.1942 - acc: 0.4709 - val_loss: 1.2488 - val_acc: 0.5323
#
# Epoch 00025: val_acc did not improve from 0.53226
# Epoch 26/400
# 550/550 [==============================] - 0s 71us/step - loss: 1.1721 - acc: 0.4709 - val_loss: 1.2488 - val_acc: 0.5323
#
# Epoch 00026: val_acc did not improve from 0.53226
# Epoch 27/400
# 550/550 [==============================] - 0s 77us/step - loss: 1.1746 - acc: 0.4564 - val_loss: 1.2431 - val_acc: 0.5323
#
# Epoch 00027: val_acc did not improve from 0.53226
# Epoch 28/400
# 550/550 [==============================] - 0s 81us/step - loss: 1.1720 - acc: 0.4836 - val_loss: 1.2400 - val_acc: 0.5323
#
# Epoch 00028: val_acc did not improve from 0.53226
# Epoch 29/400
# 550/550 [==============================] - 0s 80us/step - loss: 1.1554 - acc: 0.4782 - val_loss: 1.2408 - val_acc: 0.5161
#
# Epoch 00029: val_acc did not improve from 0.53226
# Epoch 30/400
# 550/550 [==============================] - 0s 68us/step - loss: 1.1433 - acc: 0.4982 - val_loss: 1.2447 - val_acc: 0.5161
#
# Epoch 00030: val_acc did not improve from 0.53226
# Epoch 31/400
# 550/550 [==============================] - 0s 70us/step - loss: 1.1402 - acc: 0.5127 - val_loss: 1.2507 - val_acc: 0.5000
#
# Epoch 00031: val_acc did not improve from 0.53226
# Epoch 32/400
# 550/550 [==============================] - 0s 77us/step - loss: 1.1403 - acc: 0.4873 - val_loss: 1.2488 - val_acc: 0.5000
#
# Epoch 00032: val_acc did not improve from 0.53226
# Epoch 33/400
# 550/550 [==============================] - 0s 80us/step - loss: 1.1237 - acc: 0.4945 - val_loss: 1.2381 - val_acc: 0.4839
#
# Epoch 00033: val_acc did not improve from 0.53226
# Epoch 34/400
# 550/550 [==============================] - 0s 68us/step - loss: 1.1197 - acc: 0.5073 - val_loss: 1.2375 - val_acc: 0.4839
#
# Epoch 00034: val_acc did not improve from 0.53226
# Epoch 35/400
# 550/550 [==============================] - 0s 69us/step - loss: 1.1120 - acc: 0.5091 - val_loss: 1.2390 - val_acc: 0.5161
#
# Epoch 00035: val_acc did not improve from 0.53226
# Epoch 36/400
# 550/550 [==============================] - 0s 87us/step - loss: 1.1088 - acc: 0.5091 - val_loss: 1.2261 - val_acc: 0.5161
#
# Epoch 00036: val_acc did not improve from 0.53226
# Epoch 37/400
# 550/550 [==============================] - 0s 96us/step - loss: 1.0825 - acc: 0.5327 - val_loss: 1.2214 - val_acc: 0.5161
#
# Epoch 00037: val_acc did not improve from 0.53226
# Epoch 38/400
# 550/550 [==============================] - 0s 89us/step - loss: 1.0754 - acc: 0.5473 - val_loss: 1.2226 - val_acc: 0.5161
#
# Epoch 00038: val_acc did not improve from 0.53226
# Epoch 39/400
# 550/550 [==============================] - 0s 82us/step - loss: 1.0766 - acc: 0.5382 - val_loss: 1.2201 - val_acc: 0.5161
#
# Epoch 00039: val_acc did not improve from 0.53226
# Epoch 40/400
# 550/550 [==============================] - 0s 83us/step - loss: 1.0703 - acc: 0.5436 - val_loss: 1.2311 - val_acc: 0.5161
#
# Epoch 00040: val_acc did not improve from 0.53226
# Epoch 41/400
# 550/550 [==============================] - 0s 82us/step - loss: 1.0583 - acc: 0.5400 - val_loss: 1.2349 - val_acc: 0.5161
#
# Epoch 00041: val_acc did not improve from 0.53226
# Epoch 42/400
# 550/550 [==============================] - 0s 80us/step - loss: 1.0617 - acc: 0.5345 - val_loss: 1.2126 - val_acc: 0.4839
#
# Epoch 00042: val_acc did not improve from 0.53226
# Epoch 43/400
# 550/550 [==============================] - 0s 78us/step - loss: 1.0547 - acc: 0.5582 - val_loss: 1.2158 - val_acc: 0.5161
#
# Epoch 00043: val_acc did not improve from 0.53226
# Epoch 44/400
# 550/550 [==============================] - 0s 80us/step - loss: 1.0449 - acc: 0.5709 - val_loss: 1.2107 - val_acc: 0.5161
# Epoch 00044: val_acc did not improve from 0.53226
# Epoch 45/400
# 550/550 [==============================] - 0s 78us/step - loss: 1.0274 - acc: 0.5436 - val_loss: 1.1965 - val_acc: 0.4677
#
# Epoch 00045: val_acc did not improve from 0.53226
# Epoch 46/400
# 550/550 [==============================] - 0s 61us/step - loss: 1.0495 - acc: 0.5509 - val_loss: 1.2262 - val_acc: 0.5000
#
# Epoch 00046: val_acc did not improve from 0.53226
# Epoch 47/400
# 550/550 [==============================] - 0s 60us/step - loss: 1.0127 - acc: 0.5782 - val_loss: 1.2201 - val_acc: 0.4839
#
# Epoch 00047: val_acc did not improve from 0.53226
# Epoch 48/400
# 550/550 [==============================] - 0s 71us/step - loss: 1.0034 - acc: 0.5582 - val_loss: 1.1874 - val_acc: 0.5000
#
# Epoch 00048: val_acc did not improve from 0.53226
# Epoch 49/400
# 550/550 [==============================] - 0s 72us/step - loss: 0.9900 - acc: 0.5982 - val_loss: 1.1769 - val_acc: 0.5000
#
# Epoch 00049: val_acc did not improve from 0.53226
# Epoch 50/400
# 550/550 [==============================] - 0s 73us/step - loss: 0.9841 - acc: 0.5782 - val_loss: 1.1953 - val_acc: 0.5000
#
# Epoch 00050: val_acc did not improve from 0.53226
# Epoch 51/400
# 550/550 [==============================] - 0s 71us/step - loss: 0.9885 - acc: 0.5855 - val_loss: 1.2001 - val_acc: 0.4839
#
# Epoch 00051: val_acc did not improve from 0.53226
# Epoch 52/400
# 550/550 [==============================] - 0s 70us/step - loss: 0.9654 - acc: 0.5945 - val_loss: 1.1961 - val_acc: 0.4677
#
# Epoch 00052: val_acc did not improve from 0.53226
# Epoch 53/400
# 550/550 [==============================] - 0s 74us/step - loss: 0.9812 - acc: 0.5818 - val_loss: 1.1964 - val_acc: 0.5000
#
# Epoch 00053: val_acc did not improve from 0.53226
# Epoch 54/400
# 550/550 [==============================] - 0s 67us/step - loss: 0.9702 - acc: 0.6218 - val_loss: 1.1736 - val_acc: 0.5000
#
# Epoch 00054: val_acc did not improve from 0.53226
# Epoch 55/400
# 550/550 [==============================] - 0s 72us/step - loss: 0.9622 - acc: 0.5982 - val_loss: 1.1647 - val_acc: 0.4839
#
# Epoch 00055: val_acc did not improve from 0.53226
# Epoch 56/400
# 550/550 [==============================] - 0s 72us/step - loss: 0.9524 - acc: 0.6145 - val_loss: 1.1965 - val_acc: 0.4839
#
# Epoch 00056: val_acc did not improve from 0.53226
# Epoch 57/400
# 550/550 [==============================] - 0s 77us/step - loss: 0.9504 - acc: 0.6109 - val_loss: 1.1888 - val_acc: 0.4677
#
# Epoch 00057: val_acc did not improve from 0.53226
# Epoch 58/400
# 550/550 [==============================] - 0s 72us/step - loss: 0.9565 - acc: 0.6000 - val_loss: 1.1777 - val_acc: 0.4677
#
# Epoch 00058: val_acc did not improve from 0.53226
# Epoch 59/400
# 550/550 [==============================] - 0s 70us/step - loss: 0.9524 - acc: 0.5818 - val_loss: 1.1780 - val_acc: 0.4839
#
# Epoch 00059: val_acc did not improve from 0.53226
# Epoch 60/400
# 550/550 [==============================] - 0s 72us/step - loss: 0.9385 - acc: 0.5909 - val_loss: 1.1664 - val_acc: 0.4839
#
# Epoch 00060: val_acc did not improve from 0.53226
# Epoch 61/400
# 550/550 [==============================] - 0s 70us/step - loss: 0.9253 - acc: 0.6164 - val_loss: 1.1730 - val_acc: 0.4839
#
# Epoch 00061: val_acc did not improve from 0.53226
# Epoch 62/400
# 550/550 [==============================] - 0s 69us/step - loss: 0.8871 - acc: 0.6364 - val_loss: 1.1811 - val_acc: 0.4677
#
# Epoch 00062: val_acc did not improve from 0.53226
# Epoch 63/400
# 550/550 [==============================] - 0s 72us/step - loss: 0.8903 - acc: 0.6255 - val_loss: 1.1637 - val_acc: 0.4677
#
# Epoch 00063: val_acc did not improve from 0.53226
# Epoch 64/400
# 550/550 [==============================] - 0s 72us/step - loss: 0.9068 - acc: 0.6164 - val_loss: 1.1861 - val_acc: 0.4677
#
# Epoch 00064: val_acc did not improve from 0.53226
# Epoch 65/400
# 550/550 [==============================] - 0s 73us/step - loss: 0.8950 - acc: 0.6345 - val_loss: 1.1776 - val_acc: 0.4677
#
# Epoch 00065: val_acc did not improve from 0.53226
# Epoch 66/400
# 550/550 [==============================] - 0s 66us/step - loss: 0.9095 - acc: 0.6218 - val_loss: 1.1719 - val_acc: 0.4677
#
# Epoch 00066: val_acc did not improve from 0.53226
# Epoch 67/400
# 550/550 [==============================] - 0s 79us/step - loss: 0.8871 - acc: 0.6182 - val_loss: 1.1876 - val_acc: 0.5161
#
# Epoch 00067: val_acc did not improve from 0.53226
# Epoch 68/400
# 550/550 [==============================] - 0s 71us/step - loss: 0.9071 - acc: 0.6182 - val_loss: 1.1682 - val_acc: 0.4839
#
# Epoch 00068: val_acc did not improve from 0.53226
# Epoch 69/400
# 550/550 [==============================] - 0s 71us/step - loss: 0.8670 - acc: 0.6582 - val_loss: 1.1656 - val_acc: 0.5000
#
# Epoch 00069: val_acc did not improve from 0.53226
# Epoch 70/400
# 550/550 [==============================] - 0s 69us/step - loss: 0.8728 - acc: 0.6418 - val_loss: 1.1904 - val_acc: 0.4839
#
# Epoch 00070: val_acc did not improve from 0.53226
# Epoch 71/400
# 550/550 [==============================] - 0s 63us/step - loss: 0.8727 - acc: 0.6182 - val_loss: 1.1822 - val_acc: 0.5000
#
# Epoch 00071: val_acc did not improve from 0.53226
# Epoch 72/400
# 550/550 [==============================] - 0s 72us/step - loss: 0.8586 - acc: 0.6545 - val_loss: 1.1677 - val_acc: 0.5000
#
# Epoch 00072: val_acc did not improve from 0.53226
# Epoch 73/400
# 550/550 [==============================] - 0s 64us/step - loss: 0.8693 - acc: 0.6309 - val_loss: 1.1748 - val_acc: 0.4677
#
# Epoch 00073: val_acc did not improve from 0.53226
# Epoch 74/400
# 550/550 [==============================] - 0s 61us/step - loss: 0.8366 - acc: 0.6764 - val_loss: 1.1762 - val_acc: 0.4839
#
# Epoch 00074: val_acc did not improve from 0.53226
# Epoch 75/400
# 550/550 [==============================] - 0s 60us/step - loss: 0.8449 - acc: 0.6582 - val_loss: 1.1773 - val_acc: 0.4677
#
# Epoch 00075: val_acc did not improve from 0.53226
# Epoch 76/400
# 550/550 [==============================] - 0s 70us/step - loss: 0.8418 - acc: 0.6691 - val_loss: 1.1811 - val_acc: 0.4839
#
# Epoch 00076: val_acc did not improve from 0.53226

# %%
saved_model = load_model('1dconv_feature_engineered_model_chronological_multiclass.h5')

# %%
predictions = saved_model.predict_classes(X_test,batch_size = X_test.shape[0], verbose=1)

from sklearn.metrics import accuracy_score
print ("saved model acc: %s" % accuracy_score(y_test, predictions))
# accuracy: (tp + tn) / (p + n)

# precision tp / (tp + fp)
precision = precision_score(
    y_test,
    predictions,
    average=None)


recall = recall_score(y_test,
                      predictions, 
                     average=None)
# Out:
# 150/150 [==============================] - 0s 2ms/step
# saved model acc: 0.38
# /Users/fahad/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
