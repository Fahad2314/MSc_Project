# 2019-08-08                0.0               0.0  2019-08-08
# 2019-08-07                0.0               0.0  2019-08-07
# 2019-08-06                0.0               0.0  2019-08-06
# 2019-08-05                0.0               0.0  2019-08-05
# 2019-08-02                0.0               0.0  2019-08-02
# 2019-08-01                0.0               0.0  2019-08-01
# 2019-07-31                0.0               0.0  2019-07-31
# 2019-07-30                0.0               0.0  2019-07-30
# 2019-07-29                0.0               0.0  2019-07-29
# 2019-07-26                0.0               0.0  2019-07-26
# 2019-07-25                0.0               0.0  2019-07-25
# 2019-07-24                0.0               0.0  2019-07-24
# 2019-07-23                0.0               0.0  2019-07-23
# 2019-07-22                0.0               0.0  2019-07-22
# 2019-07-19                0.0               0.0  2019-07-19
# 2019-07-18                0.0               0.0  2019-07-18
# 2019-07-17                0.0               0.0  2019-07-17
# 2019-07-16                0.0               0.0  2019-07-16
# 2019-07-15                0.0               0.0  2019-07-15
# 2019-07-12                0.0               0.0  2019-07-12
# 2019-07-11                0.0               0.0  2019-07-11
# 2019-07-10                0.0               0.0  2019-07-10
# 2019-07-09                0.0               0.0  2019-07-09
# 2019-07-08                0.0               0.0  2019-07-08
# 2019-07-05                0.0               0.0  2019-07-05
# ...                       ...               ...         ...
# 2012-06-29                0.0               0.0  2012-06-29
# 2012-06-28                0.0               0.0  2012-06-28
# 2012-06-27                0.0               0.0  2012-06-27
# 2012-06-26                0.0               0.0  2012-06-26
# 2012-06-25                0.0               0.0  2012-06-25
# 2012-06-22                0.0               0.0  2012-06-22
# 2012-06-21                0.0               0.0  2012-06-21
# 2012-06-20                0.0               0.0  2012-06-20
# 2012-06-19                0.0               0.0  2012-06-19
# 2012-06-18                0.0               0.0  2012-06-18
# 2012-06-15                0.0               1.0  2012-06-15
# 2012-06-14                0.0               1.0  2012-06-14
# 2012-06-13                0.0               1.0  2012-06-13
# 2012-06-12                0.0               1.0  2012-06-12
# 2012-06-11                0.0               1.0  2012-06-11
# 2012-06-08                0.0               0.0  2012-06-08
# 2012-06-07                0.0               0.0  2012-06-07
# 2012-06-06                0.0               0.0  2012-06-06
# 2012-06-05                0.0               0.0  2012-06-05
# 2012-06-04                0.0               0.0  2012-06-04
# 2012-06-01                0.0               0.0  2012-06-01
# 2012-05-31                0.0               0.0  2012-05-31
# 2012-05-30                0.0               0.0  2012-05-30
# 2012-05-29                0.0               0.0  2012-05-29
# 2012-05-25                0.0               0.0  2012-05-25
# 2012-05-24                0.0               0.0  2012-05-24
# 2012-05-23                0.0               0.0  2012-05-23
# 2012-05-22                0.0               0.0  2012-05-22
# 2012-05-21                1.0               0.0  2012-05-21
# 2012-05-18                1.0               0.0  2012-05-18
#
# [1822 rows x 13 columns]

# %%
FB_2012 = pd.read_csv("/Users/fahad/project_repo/data/final/FB/2012_FB.csv", index_col=0)
FB_2015 = pd.read_csv("/Users/fahad/project_repo/data/final/FB/2014_FB.csv", index_col=0)

# %%
FB_2012.head(1)
# Out:
#               Open   High    Low   Close     Volume        Date
# 2012-06-29  28.892  33.45  25.52  31.095  667910500  2012-06-29

# %%
#ADD LABELS TO THE TRAINING AND TEST DATAFRAMES AND RETURN DICTIONARIES WITH DATE:LABEL FORMAT
FB_2012_labels = labelling(FB_2012)
FB_2015_labels = labelling(FB_2015)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1c1b0957ba49> in <module>
#       1 #ADD LABELS TO THE TRAINING AND TEST DATAFRAMES AND RETURN DICTIONARIES WITH DATE:LABEL FORMAT
# ----> 2 FB_2012_labels = labelling(FB_2012)
#       3 FB_2015_labels = labelling(FB_2015)
#
# NameError: name 'labelling' is not defined

# %%
FB_2012_flattened= get_ndays_monthly_flattened(FB_2012,FB_df,30)
FB_2015_flattened= get_ndays_monthly_flattened(FB_2015,FB_df,30)

# %%
FB_2012_labels_df = pd.Series(FB_2012_labels).to_frame("Label")
FB_2015_labels_df = pd.Series(FB_2015_labels).to_frame("Label")

# %%
#CREATE DATAFRAME FROM FLATTENED DICTIONARY OF ARRAYS FOR TRAINING AND TEST DATA
FB_2012_flat_df = pd.DataFrame.from_dict(FB_2012_flattened).T
FB_2015_flat_df = pd.DataFrame.from_dict(FB_2015_flattened).T

# %%
#JOIN THE LABEL DATAFRAME AND THE FLATTENED DATAFRAME ON THE INDEX WHICH IS THE DATE
FB_2012_flat_df = FB_2012_flat_df.merge(FB_2012_labels_df, left_index=True, right_index=True)

FB_2015_flat_df  = FB_2015_flat_df.merge(FB_2015_labels_df, left_index=True, right_index=True)

# %%
X_test = X_test.reset_index(drop=True)
X_test = X_test.drop('index', axis=1)

# %%
y_test_df = pd.DataFrame(y_test)

# %%
X_test.head(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-aa79807fd330> in <module>
# ----> 1 X_test.head(1)
#
# NameError: name 'X_test' is not defined

# %%
X_test_2 = FB_2015_flat_df.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e0bcabe1516f> in <module>
# ----> 1 X_test_2 = FB_2015_flat_df.reset_index(drop=True)
#
# NameError: name 'FB_2015_flat_df' is not defined

# %%
y_test_2_df = pd.DataFrame(X_test_2.Label_x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3c4d1e119639> in <module>
# ----> 1 y_test_2_df = pd.DataFrame(X_test_2.Label_x)
#
# NameError: name 'X_test_2' is not defined

# %%
X_test_2 = X_test_2.drop(["Label_x","Label_y"], axis=1)

# %%
X_test_2.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.222835  0.220764  0.218127  0.217003  0.254140  0.346891  0.287105
# 1  0.259380  0.258248  0.260878  0.256349  0.062961  0.599229  0.334742
# 2  0.218888  0.218018  0.212408  0.211647  0.107703  0.577066  0.433996
# 3  0.192314  0.199701  0.194642  0.202337  0.122685  0.465111  0.442831
# 4  0.231538  0.229748  0.233632  0.230769  0.064804  0.560146  0.412797
#
#         7         8         9    ...       350       351       352       353  \
# 0  0.259087  0.239886  0.220645  ...  0.186509  0.185868  0.128312  0.464233
# 1  0.217617  0.222880  0.261433  ...  0.201924  0.199584  0.048885  0.530564
# 2  0.221111  0.232800  0.335477  ...  0.249949  0.247088  0.054225  0.455502
# 3  0.247112  0.271234  0.218442  ...  0.257981  0.257600  0.061505  0.872144
# 4  0.261949  0.276898  0.124292  ...  0.204301  0.210196  0.128352  0.562566
#
#         354       355       356       357  358  359
# 0  0.419722  0.220317  0.232077  0.193444  0.0  0.0
# 1  0.403107  0.261564  0.239886  0.229557  0.0  0.0
# 2  0.296517  0.226407  0.227770  0.235759  0.0  0.0
# 3  0.550049  0.218073  0.228354  0.327441  0.0  0.0
# 4  0.444748  0.239134  0.261203  0.267126  0.0  0.0
#
# [5 rows x 360 columns]

# %%
export_Xtest = X_test.to_csv("/Users/fahad/project_repo/data/final/FB/2012_FB_X_test.csv")
export_y_test = y_test_df.to_csv("/Users/fahad/project_repo/data/final/FB/2012_FB_y_test.csv")
export_X_test_2 = X_test_2.to_csv("/Users/fahad/project_repo/data/final/FB/2015_FB_X_test.csv")
export_y_test_2 = y_test_2_df.to_csv("/Users/fahad/project_repo/data/final/FB/2015_FB_y_test.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-40616c531d8a> in <module>
# ----> 1 export_Xtest = X_test.to_csv("/Users/fahad/project_repo/data/final/FB/2012_FB_X_test.csv")
#       2 export_y_test = y_test_df.to_csv("/Users/fahad/project_repo/data/final/FB/2012_FB_y_test.csv")
#       3 export_X_test_2 = X_test_2.to_csv("/Users/fahad/project_repo/data/final/FB/2015_FB_X_test.csv")
#       4 export_y_test_2 = y_test_2_df.to_csv("/Users/fahad/project_repo/data/final/FB/2015_FB_y_test.csv")
#
# NameError: name 'X_test' is not defined

# %%
def labelling(dataframe):
    """This generates labels for the dataframes we wish to predict price.
    A label of 1 suggests an increase in price between months while a label of 0 indicates
    a decrease in price. If the current price is greater than the previous price then a"""
    empty_dict = dict()
    prev_close =0
    counter = 0
    for index,cols in dataframe.iterrows():
        counter +=1
        current_close = cols['Close']
        if float(prev_close) <= float(current_close):
            #signals an increase in price between last month and next month
            empty_dict[index] = 1
        elif float(prev_close) >= float(current_close):
            empty_dict[index]=0

        #reassign prev close to the current close     
        prev_close = current_close
    
    return empty_dict

# %%
def get_ndays_monthly_flattened(dataframe_period_end,dataframe_subperiod,n):
    """returns a dictionary which contains key value pair of the month-end date as key and
    value is the proceeding n days. Returns it as a dictionary of dataframes.
    dataframe period end refers to the dataframe which will act as the period end i.e monthly end date
    sub_period dataframe refers to the dataframe with the preceeding n days, i.e daily"""
    empty_dict = dict()
    count = 0
    for end in dataframe_period_end.index:
#         print ("month end/:%s" % end)
        
        month_key = dataframe_period_end.index[count+1]
        
#         print ("month key:%s" % month_key)
        
        last_index = dataframe_period_end.index[-1]
        
#         print ("last index:%s " % last_index)
        
        if (month_key != last_index):
            temp_df = dataframe_subperiod.loc[dataframe_subperiod['Date']<end].head(n)
#             print ("\n")
#             print (temp_df.head(5))
            temp_df = temp_df.drop(['Date'], axis=1)
            
            if (len(temp_df.values.flatten())==360):
                empty_dict[month_key]= temp_df.values.flatten()
                count +=1      
            else:
                pass

        else:
            pass
       
    return empty_dict
