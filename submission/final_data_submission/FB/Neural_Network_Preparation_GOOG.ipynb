# 2019-07-15                0.0               0.0  2019-07-15
# 2019-07-12                0.0               0.0  2019-07-12
# 2019-07-11                0.0               0.0  2019-07-11
# 2019-07-10                0.0               0.0  2019-07-10
# 2019-07-09                0.0               0.0  2019-07-09
# 2019-07-08                0.0               0.0  2019-07-08
# 2019-07-05                0.0               0.0  2019-07-05
# ...                       ...               ...         ...
# 2004-09-30                0.0               0.0  2004-09-30
# 2004-09-29                0.0               0.0  2004-09-29
# 2004-09-28                0.0               0.0  2004-09-28
# 2004-09-27                0.0               0.0  2004-09-27
# 2004-09-24                0.0               0.0  2004-09-24
# 2004-09-23                0.0               0.0  2004-09-23
# 2004-09-22                0.0               0.0  2004-09-22
# 2004-09-21                0.0               0.0  2004-09-21
# 2004-09-20                0.0               0.0  2004-09-20
# 2004-09-17                0.0               0.0  2004-09-17
# 2004-09-16                0.0               0.0  2004-09-16
# 2004-09-15                0.0               0.0  2004-09-15
# 2004-09-14                0.0               0.0  2004-09-14
# 2004-09-13                0.0               0.0  2004-09-13
# 2004-09-10                0.0               0.0  2004-09-10
# 2004-09-09                0.0               0.0  2004-09-09
# 2004-09-08                0.0               0.0  2004-09-08
# 2004-09-07                0.0               0.0  2004-09-07
# 2004-09-03                0.0               0.0  2004-09-03
# 2004-09-02                0.0               0.0  2004-09-02
# 2004-09-01                0.0               0.0  2004-09-01
# 2004-08-31                0.0               0.0  2004-08-31
# 2004-08-30                0.0               0.0  2004-08-30
# 2004-08-27                0.0               0.0  2004-08-27
# 2004-08-26                0.0               0.0  2004-08-26
# 2004-08-25                0.0               0.0  2004-08-25
# 2004-08-24                0.0               0.0  2004-08-24
# 2004-08-23                0.0               0.0  2004-08-23
# 2004-08-20                0.0               0.0  2004-08-20
# 2004-08-19                0.0               0.0  2004-08-19
#
# [3774 rows x 13 columns]

# %%
GOOG_2006 = pd.read_csv("/Users/fahad/project_repo/data/final/GOOG/2006_GOOG.csv", index_col=0)
GOOG_2015 = pd.read_csv("/Users/fahad/project_repo/data/final/GOOG/2015_GOOG.csv", index_col=0)

# %%
#ADD LABELS TO THE TRAINING AND TEST DATAFRAMES AND RETURN DICTIONARIES WITH DATE:LABEL FORMAT
GOOG_2006_labels = labelling(GOOG_2006)
GOOG_2015_labels = labelling(GOOG_2015)

# %%
GOOG_2006_flattened= get_ndays_monthly_flattened(GOOG_2006,GOOG_df,30)
GOOG_2015_flattened= get_ndays_monthly_flattened(GOOG_2015,GOOG_df,30)

# %%
GOOG_2006_labels_df = pd.Series(GOOG_2006_labels).to_frame("Label")
GOOG_2015_labels_df = pd.Series(GOOG_2015_labels).to_frame("Label")

# %%
#CREATE DATAFRAME FROM FLATTENED DICTIONARY OF ARRAYS FOR TRAINING AND TEST DATA
GOOG_2006_flat_df = pd.DataFrame.from_dict(GOOG_2006_flattened).T
GOOG_2015_flat_df = pd.DataFrame.from_dict(GOOG_2015_flattened).T

# %%
#JOIN THE LABEL DATAFRAME AND THE FLATTENED DATAFRAME ON THE INDEX WHICH IS THE DATE
GOOG_2006_flat_df = GOOG_2006_flat_df.merge(GOOG_2006_labels_df, left_index=True, right_index=True)

GOOG_2015_flat_df  = GOOG_2015_flat_df.merge(GOOG_2015_labels_df, left_index=True, right_index=True)

# %%
y_test_1 = GOOG_2006_flat_df.Label

X_test_1 = GOOG_2006_flat_df.reset_index(drop=True)

# %%
X_test_1 = X_test_1.drop("Label", axis=1)

# %%
y_test_df = pd.DataFrame(y_test_1)

# %%
y_test_2 = GOOG_2015_flat_df.Label

X_test_2 = GOOG_2015_flat_df.reset_index(drop=True)

X_test_2 = X_test_2.drop("Label", axis=1)

# %%
y_test_2_df = pd.DataFrame(y_test_2)

# %%
X_test_1.head(1)
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.134252  0.133338  0.134515  0.131524  0.208814  0.865392  0.600195
#
#         7         8         9    ...      350       351       352       353  \
# 0  0.092773  0.102143  0.153339  ...  0.13104  0.129805  0.146957  0.448294
#
#         354       355       356       357  358  359
# 0  0.405223  0.111678  0.102916  0.120989  0.0  0.0
#
# [1 rows x 360 columns]

# %%
y_test_df.head(1)
# Out:
#             Label
# 2006-02-28      0

# %%
X_test_2.head(1)
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.376934  0.371728  0.372098  0.372319  0.050627  0.311516  0.410325
#
#         7         8         9    ...       350       351       352       353  \
# 0  0.414796  0.415671  0.247322  ...  0.362086  0.359982  0.047936  0.267297
#
#         354       355       356       357  358  359
# 0  0.416489  0.393415  0.406913  0.234739  0.0  0.0
#
# [1 rows x 360 columns]

# %%
y_test_2_df.head(1)
# Out:
#             Label
# 2015-02-27      1

# %%
export_Xtest = X_test_1.to_csv("/Users/fahad/project_repo/data/final/GOOG/2006_GOOG_X_test.csv ")
export_y_test = y_test_df.to_csv("/Users/fahad/project_repo/data/final/GOOG/2006_GOOG_y_test.csv")
export_X_test_2 = X_test_2.to_csv("/Users/fahad/project_repo/data/final/GOOG/2015_GOOG_X_test.csv")
export_y_test_2 = y_test_2_df.to_csv("/Users/fahad/project_repo/data/final/GOOG/2015_GOOG_y_test.csv")

# %%
def labelling(dataframe):
    """This generates labels for the dataframes we wish to predict price.
    A label of 1 suggests an increase in price between months while a label of 0 indicates
    a decrease in price. If the current price is greater than the previous price then a"""
    empty_dict = dict()
    prev_close =0
    counter = 0
    for index,cols in dataframe.iterrows():
        counter +=1
        current_close = cols['Close']
        if float(prev_close) <= float(current_close):
            #signals an increase in price between last month and next month
            empty_dict[index] = 1
        elif float(prev_close) >= float(current_close):
            empty_dict[index]=0

        #reassign prev close to the current close     
        prev_close = current_close
    
    return empty_dict

# %%
def get_ndays_monthly_flattened(dataframe_period_end,dataframe_subperiod,n):
    """returns a dictionary which contains key value pair of the month-end date as key and
    value is the proceeding n days. Returns it as a dictionary of dataframes.
    dataframe period end refers to the dataframe which will act as the period end i.e monthly end date
    sub_period dataframe refers to the dataframe with the preceeding n days, i.e daily"""
    empty_dict = dict()
    count = 0
    for end in dataframe_period_end.index:
#         print ("month end/:%s" % end)
        
        month_key = dataframe_period_end.index[count+1]
        
#         print ("month key:%s" % month_key)
        
        last_index = dataframe_period_end.index[-1]
        
#         print ("last index:%s " % last_index)
        
        if (month_key != last_index):
            temp_df = dataframe_subperiod.loc[dataframe_subperiod['Date']<end].head(n)
#             print ("\n")
#             print (temp_df.head(5))
            temp_df = temp_df.drop(['Date'], axis=1)
            
            if (len(temp_df.values.flatten())==360):
                empty_dict[month_key]= temp_df.values.flatten()
                count +=1      
            else:
                pass

        else:
            pass
       
    return empty_dict
