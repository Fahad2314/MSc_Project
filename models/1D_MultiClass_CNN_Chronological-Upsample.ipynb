# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
import csv
from pandas.tseries.offsets import MonthEnd
from datetime import datetime, timedelta, date
import requests
import json 
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
from sklearn.utils.multiclass import unique_labels

from scipy import stats
from IPython.display import display, HTML

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from sklearn.utils import resample


import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape
from keras.layers import Convolution1D, MaxPooling1D
from keras.utils import np_utils
import seaborn as sns

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
# Out:
# Using TensorFlow backend.

# %%
#### read in the flattened dataframes with the labels for the 98 to 2015 data
MSFT_df_98_to_15_df = pd.read_csv(r"/Users/fahad/project_repo/data/external/multiclass_MSFT_98_15.csv")
AAPL_df_98_to_15_df = pd.read_csv(r"/Users/fahad/project_repo/data/external/multiclass_AAPL_98_15.csv")
AMZN_df_98_to_15_df = pd.read_csv(r"/Users/fahad/project_repo/data/external/multiclass_AMZN_98_15.csv")

# %%
###read in the flattened dataframes with the labels for 2015 to 2019
MSFT_df_15_to_19_df = pd.read_csv(r"/Users/fahad/project_repo/data/external/multiclass_MSFT_15_19.csv")
AAPL_df_15_to_19_df = pd.read_csv(r"/Users/fahad/project_repo/data/external/multiclass_AAPL_15_19.csv")
AMZN_df_15_to_19_df = pd.read_csv(r"/Users/fahad/project_repo/data/external/multiclass_AMZN_15_19.csv")

# %%
#vertically stack the MSFT and AAPL dataframes on top of eachother
df = pd.concat([MSFT_df_98_to_15_df, AAPL_df_98_to_15_df], axis=0)
#vertically stack the MSFT&AAPL df and the AMZN dataframe ontop of eachother
df = pd.concat([df,AMZN_df_98_to_15_df],axis = 0)

df = df.drop(['Unnamed: 0'], axis = 1)

y_train = df.Label
y_train = pd.DataFrame(y_train)
y_train
export_multiclass_labels = y_train.to_csv(r"y_train_multiclass_labels.csv")


#X_train = df.drop(['Label'], axis =1)


# df_upsampled = df.drop(['Label'], axis=1)

# df_upsampled

# # df

# X_train.shape



# #drop the dates column
# df = df.drop(['Unnamed: 0'], axis = 1)
# #store the labels as the y_train array object 
# y_train = df['Label']
# #drop the labels from the instances
# df = df.drop(['Label'], axis =1)
# #assign the remaining columns in the dataframe
# X_train = df

# %%
print (X_train.shape)
print (y_train.shape)
# Out:
# (912, 360)
# (912,)

# %%
df_2 = pd.concat([MSFT_df_15_to_19_df, AAPL_df_15_to_19_df], axis=0)
df_2 = pd.concat([df_2,AMZN_df_15_to_19_df],axis = 0)
dates = df_2['Unnamed: 0']

df_2 = df_2.drop(['Unnamed: 0'], axis = 1)

#get labels for the prediction data
y_test = df_2['Label']

#drop the labelss
df_2 = df_2.drop(['Label'], axis=1)

#X_test to predict the values
X_test = df_2

# %%
y_test = pd.DataFrame(y_test)

# %%
export_ytest = y_test.to_csv("y_test_multiclass.csv")

# %%
#prev 50 and 150
es = EarlyStopping(monitor='val_acc', mode='max', verbose=0, patience=200)
mc = ModelCheckpoint('1dconv_feature_engineered_model_chronological_multiclass.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
cb_list = [es,mc]

# %% [markdown]
# # X_Train

# %%
#list which will become the array of shape 
list_1 = list()
#transform each row into a (30,12) array append to the list
for index, row in X_train.iterrows():
    arr = np.array(row).reshape(30,12)
    list_1.append(arr)

    #print(arr)
#     print (arr)
#     print (arr.shape)
#     list_1.append(arr)

arr1 = np.asarray(list_1)

# #arr1 is an array of all the arrays needed to utilise the 
X_train = arr1
    

X_train.shape
# Out:
# (912, 30, 12)

# %% [markdown]
# # X_test

# %%
list_2 = list()

for index, row in df_2.iterrows():
    arr_2 = np.array(row).reshape(30,12)
    list_2.append(arr_2)
    
arr2 = np.asarray(list_2)

X_test = arr2

X_test.shape
# Out:
# (150, 30, 12)

# %%
def make_timeseries_classifier(X_train, y_train, X_test, y_test):

    
    verbose, epochs, batch_size = 0, 10, 32
    
    #number of timesteps for each prediction is 30, number of features is 12, number of outputs is 1
    n_timesteps, n_features, n_outputs =1,360, 4
    
    model = Sequential()
    model.add(Convolution1D(filters=64, kernel_size=3, activation='relu',
    input_shape=(n_timesteps,n_features)))
    model.add(Convolution1D(filters=64, kernel_size=3, activation='relu')) 
    model.add(Dropout(0.5))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(4, activation='softmax')) 
    adam = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    model.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy']) # fit network
    
    return model

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-931765772341> in <module>
# ----> 1 X_train
#
# NameError: name 'X_train' is not defined

# %%
model_1 = make_timeseries_classifier(X_train, y_train, X_test, y_test)
verbose, epochs, batch_size = 0, 10, 32
model_1.summary()
print (model_1.inputs)

es = EarlyStopping(monitor='val_acc', mode='max', verbose=0, patience=75)
mc = ModelCheckpoint('1dconv_feature_engineered_model_chronological_multiclass.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
cb_list = [es,mc]
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_5 (Conv1D)            (None, 28, 64)            2368
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 26, 64)            12352
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 26, 64)            0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 13, 64)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 832)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               83300
# _________________________________________________________________
# dense_6 (Dense)              (None, 4)                 404
# =================================================================
# Total params: 98,424
# Trainable params: 98,424
# Non-trainable params: 0
# _________________________________________________________________
# [<tf.Tensor 'conv1d_5_input:0' shape=(?, 30, 12) dtype=float32>]

# %%
model_1.fit(X_train, y_train, batch_size=128,
          validation_split=0.10, epochs=400
            , verbose=1, callbacks = cb_list)
# Out:
# W0810 16:25:37.983129 4753233344 deprecation.py:323] From /Users/fahad/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 820 samples, validate on 92 samples
# Epoch 1/400
# 820/820 [==============================] - 1s 750us/step - loss: 1.3969 - acc: 0.2512 - val_loss: 1.7257 - val_acc: 0.0000e+00
#
# Epoch 00001: val_acc improved from -inf to 0.00000, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 2/400
# 820/820 [==============================] - 0s 88us/step - loss: 1.3569 - acc: 0.3549 - val_loss: 1.6204 - val_acc: 0.0000e+00
#
# Epoch 00002: val_acc did not improve from 0.00000
# Epoch 3/400
# 820/820 [==============================] - 0s 86us/step - loss: 1.3391 - acc: 0.3902 - val_loss: 1.6333 - val_acc: 0.0000e+00
#
# Epoch 00003: val_acc did not improve from 0.00000
# Epoch 4/400
# 820/820 [==============================] - 0s 85us/step - loss: 1.3072 - acc: 0.4244 - val_loss: 1.6160 - val_acc: 0.0000e+00
#
# Epoch 00004: val_acc did not improve from 0.00000
# Epoch 5/400
# 820/820 [==============================] - 0s 88us/step - loss: 1.2717 - acc: 0.4463 - val_loss: 1.6480 - val_acc: 0.0217
#
# Epoch 00005: val_acc improved from 0.00000 to 0.02174, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 6/400
# 820/820 [==============================] - 0s 80us/step - loss: 1.2184 - acc: 0.4500 - val_loss: 1.6420 - val_acc: 0.0761
#
# Epoch 00006: val_acc improved from 0.02174 to 0.07609, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 7/400
# 820/820 [==============================] - 0s 91us/step - loss: 1.1810 - acc: 0.4793 - val_loss: 1.4522 - val_acc: 0.1630
#
# Epoch 00007: val_acc improved from 0.07609 to 0.16304, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 8/400
# 820/820 [==============================] - 0s 140us/step - loss: 1.1509 - acc: 0.4902 - val_loss: 1.3212 - val_acc: 0.2065
#
# Epoch 00008: val_acc improved from 0.16304 to 0.20652, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 9/400
# 820/820 [==============================] - 0s 99us/step - loss: 1.1694 - acc: 0.4622 - val_loss: 1.6924 - val_acc: 0.0978
#
# Epoch 00009: val_acc did not improve from 0.20652
# Epoch 10/400
# 820/820 [==============================] - 0s 100us/step - loss: 1.1090 - acc: 0.5146 - val_loss: 1.2211 - val_acc: 0.4022
#
# Epoch 00010: val_acc improved from 0.20652 to 0.40217, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 11/400
# 820/820 [==============================] - 0s 96us/step - loss: 1.1062 - acc: 0.5341 - val_loss: 1.6180 - val_acc: 0.1739
#
# Epoch 00011: val_acc did not improve from 0.40217
# Epoch 12/400
# 820/820 [==============================] - 0s 138us/step - loss: 1.0567 - acc: 0.5610 - val_loss: 1.3072 - val_acc: 0.2935
#
# Epoch 00012: val_acc did not improve from 0.40217
# Epoch 13/400
# 820/820 [==============================] - 0s 125us/step - loss: 1.0496 - acc: 0.5537 - val_loss: 1.3928 - val_acc: 0.2609
#
# Epoch 00013: val_acc did not improve from 0.40217
# Epoch 14/400
# 820/820 [==============================] - 0s 102us/step - loss: 1.0223 - acc: 0.5659 - val_loss: 1.2910 - val_acc: 0.3261
#
# Epoch 00014: val_acc did not improve from 0.40217
# Epoch 15/400
# 820/820 [==============================] - 0s 132us/step - loss: 0.9837 - acc: 0.5963 - val_loss: 1.2831 - val_acc: 0.3152
#
# Epoch 00015: val_acc did not improve from 0.40217
# Epoch 16/400
# 820/820 [==============================] - 0s 131us/step - loss: 0.9827 - acc: 0.5878 - val_loss: 1.2564 - val_acc: 0.4022
#
# Epoch 00016: val_acc did not improve from 0.40217
# Epoch 17/400
# 820/820 [==============================] - 0s 111us/step - loss: 0.9600 - acc: 0.5915 - val_loss: 1.4187 - val_acc: 0.2717
#
# Epoch 00017: val_acc did not improve from 0.40217
# Epoch 18/400
# 820/820 [==============================] - 0s 89us/step - loss: 0.9313 - acc: 0.6049 - val_loss: 1.1620 - val_acc: 0.4457
#
# Epoch 00018: val_acc improved from 0.40217 to 0.44565, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 19/400
# 820/820 [==============================] - 0s 129us/step - loss: 0.9039 - acc: 0.6329 - val_loss: 1.4193 - val_acc: 0.2283
#
# Epoch 00019: val_acc did not improve from 0.44565
# Epoch 20/400
# 820/820 [==============================] - 0s 129us/step - loss: 0.8972 - acc: 0.6329 - val_loss: 1.2089 - val_acc: 0.3696
#
# Epoch 00020: val_acc did not improve from 0.44565
# Epoch 21/400
# 820/820 [==============================] - 0s 125us/step - loss: 0.8917 - acc: 0.6244 - val_loss: 1.1209 - val_acc: 0.5435
#
# Epoch 00021: val_acc improved from 0.44565 to 0.54348, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 22/400
# 820/820 [==============================] - 0s 125us/step - loss: 0.8633 - acc: 0.6354 - val_loss: 1.3899 - val_acc: 0.2935
#
# Epoch 00022: val_acc did not improve from 0.54348
# Epoch 23/400
# 820/820 [==============================] - 0s 129us/step - loss: 0.8224 - acc: 0.6671 - val_loss: 1.1230 - val_acc: 0.4783
#
# Epoch 00023: val_acc did not improve from 0.54348
# Epoch 24/400
# 820/820 [==============================] - 0s 100us/step - loss: 0.8362 - acc: 0.6476 - val_loss: 1.2241 - val_acc: 0.3913
#
# Epoch 00024: val_acc did not improve from 0.54348
# Epoch 25/400
# 820/820 [==============================] - 0s 106us/step - loss: 0.8053 - acc: 0.6598 - val_loss: 1.0937 - val_acc: 0.5543
#
# Epoch 00025: val_acc improved from 0.54348 to 0.55435, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 26/400
# 820/820 [==============================] - 0s 84us/step - loss: 0.8281 - acc: 0.6524 - val_loss: 0.9849 - val_acc: 0.5543
#
# Epoch 00026: val_acc did not improve from 0.55435
# Epoch 27/400
# 820/820 [==============================] - 0s 88us/step - loss: 0.8082 - acc: 0.6793 - val_loss: 1.3014 - val_acc: 0.3804
#
# Epoch 00027: val_acc did not improve from 0.55435
# Epoch 28/400
# 820/820 [==============================] - 0s 90us/step - loss: 0.7481 - acc: 0.7037 - val_loss: 1.0593 - val_acc: 0.5761
#
# Epoch 00028: val_acc improved from 0.55435 to 0.57609, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 29/400
# 820/820 [==============================] - 0s 97us/step - loss: 0.7510 - acc: 0.6951 - val_loss: 1.3847 - val_acc: 0.3804
#
# Epoch 00029: val_acc did not improve from 0.57609
# Epoch 30/400
# 820/820 [==============================] - 0s 80us/step - loss: 0.7857 - acc: 0.6805 - val_loss: 1.1051 - val_acc: 0.4457
#
# Epoch 00030: val_acc did not improve from 0.57609
# Epoch 31/400
# 820/820 [==============================] - 0s 86us/step - loss: 0.7203 - acc: 0.7220 - val_loss: 1.0803 - val_acc: 0.5870
#
# Epoch 00031: val_acc improved from 0.57609 to 0.58696, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 32/400
# 820/820 [==============================] - 0s 174us/step - loss: 0.7362 - acc: 0.7061 - val_loss: 1.0387 - val_acc: 0.5870
#
# Epoch 00032: val_acc did not improve from 0.58696
# Epoch 33/400
# 820/820 [==============================] - 0s 166us/step - loss: 0.7092 - acc: 0.7134 - val_loss: 1.2891 - val_acc: 0.4239
#
# Epoch 00033: val_acc did not improve from 0.58696
# Epoch 34/400
# 820/820 [==============================] - 0s 133us/step - loss: 0.6748 - acc: 0.7293 - val_loss: 0.9401 - val_acc: 0.6739
#
# Epoch 00034: val_acc improved from 0.58696 to 0.67391, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 35/400
# 820/820 [==============================] - 0s 127us/step - loss: 0.6467 - acc: 0.7366 - val_loss: 1.2201 - val_acc: 0.5326
#
# Epoch 00035: val_acc did not improve from 0.67391
# Epoch 36/400
# 820/820 [==============================] - 0s 104us/step - loss: 0.6704 - acc: 0.7280 - val_loss: 0.8980 - val_acc: 0.6413
#
# Epoch 00036: val_acc did not improve from 0.67391
# Epoch 37/400
# 820/820 [==============================] - 0s 103us/step - loss: 0.6508 - acc: 0.7524 - val_loss: 1.1764 - val_acc: 0.5000
#
# Epoch 00037: val_acc did not improve from 0.67391
# Epoch 38/400
# 820/820 [==============================] - 0s 103us/step - loss: 0.6505 - acc: 0.7463 - val_loss: 1.1059 - val_acc: 0.5870
#
# Epoch 00038: val_acc did not improve from 0.67391
# Epoch 39/400
# 820/820 [==============================] - 0s 97us/step - loss: 0.6134 - acc: 0.7610 - val_loss: 0.9415 - val_acc: 0.6630
#
# Epoch 00039: val_acc did not improve from 0.67391
# Epoch 40/400
# 820/820 [==============================] - 0s 79us/step - loss: 0.6118 - acc: 0.7707 - val_loss: 0.8552 - val_acc: 0.6848
#
# Epoch 00040: val_acc improved from 0.67391 to 0.68478, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 41/400
# 820/820 [==============================] - 0s 83us/step - loss: 0.5951 - acc: 0.7707 - val_loss: 1.0645 - val_acc: 0.6196
#
# Epoch 00041: val_acc did not improve from 0.68478
# Epoch 42/400
# 820/820 [==============================] - 0s 88us/step - loss: 0.5988 - acc: 0.7805 - val_loss: 0.9666 - val_acc: 0.6413
#
# Epoch 00042: val_acc did not improve from 0.68478
# Epoch 43/400
# 820/820 [==============================] - 0s 87us/step - loss: 0.5506 - acc: 0.8037 - val_loss: 0.8086 - val_acc: 0.6848
#
# Epoch 00043: val_acc did not improve from 0.68478
# Epoch 44/400
# 820/820 [==============================] - 0s 89us/step - loss: 0.5519 - acc: 0.7829 - val_loss: 0.9086 - val_acc: 0.6848
#
# Epoch 00044: val_acc did not improve from 0.68478
# Epoch 45/400
# 820/820 [==============================] - 0s 83us/step - loss: 0.5530 - acc: 0.8073 - val_loss: 1.2153 - val_acc: 0.5761
#
# Epoch 00045: val_acc did not improve from 0.68478
# Epoch 46/400
# 820/820 [==============================] - 0s 80us/step - loss: 0.5312 - acc: 0.8012 - val_loss: 0.7001 - val_acc: 0.7609
#
# Epoch 00046: val_acc improved from 0.68478 to 0.76087, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 47/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.5356 - acc: 0.8000 - val_loss: 1.1045 - val_acc: 0.6196
#
# Epoch 00047: val_acc did not improve from 0.76087
# Epoch 48/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.4914 - acc: 0.8256 - val_loss: 0.9596 - val_acc: 0.6196
#
# Epoch 00048: val_acc did not improve from 0.76087
# Epoch 49/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.4804 - acc: 0.8183 - val_loss: 0.9388 - val_acc: 0.7174
#
# Epoch 00049: val_acc did not improve from 0.76087
# Epoch 50/400
# 820/820 [==============================] - 0s 80us/step - loss: 0.4678 - acc: 0.8476 - val_loss: 0.7681 - val_acc: 0.7500
#
# Epoch 00050: val_acc did not improve from 0.76087
# Epoch 51/400
# 820/820 [==============================] - 0s 95us/step - loss: 0.4583 - acc: 0.8378 - val_loss: 0.9814 - val_acc: 0.6957
#
# Epoch 00051: val_acc did not improve from 0.76087
# Epoch 52/400
# 820/820 [==============================] - 0s 83us/step - loss: 0.4549 - acc: 0.8390 - val_loss: 0.8436 - val_acc: 0.7174
#
# Epoch 00052: val_acc did not improve from 0.76087
# Epoch 53/400
# 820/820 [==============================] - 0s 82us/step - loss: 0.4574 - acc: 0.8366 - val_loss: 0.7034 - val_acc: 0.7609
#
# Epoch 00053: val_acc did not improve from 0.76087
# Epoch 54/400
# 820/820 [==============================] - 0s 80us/step - loss: 0.4408 - acc: 0.8524 - val_loss: 0.7358 - val_acc: 0.7500
#
# Epoch 00054: val_acc did not improve from 0.76087
# Epoch 55/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.4470 - acc: 0.8439 - val_loss: 1.0260 - val_acc: 0.7174
#
# Epoch 00055: val_acc did not improve from 0.76087
# Epoch 56/400
# 820/820 [==============================] - 0s 80us/step - loss: 0.4476 - acc: 0.8415 - val_loss: 0.8574 - val_acc: 0.7283
#
# Epoch 00056: val_acc did not improve from 0.76087
# Epoch 57/400
# 820/820 [==============================] - 0s 80us/step - loss: 0.4227 - acc: 0.8561 - val_loss: 0.7104 - val_acc: 0.7935
#
# Epoch 00057: val_acc improved from 0.76087 to 0.79348, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 58/400
# 820/820 [==============================] - 0s 79us/step - loss: 0.4172 - acc: 0.8512 - val_loss: 0.7976 - val_acc: 0.7391
#
# Epoch 00058: val_acc did not improve from 0.79348
# Epoch 59/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.3965 - acc: 0.8646 - val_loss: 0.8135 - val_acc: 0.7500
#
# Epoch 00059: val_acc did not improve from 0.79348
# Epoch 60/400
# 820/820 [==============================] - 0s 74us/step - loss: 0.3689 - acc: 0.8720 - val_loss: 0.9216 - val_acc: 0.7391
#
# Epoch 00060: val_acc did not improve from 0.79348
# Epoch 61/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.3861 - acc: 0.8671 - val_loss: 0.8395 - val_acc: 0.7609
#
# Epoch 00061: val_acc did not improve from 0.79348
# Epoch 62/400
# 820/820 [==============================] - 0s 76us/step - loss: 0.3653 - acc: 0.8659 - val_loss: 0.6473 - val_acc: 0.8043
#
# Epoch 00062: val_acc improved from 0.79348 to 0.80435, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 63/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.3535 - acc: 0.8854 - val_loss: 0.7393 - val_acc: 0.7826
#
# Epoch 00063: val_acc did not improve from 0.80435
# Epoch 64/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.3699 - acc: 0.8659 - val_loss: 0.9057 - val_acc: 0.7609
#
# Epoch 00064: val_acc did not improve from 0.80435
# Epoch 65/400
# 820/820 [==============================] - 0s 88us/step - loss: 0.3629 - acc: 0.8671 - val_loss: 0.9057 - val_acc: 0.7391
#
# Epoch 00065: val_acc did not improve from 0.80435
# Epoch 66/400
# 820/820 [==============================] - 0s 88us/step - loss: 0.3904 - acc: 0.8585 - val_loss: 1.0038 - val_acc: 0.7065
#
# Epoch 00066: val_acc did not improve from 0.80435
# Epoch 67/400
# 820/820 [==============================] - 0s 82us/step - loss: 0.3913 - acc: 0.8585 - val_loss: 0.6225 - val_acc: 0.8370
#
# Epoch 00067: val_acc improved from 0.80435 to 0.83696, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 68/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.3562 - acc: 0.8683 - val_loss: 1.0081 - val_acc: 0.7391
#
# Epoch 00068: val_acc did not improve from 0.83696
# Epoch 69/400
# 820/820 [==============================] - 0s 101us/step - loss: 0.3264 - acc: 0.9061 - val_loss: 0.7227 - val_acc: 0.8043
#
# Epoch 00069: val_acc did not improve from 0.83696
# Epoch 70/400
# 820/820 [==============================] - 0s 105us/step - loss: 0.3278 - acc: 0.8866 - val_loss: 0.6845 - val_acc: 0.7935
#
# Epoch 00070: val_acc did not improve from 0.83696
# Epoch 71/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.3092 - acc: 0.8988 - val_loss: 0.7493 - val_acc: 0.8043
#
# Epoch 00071: val_acc did not improve from 0.83696
# Epoch 72/400
# 820/820 [==============================] - 0s 84us/step - loss: 0.2945 - acc: 0.8951 - val_loss: 0.7380 - val_acc: 0.7826
#
# Epoch 00072: val_acc did not improve from 0.83696
# Epoch 73/400
# 820/820 [==============================] - 0s 85us/step - loss: 0.2967 - acc: 0.9012 - val_loss: 0.7593 - val_acc: 0.7826
#
# Epoch 00073: val_acc did not improve from 0.83696
# Epoch 74/400
# 820/820 [==============================] - 0s 79us/step - loss: 0.2755 - acc: 0.9183 - val_loss: 0.7271 - val_acc: 0.7826
#
# Epoch 00074: val_acc did not improve from 0.83696
# Epoch 75/400
# 820/820 [==============================] - 0s 83us/step - loss: 0.2653 - acc: 0.9207 - val_loss: 0.7003 - val_acc: 0.8043
#
# Epoch 00075: val_acc did not improve from 0.83696
# Epoch 76/400
# 820/820 [==============================] - 0s 88us/step - loss: 0.2675 - acc: 0.9049 - val_loss: 0.7644 - val_acc: 0.8043
#
# Epoch 00076: val_acc did not improve from 0.83696
# Epoch 77/400
# 820/820 [==============================] - 0s 99us/step - loss: 0.2594 - acc: 0.9085 - val_loss: 0.7705 - val_acc: 0.8152
#
# Epoch 00077: val_acc did not improve from 0.83696
# Epoch 78/400
# 820/820 [==============================] - 0s 83us/step - loss: 0.2515 - acc: 0.9280 - val_loss: 0.7599 - val_acc: 0.8152
#
# Epoch 00078: val_acc did not improve from 0.83696
# Epoch 79/400
# 820/820 [==============================] - 0s 76us/step - loss: 0.2603 - acc: 0.9049 - val_loss: 0.7337 - val_acc: 0.8152
#
# Epoch 00079: val_acc did not improve from 0.83696
# Epoch 80/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.2425 - acc: 0.9280 - val_loss: 0.7915 - val_acc: 0.8152
#
# Epoch 00080: val_acc did not improve from 0.83696
# Epoch 81/400
# 820/820 [==============================] - 0s 79us/step - loss: 0.2516 - acc: 0.9098 - val_loss: 0.7621 - val_acc: 0.8152
#
# Epoch 00081: val_acc did not improve from 0.83696
# Epoch 82/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.2284 - acc: 0.9366 - val_loss: 0.6467 - val_acc: 0.8587
#
# Epoch 00082: val_acc improved from 0.83696 to 0.85870, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 83/400
# 820/820 [==============================] - 0s 93us/step - loss: 0.2499 - acc: 0.9159 - val_loss: 0.6983 - val_acc: 0.8478
#
# Epoch 00083: val_acc did not improve from 0.85870
# Epoch 84/400
# 820/820 [==============================] - 0s 89us/step - loss: 0.2245 - acc: 0.9427 - val_loss: 0.7655 - val_acc: 0.8478
#
# Epoch 00084: val_acc did not improve from 0.85870
# Epoch 85/400
# 820/820 [==============================] - 0s 83us/step - loss: 0.2155 - acc: 0.9354 - val_loss: 0.8596 - val_acc: 0.8152
#
# Epoch 00085: val_acc did not improve from 0.85870
# Epoch 86/400
# 820/820 [==============================] - 0s 79us/step - loss: 0.2118 - acc: 0.9354 - val_loss: 0.7719 - val_acc: 0.8478
#
# Epoch 00086: val_acc did not improve from 0.85870
# Epoch 87/400
# 820/820 [==============================] - 0s 83us/step - loss: 0.2291 - acc: 0.9341 - val_loss: 0.7302 - val_acc: 0.8587
#
# Epoch 00087: val_acc did not improve from 0.85870
# Epoch 88/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.2023 - acc: 0.9390 - val_loss: 0.8540 - val_acc: 0.8152
#
# Epoch 00088: val_acc did not improve from 0.85870
# Epoch 89/400
# 820/820 [==============================] - 0s 74us/step - loss: 0.1973 - acc: 0.9366 - val_loss: 0.7591 - val_acc: 0.8152
#
# Epoch 00089: val_acc did not improve from 0.85870
# Epoch 90/400
# 820/820 [==============================] - 0s 79us/step - loss: 0.1938 - acc: 0.9451 - val_loss: 0.7218 - val_acc: 0.8152
#
# Epoch 00090: val_acc did not improve from 0.85870
# Epoch 91/400
# 820/820 [==============================] - 0s 88us/step - loss: 0.1945 - acc: 0.9402 - val_loss: 0.7697 - val_acc: 0.8478
#
# Epoch 00091: val_acc did not improve from 0.85870
# Epoch 92/400
# 820/820 [==============================] - 0s 91us/step - loss: 0.1849 - acc: 0.9488 - val_loss: 0.6610 - val_acc: 0.8587
#
# Epoch 00092: val_acc did not improve from 0.85870
# Epoch 93/400
# 820/820 [==============================] - 0s 79us/step - loss: 0.1730 - acc: 0.9439 - val_loss: 0.7247 - val_acc: 0.8478
#
# Epoch 00093: val_acc did not improve from 0.85870
# Epoch 94/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.1918 - acc: 0.9366 - val_loss: 0.8648 - val_acc: 0.8370
#
# Epoch 00094: val_acc did not improve from 0.85870
# Epoch 95/400
# 820/820 [==============================] - 0s 91us/step - loss: 0.1894 - acc: 0.9427 - val_loss: 0.8239 - val_acc: 0.8261
#
# Epoch 00095: val_acc did not improve from 0.85870
# Epoch 96/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.1622 - acc: 0.9585 - val_loss: 0.7421 - val_acc: 0.8587
#
# Epoch 00096: val_acc did not improve from 0.85870
# Epoch 97/400
# 820/820 [==============================] - 0s 86us/step - loss: 0.1586 - acc: 0.9646 - val_loss: 0.8027 - val_acc: 0.8478
#
# Epoch 00097: val_acc did not improve from 0.85870
# Epoch 98/400
# 820/820 [==============================] - 0s 80us/step - loss: 0.1537 - acc: 0.9634 - val_loss: 0.8143 - val_acc: 0.8587
#
# Epoch 00098: val_acc did not improve from 0.85870
# Epoch 99/400
# 820/820 [==============================] - 0s 76us/step - loss: 0.1580 - acc: 0.9476 - val_loss: 0.7792 - val_acc: 0.8587
#
# Epoch 00099: val_acc did not improve from 0.85870
# Epoch 100/400
# 820/820 [==============================] - 0s 76us/step - loss: 0.1416 - acc: 0.9659 - val_loss: 0.7530 - val_acc: 0.8587
#
# Epoch 00100: val_acc did not improve from 0.85870
# Epoch 101/400
# 820/820 [==============================] - 0s 76us/step - loss: 0.1742 - acc: 0.9488 - val_loss: 0.8294 - val_acc: 0.8587
#
# Epoch 00101: val_acc did not improve from 0.85870
# Epoch 102/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.1453 - acc: 0.9537 - val_loss: 0.7278 - val_acc: 0.8587
#
# Epoch 00102: val_acc did not improve from 0.85870
# Epoch 103/400
# 820/820 [==============================] - 0s 80us/step - loss: 0.1518 - acc: 0.9561 - val_loss: 0.8365 - val_acc: 0.8478
#
# Epoch 00103: val_acc did not improve from 0.85870
# Epoch 104/400
# 820/820 [==============================] - 0s 83us/step - loss: 0.1498 - acc: 0.9573 - val_loss: 0.6659 - val_acc: 0.8587
#
# Epoch 00104: val_acc did not improve from 0.85870
# Epoch 105/400
# 820/820 [==============================] - 0s 82us/step - loss: 0.1399 - acc: 0.9634 - val_loss: 0.8394 - val_acc: 0.8587
#
# Epoch 00105: val_acc did not improve from 0.85870
# Epoch 106/400
# 820/820 [==============================] - 0s 82us/step - loss: 0.1401 - acc: 0.9610 - val_loss: 0.7658 - val_acc: 0.8587
#
# Epoch 00106: val_acc did not improve from 0.85870
# Epoch 107/400
# 820/820 [==============================] - 0s 85us/step - loss: 0.1232 - acc: 0.9683 - val_loss: 0.8142 - val_acc: 0.8587
#
# Epoch 00107: val_acc did not improve from 0.85870
# Epoch 108/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.1436 - acc: 0.9659 - val_loss: 0.8823 - val_acc: 0.8261
#
# Epoch 00108: val_acc did not improve from 0.85870
# Epoch 109/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.1408 - acc: 0.9524 - val_loss: 0.7118 - val_acc: 0.8696
#
# Epoch 00109: val_acc improved from 0.85870 to 0.86957, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 110/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.1327 - acc: 0.9622 - val_loss: 0.7950 - val_acc: 0.8587
#
# Epoch 00110: val_acc did not improve from 0.86957
# Epoch 111/400
# 820/820 [==============================] - 0s 82us/step - loss: 0.1405 - acc: 0.9537 - val_loss: 0.8665 - val_acc: 0.8587
#
# Epoch 00111: val_acc did not improve from 0.86957
# Epoch 112/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.1320 - acc: 0.9598 - val_loss: 0.8321 - val_acc: 0.8696
#
# Epoch 00112: val_acc did not improve from 0.86957
# Epoch 113/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.1296 - acc: 0.9610 - val_loss: 0.8396 - val_acc: 0.8696
#
# Epoch 00113: val_acc did not improve from 0.86957
# Epoch 114/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.1359 - acc: 0.9622 - val_loss: 0.7471 - val_acc: 0.8696
#
# Epoch 00114: val_acc did not improve from 0.86957
# Epoch 115/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.1128 - acc: 0.9720 - val_loss: 0.8205 - val_acc: 0.8696
#
# Epoch 00115: val_acc did not improve from 0.86957
# Epoch 116/400
# 820/820 [==============================] - 0s 80us/step - loss: 0.1223 - acc: 0.9646 - val_loss: 0.8046 - val_acc: 0.8696
#
# Epoch 00116: val_acc did not improve from 0.86957
# Epoch 117/400
# 820/820 [==============================] - 0s 85us/step - loss: 0.1166 - acc: 0.9634 - val_loss: 0.8641 - val_acc: 0.8696
#
# Epoch 00117: val_acc did not improve from 0.86957
# Epoch 118/400
# 820/820 [==============================] - 0s 75us/step - loss: 0.1034 - acc: 0.9780 - val_loss: 0.7673 - val_acc: 0.8696
#
# Epoch 00118: val_acc did not improve from 0.86957
# Epoch 119/400
# 820/820 [==============================] - 0s 74us/step - loss: 0.1094 - acc: 0.9646 - val_loss: 0.7309 - val_acc: 0.8696
#
# Epoch 00119: val_acc did not improve from 0.86957
# Epoch 120/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.1166 - acc: 0.9646 - val_loss: 0.7668 - val_acc: 0.8696
#
# Epoch 00120: val_acc did not improve from 0.86957
# Epoch 121/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.1208 - acc: 0.9634 - val_loss: 0.6599 - val_acc: 0.8696
#
# Epoch 00121: val_acc did not improve from 0.86957
# Epoch 122/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.0999 - acc: 0.9780 - val_loss: 0.8335 - val_acc: 0.8696
#
# Epoch 00122: val_acc did not improve from 0.86957
# Epoch 123/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.0946 - acc: 0.9756 - val_loss: 0.8535 - val_acc: 0.8696
#
# Epoch 00123: val_acc did not improve from 0.86957
# Epoch 124/400
# 820/820 [==============================] - 0s 79us/step - loss: 0.0900 - acc: 0.9805 - val_loss: 0.7061 - val_acc: 0.8804
#
# Epoch 00124: val_acc improved from 0.86957 to 0.88043, saving model to 1dconv_feature_engineered_model_chronological_multiclass.h5
# Epoch 125/400
# 820/820 [==============================] - 0s 73us/step - loss: 0.0814 - acc: 0.9841 - val_loss: 0.8330 - val_acc: 0.8696
#
# Epoch 00125: val_acc did not improve from 0.88043
# Epoch 126/400
# 820/820 [==============================] - 0s 72us/step - loss: 0.0966 - acc: 0.9756 - val_loss: 0.8300 - val_acc: 0.8696
#
# Epoch 00126: val_acc did not improve from 0.88043
# Epoch 127/400
# 820/820 [==============================] - 0s 75us/step - loss: 0.1075 - acc: 0.9659 - val_loss: 0.7961 - val_acc: 0.8696
#
# Epoch 00127: val_acc did not improve from 0.88043
# Epoch 128/400
# 820/820 [==============================] - 0s 72us/step - loss: 0.0986 - acc: 0.9683 - val_loss: 0.8602 - val_acc: 0.8696
#
# Epoch 00128: val_acc did not improve from 0.88043
# Epoch 129/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.1005 - acc: 0.9732 - val_loss: 0.7748 - val_acc: 0.8804
#
# Epoch 00129: val_acc did not improve from 0.88043
# Epoch 130/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.0943 - acc: 0.9768 - val_loss: 0.7225 - val_acc: 0.8696
#
# Epoch 00130: val_acc did not improve from 0.88043
# Epoch 131/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.0805 - acc: 0.9768 - val_loss: 0.8187 - val_acc: 0.8696
#
# Epoch 00131: val_acc did not improve from 0.88043
# Epoch 132/400
# 820/820 [==============================] - 0s 79us/step - loss: 0.0854 - acc: 0.9780 - val_loss: 0.7143 - val_acc: 0.8696
#
# Epoch 00132: val_acc did not improve from 0.88043
# Epoch 133/400
# 820/820 [==============================] - 0s 82us/step - loss: 0.0799 - acc: 0.9768 - val_loss: 0.7812 - val_acc: 0.8696
#
# Epoch 00133: val_acc did not improve from 0.88043
# Epoch 134/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.0796 - acc: 0.9854 - val_loss: 0.7904 - val_acc: 0.8696
#
# Epoch 00134: val_acc did not improve from 0.88043
# Epoch 135/400
# 820/820 [==============================] - 0s 74us/step - loss: 0.0682 - acc: 0.9829 - val_loss: 0.7042 - val_acc: 0.8696
#
# Epoch 00135: val_acc did not improve from 0.88043
# Epoch 136/400
# 820/820 [==============================] - 0s 89us/step - loss: 0.0763 - acc: 0.9817 - val_loss: 0.6519 - val_acc: 0.8804
#
# Epoch 00136: val_acc did not improve from 0.88043
# Epoch 137/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.0724 - acc: 0.9854 - val_loss: 0.7864 - val_acc: 0.8804
#
# Epoch 00137: val_acc did not improve from 0.88043
# Epoch 138/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.0777 - acc: 0.9768 - val_loss: 0.8156 - val_acc: 0.8804
#
# Epoch 00138: val_acc did not improve from 0.88043
# Epoch 139/400
# 820/820 [==============================] - 0s 73us/step - loss: 0.0704 - acc: 0.9817 - val_loss: 0.9444 - val_acc: 0.8261
#
# Epoch 00139: val_acc did not improve from 0.88043
# Epoch 140/400
# 820/820 [==============================] - 0s 84us/step - loss: 0.0737 - acc: 0.9841 - val_loss: 0.7024 - val_acc: 0.8804
#
# Epoch 00140: val_acc did not improve from 0.88043
# Epoch 141/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.0846 - acc: 0.9756 - val_loss: 0.8283 - val_acc: 0.8696
#
# Epoch 00141: val_acc did not improve from 0.88043
# Epoch 142/400
# 820/820 [==============================] - 0s 85us/step - loss: 0.0751 - acc: 0.9805 - val_loss: 0.6837 - val_acc: 0.8804
#
# Epoch 00142: val_acc did not improve from 0.88043
# Epoch 143/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.0602 - acc: 0.9939 - val_loss: 0.7517 - val_acc: 0.8804
#
# Epoch 00143: val_acc did not improve from 0.88043
# Epoch 144/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.0656 - acc: 0.9866 - val_loss: 0.7089 - val_acc: 0.8804
#
# Epoch 00144: val_acc did not improve from 0.88043
# Epoch 145/400
# 820/820 [==============================] - 0s 80us/step - loss: 0.0653 - acc: 0.9841 - val_loss: 0.7938 - val_acc: 0.8804
#
# Epoch 00145: val_acc did not improve from 0.88043
# Epoch 146/400
# 820/820 [==============================] - 0s 80us/step - loss: 0.0754 - acc: 0.9817 - val_loss: 0.8307 - val_acc: 0.8696
#
# Epoch 00146: val_acc did not improve from 0.88043
# Epoch 147/400
# 820/820 [==============================] - 0s 82us/step - loss: 0.0755 - acc: 0.9841 - val_loss: 0.8899 - val_acc: 0.8696
#
# Epoch 00147: val_acc did not improve from 0.88043
# Epoch 148/400
# 820/820 [==============================] - 0s 82us/step - loss: 0.0724 - acc: 0.9841 - val_loss: 0.6554 - val_acc: 0.8804
#
# Epoch 00148: val_acc did not improve from 0.88043
# Epoch 149/400
# 820/820 [==============================] - 0s 79us/step - loss: 0.0750 - acc: 0.9793 - val_loss: 0.7673 - val_acc: 0.8696
#
# Epoch 00149: val_acc did not improve from 0.88043
# Epoch 150/400
# 820/820 [==============================] - 0s 83us/step - loss: 0.0615 - acc: 0.9878 - val_loss: 0.7848 - val_acc: 0.8696
#
# Epoch 00150: val_acc did not improve from 0.88043
# Epoch 151/400
# 820/820 [==============================] - 0s 93us/step - loss: 0.0749 - acc: 0.9793 - val_loss: 0.7885 - val_acc: 0.8804
#
# Epoch 00151: val_acc did not improve from 0.88043
# Epoch 152/400
# 820/820 [==============================] - 0s 84us/step - loss: 0.0506 - acc: 0.9878 - val_loss: 0.7961 - val_acc: 0.8804
#
# Epoch 00152: val_acc did not improve from 0.88043
# Epoch 153/400
# 820/820 [==============================] - 0s 80us/step - loss: 0.0611 - acc: 0.9841 - val_loss: 0.7441 - val_acc: 0.8804
#
# Epoch 00153: val_acc did not improve from 0.88043
# Epoch 154/400
# 820/820 [==============================] - 0s 85us/step - loss: 0.0735 - acc: 0.9817 - val_loss: 0.8781 - val_acc: 0.8696
#
# Epoch 00154: val_acc did not improve from 0.88043
# Epoch 155/400
# 820/820 [==============================] - 0s 79us/step - loss: 0.0660 - acc: 0.9805 - val_loss: 0.6986 - val_acc: 0.8804
#
# Epoch 00155: val_acc did not improve from 0.88043
# Epoch 156/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.0912 - acc: 0.9732 - val_loss: 0.9588 - val_acc: 0.8696
#
# Epoch 00156: val_acc did not improve from 0.88043
# Epoch 157/400
# 820/820 [==============================] - 0s 74us/step - loss: 0.0628 - acc: 0.9817 - val_loss: 0.8130 - val_acc: 0.8696
#
# Epoch 00157: val_acc did not improve from 0.88043
# Epoch 158/400
# 820/820 [==============================] - 0s 75us/step - loss: 0.0591 - acc: 0.9890 - val_loss: 0.8393 - val_acc: 0.8696
#
# Epoch 00158: val_acc did not improve from 0.88043
# Epoch 159/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.0568 - acc: 0.9817 - val_loss: 0.8703 - val_acc: 0.8696
#
# Epoch 00159: val_acc did not improve from 0.88043
# Epoch 160/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.0530 - acc: 0.9866 - val_loss: 0.7830 - val_acc: 0.8696
#
# Epoch 00160: val_acc did not improve from 0.88043
# Epoch 161/400
# 820/820 [==============================] - 0s 74us/step - loss: 0.0427 - acc: 0.9927 - val_loss: 0.8354 - val_acc: 0.8804
#
# Epoch 00161: val_acc did not improve from 0.88043
# Epoch 162/400
# 820/820 [==============================] - 0s 76us/step - loss: 0.0613 - acc: 0.9829 - val_loss: 0.8201 - val_acc: 0.8804
#
# Epoch 00162: val_acc did not improve from 0.88043
# Epoch 163/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.0530 - acc: 0.9878 - val_loss: 0.8673 - val_acc: 0.8804
#
# Epoch 00163: val_acc did not improve from 0.88043
# Epoch 164/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.0563 - acc: 0.9902 - val_loss: 0.8103 - val_acc: 0.8804
#
# Epoch 00164: val_acc did not improve from 0.88043
# Epoch 165/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.0616 - acc: 0.9878 - val_loss: 0.8573 - val_acc: 0.8804
#
# Epoch 00165: val_acc did not improve from 0.88043
# Epoch 166/400
# 820/820 [==============================] - 0s 86us/step - loss: 0.0464 - acc: 0.9915 - val_loss: 0.8638 - val_acc: 0.8804
#
# Epoch 00166: val_acc did not improve from 0.88043
# Epoch 167/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.0613 - acc: 0.9854 - val_loss: 0.7581 - val_acc: 0.8804
#
# Epoch 00167: val_acc did not improve from 0.88043
# Epoch 168/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.0515 - acc: 0.9878 - val_loss: 0.8257 - val_acc: 0.8804
#
# Epoch 00168: val_acc did not improve from 0.88043
# Epoch 169/400
# 820/820 [==============================] - 0s 75us/step - loss: 0.0448 - acc: 0.9927 - val_loss: 0.8259 - val_acc: 0.8804
#
# Epoch 00169: val_acc did not improve from 0.88043
# Epoch 170/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.0532 - acc: 0.9854 - val_loss: 0.8704 - val_acc: 0.8696
#
# Epoch 00170: val_acc did not improve from 0.88043
# Epoch 171/400
# 820/820 [==============================] - 0s 76us/step - loss: 0.0464 - acc: 0.9878 - val_loss: 0.8230 - val_acc: 0.8804
#
# Epoch 00171: val_acc did not improve from 0.88043
# Epoch 172/400
# 820/820 [==============================] - 0s 74us/step - loss: 0.0446 - acc: 0.9927 - val_loss: 0.8587 - val_acc: 0.8804
#
# Epoch 00172: val_acc did not improve from 0.88043
# Epoch 173/400
# 820/820 [==============================] - 0s 75us/step - loss: 0.0396 - acc: 0.9951 - val_loss: 0.8413 - val_acc: 0.8804
#
# Epoch 00173: val_acc did not improve from 0.88043
# Epoch 174/400
# 820/820 [==============================] - 0s 76us/step - loss: 0.0416 - acc: 0.9915 - val_loss: 0.9336 - val_acc: 0.8804
#
# Epoch 00174: val_acc did not improve from 0.88043
# Epoch 175/400
# 820/820 [==============================] - 0s 75us/step - loss: 0.0439 - acc: 0.9890 - val_loss: 0.7512 - val_acc: 0.8804
#
# Epoch 00175: val_acc did not improve from 0.88043
# Epoch 176/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.0401 - acc: 0.9939 - val_loss: 1.0948 - val_acc: 0.8696
#
# Epoch 00176: val_acc did not improve from 0.88043
# Epoch 177/400
# 820/820 [==============================] - 0s 76us/step - loss: 0.0466 - acc: 0.9854 - val_loss: 0.7858 - val_acc: 0.8804
#
# Epoch 00177: val_acc did not improve from 0.88043
# Epoch 178/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.0460 - acc: 0.9866 - val_loss: 1.0682 - val_acc: 0.8370
#
# Epoch 00178: val_acc did not improve from 0.88043
# Epoch 179/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.0526 - acc: 0.9854 - val_loss: 0.9167 - val_acc: 0.8804
#
# Epoch 00179: val_acc did not improve from 0.88043
# Epoch 180/400
# 820/820 [==============================] - 0s 76us/step - loss: 0.0378 - acc: 0.9927 - val_loss: 0.9213 - val_acc: 0.8804
#
# Epoch 00180: val_acc did not improve from 0.88043
# Epoch 181/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.0428 - acc: 0.9890 - val_loss: 0.9507 - val_acc: 0.8804
#
# Epoch 00181: val_acc did not improve from 0.88043
# Epoch 182/400
# 820/820 [==============================] - 0s 83us/step - loss: 0.0394 - acc: 0.9890 - val_loss: 0.8765 - val_acc: 0.8804
#
# Epoch 00182: val_acc did not improve from 0.88043
# Epoch 183/400
# 820/820 [==============================] - 0s 76us/step - loss: 0.0439 - acc: 0.9890 - val_loss: 0.8588 - val_acc: 0.8804
#
# Epoch 00183: val_acc did not improve from 0.88043
# Epoch 184/400
# 820/820 [==============================] - 0s 79us/step - loss: 0.0298 - acc: 0.9976 - val_loss: 0.8930 - val_acc: 0.8804
#
# Epoch 00184: val_acc did not improve from 0.88043
# Epoch 185/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.0354 - acc: 0.9939 - val_loss: 0.9358 - val_acc: 0.8804
#
# Epoch 00185: val_acc did not improve from 0.88043
# Epoch 186/400
# 820/820 [==============================] - 0s 76us/step - loss: 0.0281 - acc: 0.9988 - val_loss: 0.8735 - val_acc: 0.8804
#
# Epoch 00186: val_acc did not improve from 0.88043
# Epoch 187/400
# 820/820 [==============================] - 0s 76us/step - loss: 0.0324 - acc: 0.9915 - val_loss: 0.9849 - val_acc: 0.8804
#
# Epoch 00187: val_acc did not improve from 0.88043
# Epoch 188/400
# 820/820 [==============================] - 0s 74us/step - loss: 0.0373 - acc: 0.9902 - val_loss: 0.9015 - val_acc: 0.8804
#
# Epoch 00188: val_acc did not improve from 0.88043
# Epoch 189/400
# 820/820 [==============================] - 0s 80us/step - loss: 0.0378 - acc: 0.9951 - val_loss: 1.1193 - val_acc: 0.8696
#
# Epoch 00189: val_acc did not improve from 0.88043
# Epoch 190/400
# 820/820 [==============================] - 0s 85us/step - loss: 0.0306 - acc: 0.9939 - val_loss: 0.9264 - val_acc: 0.8804
#
# Epoch 00190: val_acc did not improve from 0.88043
# Epoch 191/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.0381 - acc: 0.9890 - val_loss: 0.9910 - val_acc: 0.8804
#
# Epoch 00191: val_acc did not improve from 0.88043
# Epoch 192/400
# 820/820 [==============================] - 0s 79us/step - loss: 0.0336 - acc: 0.9927 - val_loss: 0.9665 - val_acc: 0.8804
#
# Epoch 00192: val_acc did not improve from 0.88043
# Epoch 193/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.0286 - acc: 0.9988 - val_loss: 0.9257 - val_acc: 0.8804
#
# Epoch 00193: val_acc did not improve from 0.88043
# Epoch 194/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.0344 - acc: 0.9927 - val_loss: 0.8432 - val_acc: 0.8804
#
# Epoch 00194: val_acc did not improve from 0.88043
# Epoch 195/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.0307 - acc: 0.9927 - val_loss: 0.9709 - val_acc: 0.8804
#
# Epoch 00195: val_acc did not improve from 0.88043
# Epoch 196/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.0275 - acc: 0.9963 - val_loss: 0.9398 - val_acc: 0.8804
#
# Epoch 00196: val_acc did not improve from 0.88043
# Epoch 197/400
# 820/820 [==============================] - 0s 81us/step - loss: 0.0353 - acc: 0.9890 - val_loss: 0.9206 - val_acc: 0.8804
#
# Epoch 00197: val_acc did not improve from 0.88043
# Epoch 198/400
# 820/820 [==============================] - 0s 77us/step - loss: 0.0383 - acc: 0.9866 - val_loss: 0.9779 - val_acc: 0.8804
#
# Epoch 00198: val_acc did not improve from 0.88043
# Epoch 199/400
# 820/820 [==============================] - 0s 78us/step - loss: 0.0411 - acc: 0.9878 - val_loss: 0.9678 - val_acc: 0.8804
#
# Epoch 00199: val_acc did not improve from 0.88043

# %%
saved_model = load_model('1dconv_feature_engineered_model_chronological_multiclass.h5')

# %%
predictions = saved_model.predict_classes(X_test,batch_size = X_test.shape[0], verbose=1)

from sklearn.metrics import accuracy_score
print ("saved model acc: %s" % accuracy_score(y_test, predictions))
# accuracy: (tp + tn) / (p + n)

# precision tp / (tp + fp)
precision = precision_score(
    y_test,
    predictions,
    average=None)


recall = recall_score(y_test,
                      predictions, 
                     average=None)
# Out:
# 150/150 [==============================] - 0s 508us/step
# saved model acc: 0.4066666666666667
