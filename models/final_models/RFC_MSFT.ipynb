# %%
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
from sklearn.utils.multiclass import unique_labels

from scipy import stats
from IPython.display import display, HTML

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# %%
X_train = pd.read_csv("/Users/fahad/project_repo/data/final/X_train.csv", index_col=0)
y_train = pd.read_csv("/Users/fahad/project_repo/data/final/y_train.csv", index_col=0)
MSFT_10_X_test = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_10_X_test.csv", index_col=0)
MSFT_10_y_test = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_10_y_test.csv", index_col=0)
MSFT_14_X_test  = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_14_X_test.csv", index_col=0)
MSFT_14_y_test = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_14_y_test.csv", index_col=0)

# %%
rfc = RandomForestClassifier(n_jobs=-1,max_features= 'sqrt' ,n_estimators=50, oob_score = True) 

param_grid = { 
    'n_estimators': [100, 200],
    'max_features': ['auto', 'sqrt', 'log2'],
    "min_samples_split": [2, 3, 10],
    "max_depth": [3, None],
    
}

CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(X_train, y_train)


print (CV_rfc.best_params_)
# Out:
# /Users/fahad/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/fahad/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/fahad/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
rfc = RandomForestClassifier(max_depth =3, max_features='auto', min_samples_split=2, n_estimators=100)
rfc.fit(X_train, y_train)
# Out:
# /Users/fahad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=3, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
predictions = rfc.predict(MSFT_10_X_test)
predictions = predictions.tolist()

# %%
from sklearn.metrics import accuracy_score
print ("saved model acc: %s" % accuracy_score(MSFT_10_y_test, predictions))
# accuracy: (tp + tn) / (p + n)

# precision tp / (tp + fp)
precision = precision_score(MSFT_10_y_test, predictions)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(MSFT_10_y_test, predictions)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(MSFT_10_y_test, predictions)
print('F1 score: %f' % f1)
 
# kappa
kappa = cohen_kappa_score(MSFT_10_y_test, predictions)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(MSFT_10_y_test, predictions)
print('ROC AUC: %f' % auc)
# Out:
# saved model acc: 0.7058823529411765
# Precision: 0.727273
# Recall: 0.800000
# F1 score: 0.761905
# Cohens kappa: 0.379562
# ROC AUC: 0.685714

# %%
predictions_2= rfc.predict(MSFT_14_X_test)
predictions_2= predictions_2.tolist()

# %%
from sklearn.metrics import accuracy_score
print ("saved model acc: %s" % accuracy_score(MSFT_14_y_test, predictions_2))
# accuracy: (tp + tn) / (p + n)

# precision tp / (tp + fp)
precision = precision_score(MSFT_14_y_test, predictions_2)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(MSFT_14_y_test, predictions_2)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(MSFT_14_y_test, predictions_2)
print('F1 score: %f' % f1)
 
# kappa
kappa = cohen_kappa_score(MSFT_14_y_test, predictions_2)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(MSFT_14_y_test, predictions_2)
print('ROC AUC: %f' % auc)
# Out:
# saved model acc: 0.6290322580645161
# Precision: 0.727273
# Recall: 0.744186
# F1 score: 0.735632
# Cohens kappa: 0.114286
# ROC AUC: 0.556304

# %%
# %matplotlib inline

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title="Confusion Matrix",
                          cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation="nearest", cmap=cmap)
    plt.title(title)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    if normalize:
        cm = cm.astype("float")/ cm.sum(axis=1)[:,np.newaxis]
        print ("Normalised confusion matrix")
    else:
        print ("Confusion matrix, without normalisation")
        
    print (cm)
    
    thresh = cm.max()/2
    for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
        plt.text(j, i, cm[i,j],
        horizontalalignment = "center",
        color="white" if cm[i,j] > thresh else "black" )
        
    plt.tight_layout()
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")

# %%
cm = confusion_matrix(MSFT_10_y_test, predictions)
cm_labels = ['Sell', 'Buy']
plot_confusion_matrix(cm, cm_labels, title="Confusion Matrix")
# Out:
# Confusion matrix, without normalisation
# [[16 12]
#  [ 8 32]]

# %%
cm = confusion_matrix(MSFT_14_y_test, predictions_2)
cm_labels = ['Sell', 'Buy']
plot_confusion_matrix(cm, cm_labels, title="Confusion Matrix")
# Out:
# Confusion matrix, without normalisation
# [[ 7 12]
#  [11 32]]
