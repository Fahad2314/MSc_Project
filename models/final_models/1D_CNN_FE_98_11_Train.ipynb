# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
import csv
from pandas.tseries.offsets import MonthEnd
from datetime import datetime, timedelta, date
import requests
import json 
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
from sklearn.utils.multiclass import unique_labels

from scipy import stats
from IPython.display import display, HTML

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape
from keras.layers import Convolution1D, MaxPooling1D
from keras.utils import np_utils
import seaborn as sns

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 1998_2011 data MSFT

# %%
MSFT_98_train = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_98_train_flat_df.csv", index_col=0)
MSFT_98_train = MSFT_98_train.reset_index(drop=True)


MSFT_98_test = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_98_test_flat_df.csv", index_col=0)
MSFT_98_test = MSFT_98_test.reset_index(drop=True)


MSFT_02_train = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_02_train_flat_df.csv", index_col=0)
MSFT_02_train = MSFT_02_train.reset_index(drop=True)


MSFT_02_test = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_02_test_flat_df.csv", index_col=0)
MSFT_02_test = MSFT_02_test.reset_index(drop=True)


MSFT_06_train = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_06_train_flat_df.csv", index_col=0)
MSFT_06_train = MSFT_06_train.reset_index(drop=True)


MSFT_06_test = pd.read_csv("/Users/fahad/project_repo/data/final/MSFT/MSFT_06_test_flat_df.csv", index_col=0)
MSFT_06_test = MSFT_06_test.reset_index(drop=True)

# %% [markdown]
# # 1998_2011 data AAPL

# %%
AAPL_98_train = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/AAPL_98_train_flat_df.csv", index_col=0)
AAPL_98_train = AAPL_98_train.reset_index(drop=True)


AAPL_98_test = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/AAPL_98_test_flat_df.csv", index_col=0)
AAPL_98_test = AAPL_98_test.reset_index(drop=True)


AAPL_02_train = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/AAPL_02_train_flat_df.csv", index_col=0)
AAPL_02_train = AAPL_02_train.reset_index(drop=True)


AAPL_02_test = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/AAPL_02_test_flat_df.csv", index_col=0)
AAPL_02_test = AAPL_02_test.reset_index(drop=True)


AAPL_06_train = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/AAPL_06_train_flat_df.csv", index_col=0)
AAPL_06_train = AAPL_06_train.reset_index(drop=True)


AAPL_06_test = pd.read_csv("/Users/fahad/project_repo/data/final/AAPL/AAPL_06_test_flat_df.csv", index_col=0)
AAPL_06_test = AAPL_06_test.reset_index(drop=True)

# %% [markdown]
# # 1998_2011 data AMZN

# %%
AMZN_98_train = pd.read_csv("/Users/fahad/project_repo/data/final/AMZN/AMZN_98_train_flat_df.csv", index_col=0)
AMZN_98_train = AMZN_98_train.reset_index(drop=True)


AMZN_98_test = pd.read_csv("/Users/fahad/project_repo/data/final/AMZN/AMZN_98_test_flat_df.csv", index_col=0)
AMZN_98_test = AMZN_98_test.reset_index(drop=True)


AMZN_02_train = pd.read_csv("/Users/fahad/project_repo/data/final/AMZN/AMZN_02_train_flat_df.csv", index_col=0)
AMZN_02_train = AMZN_02_train.reset_index(drop=True)


AMZN_02_test = pd.read_csv("/Users/fahad/project_repo/data/final/AMZN/AMZN_02_test_flat_df.csv", index_col=0)
AMZN_02_test = AMZN_02_test.reset_index(drop=True)


AMZN_06_train = pd.read_csv("/Users/fahad/project_repo/data/final/AMZN/AMZN_06_train_flat_df.csv", index_col=0)
AMZN_06_train = AMZN_06_train.reset_index(drop=True)


AMZN_06_test = pd.read_csv("/Users/fahad/project_repo/data/final/AMZN/AMZN_06_test_flat_df.csv", index_col=0)
AMZN_06_test = AMZN_06_test.reset_index(drop=True)

# %% [markdown]
# # JOIN DATAFRAMES IN ORDER TO HAVE SUFFICIENT DATA TO TRAIN MODEL

# %%
X_train= pd.concat([MSFT_98_train,MSFT_98_test,MSFT_02_train,MSFT_02_test,MSFT_06_train,MSFT_06_test,
               AAPL_98_train,AAPL_98_test,AAPL_02_train,AAPL_02_test,AAPL_06_train,AAPL_06_test,
                AMZN_98_train,AMZN_98_test,AMZN_02_train,AMZN_02_test,AMZN_06_train,AMZN_06_test])

# %%
#assign the training labels to y_train
y_train = X_train.Label
y_train_df = pd.DataFrame(y_train)
#drop the labels from the X_train dataframe
X_train = X_train.drop("Label", axis=1)

export_X_train = X_train.to_csv("/Users/fahad/project_repo/data/final/X_train.csv")
export_y_train = y_train_df.to_csv("/Users/fahad/project_repo/data/final/y_train.csv")
# Out:
# /Users/fahad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   import sys

# %%
def make_timeseries_classifier(sample_num,window_size, filter_length, nb_input_series=1, nb_outputs=1, nb_filter=16):
    """:Return: a Keras Model for predicting the next value in a timeseries given a fixed-size lookback window of previous values.
    The model can handle multiple input timeseries (`nb_input_series`) and multiple prediction targets (`nb_outputs`).
    :param int window_size: The number of previous timeseries values to use as input features.  Also called lag or lookback.
    :param int nb_input_series: The number of input timeseries; 1 for a single timeseries.
      The `X` input to ``fit()`` should be an array of shape ``(n_instances, window_size, nb_input_series)``; each instance is
      a 2D array of shape ``(window_size, nb_input_series)``.  For example, for `window_size` = 3 and `nb_input_series` = 1 (a
      single timeseries), one instance could be ``[[0], [1], [2]]``. See ``make_timeseries_instances()``.
    :param int nb_outputs: The output dimension, often equal to the number of inputs.
      For each input instance (array with shape ``(window_size, nb_input_series)``), the output is a vector of size `nb_outputs`,
      usually the value(s) predicted to come after the last value in that input instance, i.e., the next value
      in the sequence. The `y` input to ``fit()`` should be an array of shape ``(n_instances, nb_outputs)``.
    :param int filter_length: the size (along the `window_size` dimension) of the sliding window that gets convolved with
      each position along each instance. The difference between 1D and 2D convolution is that a 1D filter's "height" is fixed
      to the number of input timeseries (its "width" being `filter_length`), and it can only slide along the window
      dimension.  This is useful as generally the input timeseries have no spatial/ordinal relationship, so it's not
      meaningful to look for patterns that are invariant with respect to subsets of the timeseries.
    :param int nb_filter: The number of different filters to learn (roughly, input patterns to recognize).
    """
    model = Sequential((
        # The first conv layer learns `nb_filter` filters (aka kernels), each of size ``(filter_length, nb_input_series)``.
        # Its output will have shape (None, window_size - filter_length + 1, nb_filter), i.e., for each position in
        # the input timeseries, the activation of each filter at that position.
        Convolution1D(nb_filter=nb_filter, filter_length=filter_length, activation='relu', input_shape=(window_size,nb_input_series)),
        MaxPooling1D(),     # Downsample the output of convolution by 2X.
        Convolution1D(nb_filter=nb_filter, filter_length=filter_length, activation='relu'),
        MaxPooling1D(),
        Flatten(),
        Dense(nb_outputs, activation='sigmoid'),     # For binary classification, change the activation to 'sigmoid'
    ))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # To perform (binary) classification instead:
    # model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])
    
    return model

# %%
model_1 = make_timeseries_classifier(X_train.shape[0],X_train.shape[1],3)
# Out:
# /Users/fahad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(activation="relu", input_shape=(360, 1), filters=16, kernel_size=3)`
# /Users/fahad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(activation="relu", filters=16, kernel_size=3)`

# %%
model_1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3 (Conv1D)            (None, 358, 16)           64
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 179, 16)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 177, 16)           784
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 88, 16)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1408)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1409
# =================================================================
# Total params: 2,257
# Trainable params: 2,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train.shape
y_train.shape
# Out:
# (609, 360, 1)
# (609,)

# %%
es = EarlyStopping(monitor='val_acc', mode='max', verbose=0, patience=150)
mc = ModelCheckpoint('1D_CNN_FE_98_11_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
cb_list = [es,mc]

# %%
history=model_1.fit(X_train, y_train,validation_split=0.10, epochs=1000,batch_size=1, verbose=1,
                    callbacks = cb_list)
# Out:
# W0815 11:59:22.196156 4469847488 deprecation_wrapper.py:119] From /Users/fahad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 548 samples, validate on 61 samples
# Epoch 1/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.6854 - acc: 0.5803 - val_loss: 0.6296 - val_acc: 0.6721
#
# Epoch 00001: val_acc improved from -inf to 0.67213, saving model to 1D_CNN_FE_98_11_model.h5
# Epoch 2/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.6189 - acc: 0.6752 - val_loss: 0.5793 - val_acc: 0.6885
#
# Epoch 00002: val_acc improved from 0.67213 to 0.68852, saving model to 1D_CNN_FE_98_11_model.h5
# Epoch 3/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5453 - acc: 0.7281 - val_loss: 0.5787 - val_acc: 0.6885
#
# Epoch 00003: val_acc did not improve from 0.68852
# Epoch 4/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.5099 - acc: 0.7518 - val_loss: 0.5704 - val_acc: 0.6557
#
# Epoch 00004: val_acc did not improve from 0.68852
# Epoch 5/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4887 - acc: 0.7591 - val_loss: 0.5637 - val_acc: 0.6721
#
# Epoch 00005: val_acc did not improve from 0.68852
# Epoch 6/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.4553 - acc: 0.7682 - val_loss: 0.6249 - val_acc: 0.7049
#
# Epoch 00006: val_acc improved from 0.68852 to 0.70492, saving model to 1D_CNN_FE_98_11_model.h5
# Epoch 7/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4444 - acc: 0.7810 - val_loss: 0.5669 - val_acc: 0.6721
#
# Epoch 00007: val_acc did not improve from 0.70492
# Epoch 8/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4222 - acc: 0.8029 - val_loss: 0.6262 - val_acc: 0.7049
#
# Epoch 00008: val_acc did not improve from 0.70492
# Epoch 9/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4197 - acc: 0.7974 - val_loss: 0.5964 - val_acc: 0.7049
#
# Epoch 00009: val_acc did not improve from 0.70492
# Epoch 10/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.4039 - acc: 0.8011 - val_loss: 0.6139 - val_acc: 0.7049
#
# Epoch 00010: val_acc did not improve from 0.70492
# Epoch 11/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3885 - acc: 0.8212 - val_loss: 0.5885 - val_acc: 0.7213
#
# Epoch 00011: val_acc improved from 0.70492 to 0.72131, saving model to 1D_CNN_FE_98_11_model.h5
# Epoch 12/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3776 - acc: 0.8157 - val_loss: 0.6717 - val_acc: 0.6393
#
# Epoch 00012: val_acc did not improve from 0.72131
# Epoch 13/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3962 - acc: 0.8139 - val_loss: 0.5637 - val_acc: 0.7213
#
# Epoch 00013: val_acc did not improve from 0.72131
# Epoch 14/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3686 - acc: 0.8285 - val_loss: 0.5893 - val_acc: 0.7705
#
# Epoch 00014: val_acc improved from 0.72131 to 0.77049, saving model to 1D_CNN_FE_98_11_model.h5
# Epoch 15/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3515 - acc: 0.8358 - val_loss: 0.7890 - val_acc: 0.6230
#
# Epoch 00015: val_acc did not improve from 0.77049
# Epoch 16/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3525 - acc: 0.8339 - val_loss: 0.6495 - val_acc: 0.6557
#
# Epoch 00016: val_acc did not improve from 0.77049
# Epoch 17/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3568 - acc: 0.8248 - val_loss: 0.5968 - val_acc: 0.7213
#
# Epoch 00017: val_acc did not improve from 0.77049
# Epoch 18/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3504 - acc: 0.8394 - val_loss: 0.6481 - val_acc: 0.6885
#
# Epoch 00018: val_acc did not improve from 0.77049
# Epoch 19/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3467 - acc: 0.8321 - val_loss: 0.6167 - val_acc: 0.7541
#
# Epoch 00019: val_acc did not improve from 0.77049
# Epoch 20/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3373 - acc: 0.8485 - val_loss: 0.6448 - val_acc: 0.7049
#
# Epoch 00020: val_acc did not improve from 0.77049
# Epoch 21/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3234 - acc: 0.8449 - val_loss: 0.6065 - val_acc: 0.7541
#
# Epoch 00021: val_acc did not improve from 0.77049
# Epoch 22/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3246 - acc: 0.8558 - val_loss: 0.6876 - val_acc: 0.6721
#
# Epoch 00022: val_acc did not improve from 0.77049
# Epoch 23/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.3259 - acc: 0.8577 - val_loss: 0.6351 - val_acc: 0.7377
#
# Epoch 00023: val_acc did not improve from 0.77049
# Epoch 24/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3247 - acc: 0.8540 - val_loss: 0.5993 - val_acc: 0.7705
#
# Epoch 00024: val_acc did not improve from 0.77049
# Epoch 25/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3151 - acc: 0.8613 - val_loss: 0.6327 - val_acc: 0.7705
#
# Epoch 00025: val_acc did not improve from 0.77049
# Epoch 26/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3134 - acc: 0.8686 - val_loss: 0.6998 - val_acc: 0.6721
#
# Epoch 00026: val_acc did not improve from 0.77049
# Epoch 27/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3121 - acc: 0.8650 - val_loss: 0.6457 - val_acc: 0.7377
#
# Epoch 00027: val_acc did not improve from 0.77049
# Epoch 28/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2929 - acc: 0.8577 - val_loss: 0.6780 - val_acc: 0.6885
#
# Epoch 00028: val_acc did not improve from 0.77049
# Epoch 29/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2978 - acc: 0.8741 - val_loss: 0.6472 - val_acc: 0.7049
#
# Epoch 00029: val_acc did not improve from 0.77049
# Epoch 30/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.3035 - acc: 0.8650 - val_loss: 0.6638 - val_acc: 0.7705
#
# Epoch 00030: val_acc did not improve from 0.77049
# Epoch 31/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2999 - acc: 0.8668 - val_loss: 0.6351 - val_acc: 0.7705
#
# Epoch 00031: val_acc did not improve from 0.77049
# Epoch 32/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2841 - acc: 0.8905 - val_loss: 0.6157 - val_acc: 0.7869
#
# Epoch 00032: val_acc improved from 0.77049 to 0.78689, saving model to 1D_CNN_FE_98_11_model.h5
# Epoch 33/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2871 - acc: 0.8887 - val_loss: 0.6602 - val_acc: 0.8033
#
# Epoch 00033: val_acc improved from 0.78689 to 0.80328, saving model to 1D_CNN_FE_98_11_model.h5
# Epoch 34/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2815 - acc: 0.8631 - val_loss: 0.6732 - val_acc: 0.7869
#
# Epoch 00034: val_acc did not improve from 0.80328
# Epoch 35/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2903 - acc: 0.8796 - val_loss: 0.6476 - val_acc: 0.7869
#
# Epoch 00035: val_acc did not improve from 0.80328
# Epoch 36/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2762 - acc: 0.8887 - val_loss: 0.6512 - val_acc: 0.7541
#
# Epoch 00036: val_acc did not improve from 0.80328
# Epoch 37/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2684 - acc: 0.8814 - val_loss: 0.6711 - val_acc: 0.7213
#
# Epoch 00037: val_acc did not improve from 0.80328
# Epoch 38/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2659 - acc: 0.9015 - val_loss: 0.7346 - val_acc: 0.7705
#
# Epoch 00038: val_acc did not improve from 0.80328
# Epoch 39/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2733 - acc: 0.8741 - val_loss: 0.7641 - val_acc: 0.7377
#
# Epoch 00039: val_acc did not improve from 0.80328
# Epoch 40/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2712 - acc: 0.8923 - val_loss: 0.7128 - val_acc: 0.8033
#
# Epoch 00040: val_acc did not improve from 0.80328
# Epoch 41/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2592 - acc: 0.8942 - val_loss: 0.7147 - val_acc: 0.7049
#
# Epoch 00041: val_acc did not improve from 0.80328
# Epoch 42/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2606 - acc: 0.8942 - val_loss: 0.7949 - val_acc: 0.7541
#
# Epoch 00042: val_acc did not improve from 0.80328
# Epoch 43/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2467 - acc: 0.8978 - val_loss: 0.7538 - val_acc: 0.6885
#
# Epoch 00043: val_acc did not improve from 0.80328
# Epoch 44/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2618 - acc: 0.8905 - val_loss: 0.7156 - val_acc: 0.7213
#
# Epoch 00044: val_acc did not improve from 0.80328
# Epoch 45/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2455 - acc: 0.9015 - val_loss: 0.8864 - val_acc: 0.6230
#
# Epoch 00045: val_acc did not improve from 0.80328
# Epoch 46/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2576 - acc: 0.8887 - val_loss: 0.6515 - val_acc: 0.8033
#
# Epoch 00046: val_acc did not improve from 0.80328
# Epoch 47/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2361 - acc: 0.9197 - val_loss: 0.8362 - val_acc: 0.7377
#
# Epoch 00047: val_acc did not improve from 0.80328
# Epoch 48/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2351 - acc: 0.9142 - val_loss: 0.8996 - val_acc: 0.7377
#
# Epoch 00048: val_acc did not improve from 0.80328
# Epoch 49/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2329 - acc: 0.8942 - val_loss: 0.7766 - val_acc: 0.7049
#
# Epoch 00049: val_acc did not improve from 0.80328
# Epoch 50/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2335 - acc: 0.9088 - val_loss: 0.7235 - val_acc: 0.7541
#
# Epoch 00050: val_acc did not improve from 0.80328
# Epoch 51/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2272 - acc: 0.9051 - val_loss: 0.7954 - val_acc: 0.7377
#
# Epoch 00051: val_acc did not improve from 0.80328
# Epoch 52/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2276 - acc: 0.9106 - val_loss: 0.7919 - val_acc: 0.7213
#
# Epoch 00052: val_acc did not improve from 0.80328
# Epoch 53/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.2397 - acc: 0.8996 - val_loss: 0.8564 - val_acc: 0.6721
#
# Epoch 00053: val_acc did not improve from 0.80328
# Epoch 54/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2325 - acc: 0.8978 - val_loss: 0.7267 - val_acc: 0.7377
#
# Epoch 00054: val_acc did not improve from 0.80328
# Epoch 55/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.2195 - acc: 0.9124 - val_loss: 0.7263 - val_acc: 0.7869
#
# Epoch 00055: val_acc did not improve from 0.80328
# Epoch 56/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2010 - acc: 0.9361 - val_loss: 0.9024 - val_acc: 0.6557
#
# Epoch 00056: val_acc did not improve from 0.80328
# Epoch 57/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2167 - acc: 0.9088 - val_loss: 0.7949 - val_acc: 0.7705
#
# Epoch 00057: val_acc did not improve from 0.80328
# Epoch 58/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2111 - acc: 0.9179 - val_loss: 0.7652 - val_acc: 0.7869
#
# Epoch 00058: val_acc did not improve from 0.80328
# Epoch 59/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2063 - acc: 0.9106 - val_loss: 0.8294 - val_acc: 0.6721
#
# Epoch 00059: val_acc did not improve from 0.80328
# Epoch 60/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2082 - acc: 0.9215 - val_loss: 0.8073 - val_acc: 0.7705
#
# Epoch 00060: val_acc did not improve from 0.80328
# Epoch 61/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1997 - acc: 0.9197 - val_loss: 0.8880 - val_acc: 0.6885
#
# Epoch 00061: val_acc did not improve from 0.80328
# Epoch 62/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1953 - acc: 0.9161 - val_loss: 0.8343 - val_acc: 0.7705
#
# Epoch 00062: val_acc did not improve from 0.80328
# Epoch 63/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1949 - acc: 0.9234 - val_loss: 0.8258 - val_acc: 0.7377
#
# Epoch 00063: val_acc did not improve from 0.80328
# Epoch 64/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.2005 - acc: 0.9307 - val_loss: 0.8851 - val_acc: 0.7049
#
# Epoch 00064: val_acc did not improve from 0.80328
# Epoch 65/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1809 - acc: 0.9361 - val_loss: 0.8260 - val_acc: 0.7541
#
# Epoch 00065: val_acc did not improve from 0.80328
# Epoch 66/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1960 - acc: 0.9343 - val_loss: 0.8762 - val_acc: 0.7213
#
# Epoch 00066: val_acc did not improve from 0.80328
# Epoch 67/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1903 - acc: 0.9179 - val_loss: 0.9078 - val_acc: 0.7377
#
# Epoch 00067: val_acc did not improve from 0.80328
# Epoch 68/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1826 - acc: 0.9270 - val_loss: 0.9336 - val_acc: 0.7377
#
# Epoch 00068: val_acc did not improve from 0.80328
# Epoch 69/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1784 - acc: 0.9325 - val_loss: 0.8023 - val_acc: 0.7377
#
# Epoch 00069: val_acc did not improve from 0.80328
# Epoch 70/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1820 - acc: 0.9380 - val_loss: 0.8612 - val_acc: 0.7541
#
# Epoch 00070: val_acc did not improve from 0.80328
# Epoch 71/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1926 - acc: 0.9361 - val_loss: 0.8916 - val_acc: 0.7541
#
# Epoch 00071: val_acc did not improve from 0.80328
# Epoch 72/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1710 - acc: 0.9398 - val_loss: 0.8741 - val_acc: 0.7541
#
# Epoch 00072: val_acc did not improve from 0.80328
# Epoch 73/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1757 - acc: 0.9252 - val_loss: 0.9271 - val_acc: 0.7377
#
# Epoch 00073: val_acc did not improve from 0.80328
# Epoch 74/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1716 - acc: 0.9361 - val_loss: 0.9531 - val_acc: 0.6885
#
# Epoch 00074: val_acc did not improve from 0.80328
# Epoch 75/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1573 - acc: 0.9453 - val_loss: 0.8951 - val_acc: 0.7541
#
# Epoch 00075: val_acc did not improve from 0.80328
# Epoch 76/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1674 - acc: 0.9453 - val_loss: 0.8866 - val_acc: 0.6885
#
# Epoch 00076: val_acc did not improve from 0.80328
# Epoch 77/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1547 - acc: 0.9380 - val_loss: 1.0044 - val_acc: 0.6721
#
# Epoch 00077: val_acc did not improve from 0.80328
# Epoch 78/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1488 - acc: 0.9526 - val_loss: 0.9061 - val_acc: 0.7213
#
# Epoch 00078: val_acc did not improve from 0.80328
# Epoch 79/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1585 - acc: 0.9453 - val_loss: 0.9670 - val_acc: 0.7213
#
# Epoch 00079: val_acc did not improve from 0.80328
# Epoch 80/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1494 - acc: 0.9544 - val_loss: 0.9030 - val_acc: 0.7541
#
# Epoch 00080: val_acc did not improve from 0.80328
# Epoch 81/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1514 - acc: 0.9361 - val_loss: 1.0236 - val_acc: 0.7541
#
# Epoch 00081: val_acc did not improve from 0.80328
# Epoch 82/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1477 - acc: 0.9471 - val_loss: 1.0690 - val_acc: 0.7213
#
# Epoch 00082: val_acc did not improve from 0.80328
# Epoch 83/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1451 - acc: 0.9489 - val_loss: 0.9400 - val_acc: 0.7705
#
# Epoch 00083: val_acc did not improve from 0.80328
# Epoch 84/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1352 - acc: 0.9599 - val_loss: 0.9311 - val_acc: 0.7541
#
# Epoch 00084: val_acc did not improve from 0.80328
# Epoch 85/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1371 - acc: 0.9580 - val_loss: 0.8910 - val_acc: 0.7049
#
# Epoch 00085: val_acc did not improve from 0.80328
# Epoch 86/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1514 - acc: 0.9526 - val_loss: 0.9258 - val_acc: 0.7541
#
# Epoch 00086: val_acc did not improve from 0.80328
# Epoch 87/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1441 - acc: 0.9489 - val_loss: 0.9488 - val_acc: 0.7049
#
# Epoch 00087: val_acc did not improve from 0.80328
# Epoch 88/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1304 - acc: 0.9544 - val_loss: 0.9803 - val_acc: 0.7541
#
# Epoch 00088: val_acc did not improve from 0.80328
# Epoch 89/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1280 - acc: 0.9434 - val_loss: 0.9520 - val_acc: 0.7869
#
# Epoch 00089: val_acc did not improve from 0.80328
# Epoch 90/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1306 - acc: 0.9544 - val_loss: 1.2006 - val_acc: 0.7377
#
# Epoch 00090: val_acc did not improve from 0.80328
# Epoch 91/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1267 - acc: 0.9562 - val_loss: 1.0526 - val_acc: 0.7213
#
# Epoch 00091: val_acc did not improve from 0.80328
# Epoch 92/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1319 - acc: 0.9507 - val_loss: 0.9245 - val_acc: 0.8033
#
# Epoch 00092: val_acc did not improve from 0.80328
# Epoch 93/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1146 - acc: 0.9617 - val_loss: 1.0708 - val_acc: 0.7377
#
# Epoch 00093: val_acc did not improve from 0.80328
# Epoch 94/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1303 - acc: 0.9544 - val_loss: 1.2535 - val_acc: 0.6885
#
# Epoch 00094: val_acc did not improve from 0.80328
# Epoch 95/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1155 - acc: 0.9653 - val_loss: 1.0146 - val_acc: 0.7213
#
# Epoch 00095: val_acc did not improve from 0.80328
# Epoch 96/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1122 - acc: 0.9599 - val_loss: 1.0501 - val_acc: 0.7541
#
# Epoch 00096: val_acc did not improve from 0.80328
# Epoch 97/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1119 - acc: 0.9599 - val_loss: 1.0216 - val_acc: 0.7049
#
# Epoch 00097: val_acc did not improve from 0.80328
# Epoch 98/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1074 - acc: 0.9653 - val_loss: 1.0942 - val_acc: 0.7213
#
# Epoch 00098: val_acc did not improve from 0.80328
# Epoch 99/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1285 - acc: 0.9507 - val_loss: 1.1780 - val_acc: 0.7377
#
# Epoch 00099: val_acc did not improve from 0.80328
# Epoch 100/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1185 - acc: 0.9599 - val_loss: 1.1531 - val_acc: 0.7213
#
# Epoch 00100: val_acc did not improve from 0.80328
# Epoch 101/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1021 - acc: 0.9672 - val_loss: 1.1012 - val_acc: 0.7541
#
# Epoch 00101: val_acc did not improve from 0.80328
# Epoch 102/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0865 - acc: 0.9745 - val_loss: 1.0544 - val_acc: 0.6885
#
# Epoch 00102: val_acc did not improve from 0.80328
# Epoch 103/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1070 - acc: 0.9690 - val_loss: 1.0953 - val_acc: 0.7213
#
# Epoch 00103: val_acc did not improve from 0.80328
# Epoch 104/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0997 - acc: 0.9672 - val_loss: 1.1640 - val_acc: 0.7213
#
# Epoch 00104: val_acc did not improve from 0.80328
# Epoch 105/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0974 - acc: 0.9672 - val_loss: 1.0991 - val_acc: 0.7705
#
# Epoch 00105: val_acc did not improve from 0.80328
# Epoch 106/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.1029 - acc: 0.9672 - val_loss: 1.1662 - val_acc: 0.7377
#
# Epoch 00106: val_acc did not improve from 0.80328
# Epoch 107/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0944 - acc: 0.9745 - val_loss: 1.1754 - val_acc: 0.7541
#
# Epoch 00107: val_acc did not improve from 0.80328
# Epoch 108/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0877 - acc: 0.9726 - val_loss: 1.2206 - val_acc: 0.7541
#
# Epoch 00108: val_acc did not improve from 0.80328
# Epoch 109/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0917 - acc: 0.9653 - val_loss: 1.1737 - val_acc: 0.7541
#
# Epoch 00109: val_acc did not improve from 0.80328
# Epoch 110/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0870 - acc: 0.9726 - val_loss: 1.3417 - val_acc: 0.7213
#
# Epoch 00110: val_acc did not improve from 0.80328
# Epoch 111/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0811 - acc: 0.9781 - val_loss: 1.2280 - val_acc: 0.7541
#
# Epoch 00111: val_acc did not improve from 0.80328
# Epoch 112/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0920 - acc: 0.9653 - val_loss: 1.2171 - val_acc: 0.7049
#
# Epoch 00112: val_acc did not improve from 0.80328
# Epoch 113/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0887 - acc: 0.9745 - val_loss: 1.2287 - val_acc: 0.7541
#
# Epoch 00113: val_acc did not improve from 0.80328
# Epoch 114/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0769 - acc: 0.9763 - val_loss: 1.2602 - val_acc: 0.7377
#
# Epoch 00114: val_acc did not improve from 0.80328
# Epoch 115/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0687 - acc: 0.9799 - val_loss: 1.3244 - val_acc: 0.7541
#
# Epoch 00115: val_acc did not improve from 0.80328
# Epoch 116/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0791 - acc: 0.9763 - val_loss: 1.3000 - val_acc: 0.7049
#
# Epoch 00116: val_acc did not improve from 0.80328
# Epoch 117/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0882 - acc: 0.9653 - val_loss: 1.3190 - val_acc: 0.7213
#
# Epoch 00117: val_acc did not improve from 0.80328
# Epoch 118/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0720 - acc: 0.9708 - val_loss: 1.2552 - val_acc: 0.7049
#
# Epoch 00118: val_acc did not improve from 0.80328
# Epoch 119/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0609 - acc: 0.9836 - val_loss: 1.4183 - val_acc: 0.6557
#
# Epoch 00119: val_acc did not improve from 0.80328
# Epoch 120/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0803 - acc: 0.9726 - val_loss: 1.2356 - val_acc: 0.7377
#
# Epoch 00120: val_acc did not improve from 0.80328
# Epoch 121/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0677 - acc: 0.9818 - val_loss: 1.4707 - val_acc: 0.7377
#
# Epoch 00121: val_acc did not improve from 0.80328
# Epoch 122/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0701 - acc: 0.9726 - val_loss: 1.4591 - val_acc: 0.6393
#
# Epoch 00122: val_acc did not improve from 0.80328
# Epoch 123/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0653 - acc: 0.9818 - val_loss: 1.3852 - val_acc: 0.7049
#
# Epoch 00123: val_acc did not improve from 0.80328
# Epoch 124/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0605 - acc: 0.9854 - val_loss: 1.3796 - val_acc: 0.6721
#
# Epoch 00124: val_acc did not improve from 0.80328
# Epoch 125/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0643 - acc: 0.9763 - val_loss: 1.2850 - val_acc: 0.7213
#
# Epoch 00125: val_acc did not improve from 0.80328
# Epoch 126/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0617 - acc: 0.9799 - val_loss: 1.4350 - val_acc: 0.6885
#
# Epoch 00126: val_acc did not improve from 0.80328
# Epoch 127/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0734 - acc: 0.9726 - val_loss: 1.6097 - val_acc: 0.7541
#
# Epoch 00127: val_acc did not improve from 0.80328
# Epoch 128/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0576 - acc: 0.9836 - val_loss: 1.3432 - val_acc: 0.7049
#
# Epoch 00128: val_acc did not improve from 0.80328
# Epoch 129/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0645 - acc: 0.9726 - val_loss: 1.3067 - val_acc: 0.7213
#
# Epoch 00129: val_acc did not improve from 0.80328
# Epoch 130/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0589 - acc: 0.9799 - val_loss: 1.4929 - val_acc: 0.6885
#
# Epoch 00130: val_acc did not improve from 0.80328
# Epoch 131/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0501 - acc: 0.9891 - val_loss: 1.5095 - val_acc: 0.7049
#
# Epoch 00131: val_acc did not improve from 0.80328
# Epoch 132/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0435 - acc: 0.9872 - val_loss: 1.5326 - val_acc: 0.7541
#
# Epoch 00132: val_acc did not improve from 0.80328
# Epoch 133/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0530 - acc: 0.9836 - val_loss: 1.5858 - val_acc: 0.7213
#
# Epoch 00133: val_acc did not improve from 0.80328
# Epoch 134/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0501 - acc: 0.9836 - val_loss: 1.4247 - val_acc: 0.7213
#
# Epoch 00134: val_acc did not improve from 0.80328
# Epoch 135/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0573 - acc: 0.9781 - val_loss: 1.5313 - val_acc: 0.7377
#
# Epoch 00135: val_acc did not improve from 0.80328
# Epoch 136/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0436 - acc: 0.9891 - val_loss: 1.5049 - val_acc: 0.6721
#
# Epoch 00136: val_acc did not improve from 0.80328
# Epoch 137/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0550 - acc: 0.9799 - val_loss: 1.7138 - val_acc: 0.7377
#
# Epoch 00137: val_acc did not improve from 0.80328
# Epoch 138/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0613 - acc: 0.9781 - val_loss: 1.5621 - val_acc: 0.7541
#
# Epoch 00138: val_acc did not improve from 0.80328
# Epoch 139/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0405 - acc: 0.9891 - val_loss: 1.4346 - val_acc: 0.7213
#
# Epoch 00139: val_acc did not improve from 0.80328
# Epoch 140/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0384 - acc: 0.9891 - val_loss: 1.4595 - val_acc: 0.7213
#
# Epoch 00140: val_acc did not improve from 0.80328
# Epoch 141/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0420 - acc: 0.9872 - val_loss: 1.5020 - val_acc: 0.7213
#
# Epoch 00141: val_acc did not improve from 0.80328
# Epoch 142/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0445 - acc: 0.9872 - val_loss: 1.4994 - val_acc: 0.7049
#
# Epoch 00142: val_acc did not improve from 0.80328
# Epoch 143/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0272 - acc: 0.9945 - val_loss: 1.5734 - val_acc: 0.6885
#
# Epoch 00143: val_acc did not improve from 0.80328
# Epoch 144/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0316 - acc: 0.9927 - val_loss: 1.6606 - val_acc: 0.6557
#
# Epoch 00144: val_acc did not improve from 0.80328
# Epoch 145/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0490 - acc: 0.9854 - val_loss: 1.7249 - val_acc: 0.7541
#
# Epoch 00145: val_acc did not improve from 0.80328
# Epoch 146/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0470 - acc: 0.9799 - val_loss: 1.4814 - val_acc: 0.7213
#
# Epoch 00146: val_acc did not improve from 0.80328
# Epoch 147/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0475 - acc: 0.9854 - val_loss: 1.6167 - val_acc: 0.7213
#
# Epoch 00147: val_acc did not improve from 0.80328
# Epoch 148/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0393 - acc: 0.9872 - val_loss: 1.7766 - val_acc: 0.7213
#
# Epoch 00148: val_acc did not improve from 0.80328
# Epoch 149/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.0299 - acc: 0.9891 - val_loss: 1.5540 - val_acc: 0.7377
#
# Epoch 00149: val_acc did not improve from 0.80328
# Epoch 150/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.0378 - acc: 0.9872 - val_loss: 1.5188 - val_acc: 0.7705
#
# Epoch 00150: val_acc did not improve from 0.80328
# Epoch 151/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.0254 - acc: 0.9927 - val_loss: 1.5918 - val_acc: 0.7213
#
# Epoch 00151: val_acc did not improve from 0.80328
# Epoch 152/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0206 - acc: 0.9945 - val_loss: 1.6720 - val_acc: 0.7541
#
# Epoch 00152: val_acc did not improve from 0.80328
# Epoch 153/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.0445 - acc: 0.9781 - val_loss: 1.9216 - val_acc: 0.7049
#
# Epoch 00153: val_acc did not improve from 0.80328
# Epoch 154/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.0459 - acc: 0.9799 - val_loss: 1.6650 - val_acc: 0.6885
#
# Epoch 00154: val_acc did not improve from 0.80328
# Epoch 155/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0382 - acc: 0.9891 - val_loss: 1.7628 - val_acc: 0.7377
#
# Epoch 00155: val_acc did not improve from 0.80328
# Epoch 156/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0213 - acc: 1.0000 - val_loss: 1.7459 - val_acc: 0.6721
#
# Epoch 00156: val_acc did not improve from 0.80328
# Epoch 157/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0270 - acc: 0.9927 - val_loss: 1.5840 - val_acc: 0.7377
#
# Epoch 00157: val_acc did not improve from 0.80328
# Epoch 158/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.0194 - acc: 0.9945 - val_loss: 1.7905 - val_acc: 0.6721
#
# Epoch 00158: val_acc did not improve from 0.80328
# Epoch 159/1000
# 548/548 [==============================] - 1s 2ms/step - loss: 0.0423 - acc: 0.9836 - val_loss: 1.8225 - val_acc: 0.7377
#
# Epoch 00159: val_acc did not improve from 0.80328
# Epoch 160/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0270 - acc: 0.9891 - val_loss: 1.7304 - val_acc: 0.7377
#
# Epoch 00160: val_acc did not improve from 0.80328
# Epoch 161/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0361 - acc: 0.9854 - val_loss: 1.7229 - val_acc: 0.6885
#
# Epoch 00161: val_acc did not improve from 0.80328
# Epoch 162/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0264 - acc: 0.9945 - val_loss: 1.6992 - val_acc: 0.7049
#
# Epoch 00162: val_acc did not improve from 0.80328
# Epoch 163/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0142 - acc: 0.9982 - val_loss: 1.6534 - val_acc: 0.7049
#
# Epoch 00163: val_acc did not improve from 0.80328
# Epoch 164/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0123 - acc: 1.0000 - val_loss: 1.7600 - val_acc: 0.7049
#
# Epoch 00164: val_acc did not improve from 0.80328
# Epoch 165/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0118 - acc: 1.0000 - val_loss: 1.9202 - val_acc: 0.7213
#
# Epoch 00165: val_acc did not improve from 0.80328
# Epoch 166/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0175 - acc: 0.9964 - val_loss: 1.9018 - val_acc: 0.7541
#
# Epoch 00166: val_acc did not improve from 0.80328
# Epoch 167/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0729 - acc: 0.9799 - val_loss: 1.9430 - val_acc: 0.7049
#
# Epoch 00167: val_acc did not improve from 0.80328
# Epoch 168/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0189 - acc: 0.9945 - val_loss: 1.8407 - val_acc: 0.7213
#
# Epoch 00168: val_acc did not improve from 0.80328
# Epoch 169/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0169 - acc: 0.9964 - val_loss: 1.9337 - val_acc: 0.7213
#
# Epoch 00169: val_acc did not improve from 0.80328
# Epoch 170/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0373 - acc: 0.9872 - val_loss: 1.8142 - val_acc: 0.7049
#
# Epoch 00170: val_acc did not improve from 0.80328
# Epoch 171/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0249 - acc: 0.9927 - val_loss: 1.8266 - val_acc: 0.7049
#
# Epoch 00171: val_acc did not improve from 0.80328
# Epoch 172/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0089 - acc: 1.0000 - val_loss: 1.9914 - val_acc: 0.7049
#
# Epoch 00172: val_acc did not improve from 0.80328
# Epoch 173/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0080 - acc: 1.0000 - val_loss: 1.8232 - val_acc: 0.7049
#
# Epoch 00173: val_acc did not improve from 0.80328
# Epoch 174/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0091 - acc: 1.0000 - val_loss: 1.8258 - val_acc: 0.7541
#
# Epoch 00174: val_acc did not improve from 0.80328
# Epoch 175/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0349 - acc: 0.9891 - val_loss: 2.1581 - val_acc: 0.7213
#
# Epoch 00175: val_acc did not improve from 0.80328
# Epoch 176/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0148 - acc: 0.9982 - val_loss: 2.0170 - val_acc: 0.7049
#
# Epoch 00176: val_acc did not improve from 0.80328
# Epoch 177/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0082 - acc: 1.0000 - val_loss: 1.8891 - val_acc: 0.7049
#
# Epoch 00177: val_acc did not improve from 0.80328
# Epoch 178/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0067 - acc: 1.0000 - val_loss: 1.9018 - val_acc: 0.7049
#
# Epoch 00178: val_acc did not improve from 0.80328
# Epoch 179/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0073 - acc: 1.0000 - val_loss: 1.9119 - val_acc: 0.7049
#
# Epoch 00179: val_acc did not improve from 0.80328
# Epoch 180/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0546 - acc: 0.9854 - val_loss: 1.9108 - val_acc: 0.7377
#
# Epoch 00180: val_acc did not improve from 0.80328
# Epoch 181/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0203 - acc: 0.9945 - val_loss: 1.9249 - val_acc: 0.7213
#
# Epoch 00181: val_acc did not improve from 0.80328
# Epoch 182/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0228 - acc: 0.9909 - val_loss: 2.0352 - val_acc: 0.6885
#
# Epoch 00182: val_acc did not improve from 0.80328
# Epoch 183/1000
# 548/548 [==============================] - 1s 1ms/step - loss: 0.0060 - acc: 1.0000 - val_loss: 2.0153 - val_acc: 0.7213
#
# Epoch 00183: val_acc did not improve from 0.80328

# %%
#plot the accuracy of the training set  and the validation set of the model
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

plt.rc('font', **font)
axis_font = {'fontname':'Arial', 'size':'25'}

plt.figure(figsize=[20,20])
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.ylabel('Accuracy', **axis_font)
plt.xlabel('Epochs', **axis_font)

plt.show()
# Out:
# W0815 12:01:37.292064 4469847488 font_manager.py:1282] findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
#EXPORT THE X_train data as a dataframe so it can be used easily in the other classifiers
#export the y_train data labels for the same reason
export_X_train = X_train.to_csv("/Users/fahad/project_repo/data/final/X_train.csv")

# %%
# Out:
# array([[[0.4293392 ],
#         [0.42528526],
#         [0.43243411],
#         ...,
#         [0.45345471],
#         [0.        ],
#         [0.        ]],
#
#        [[0.44497374],
#         [0.44306871],
#         [0.44909249],
#         ...,
#         [0.64097692],
#         [0.        ],
#         [0.        ]],
#
#        [[0.45718823],
#         [0.46054868],
#         [0.46463202],
#         ...,
#         [0.26641454],
#         [0.        ],
#         [0.        ]],
#
#        ...,
#
#        [[0.09835154],
#         [0.10095383],
#         [0.09903481],
#         ...,
#         [0.08334002],
#         [0.        ],
#         [0.        ]],
#
#        [[0.11232162],
#         [0.11162199],
#         [0.10499679],
#         ...,
#         [0.10062629],
#         [0.        ],
#         [0.        ]],
#
#        [[0.0987206 ],
#         [0.10384465],
#         [0.09974645],
#         ...,
#         [0.10325003],
#         [0.        ],
#         [0.        ]]])
