# %%
from backtesting import Strategy
from backtesting.lib import crossover
from backtesting import Backtest
from backtesting.test import GOOG
import pandas as pd
from backtesting.test import SMA
import ta
import pandas as pd
# Out:
# /Users/fahad/anaconda3/lib/python3.7/site-packages/backtesting/_plotting.py:34: UserWarning: Jupyter Notebook detected. Setting Bokeh output to notebook. This may not work in Jupyter clients without JavaScript support (e.g. PyCharm, Spyder IDE). Reset with `bokeh.io.reset_output()`.
#   warnings.warn('Jupyter Notebook detected. '
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
#read in dataframes with monthly data 
MSFT = pd.read_csv(r"/Users/fahad/project_repo/data/external/MSFT_monthly.csv")
AAPL = pd.read_csv(r"/Users/fahad/project_repo/data/external/AAPL_monthly.csv")
AMZN = pd.read_csv(r"/Users/fahad/project_repo/data/external/AMZN_monthly.csv")

#GIVE COLUMN NAMES 
MSFT.columns = ['Date','Open','High','Low','Close','Volume']
AAPL.columns = ['Date','Open','High','Low','Close','Volume']
AMZN.columns = ['Date','Open','High','Low','Close','Volume']

#convert to datetime object
MSFT.Date = pd.to_datetime(MSFT.Date, format="%Y/%m/%d")
AAPL.Date = pd.to_datetime(AAPL.Date, format="%Y/%m/%d")
AMZN.Date = pd.to_datetime(AMZN.Date, format="%Y/%m/%d")

#set date column as the index
MSFT = MSFT.set_index(['Date'])
AAPL = AAPL.set_index(['Date'])
AMZN = AMZN.set_index(['Date'])


#convert all the values from strings to ints
MSFT.Open = MSFT.Open.astype('int32')
MSFT.High = MSFT.High.astype('int32')
MSFT.Low = MSFT.Low.astype('int32')
MSFT.Close = MSFT.Close.astype('int32')

#Dataframe should be in ascending order
MSFT = MSFT.sort_index()

# %%
class SmaCross(Strategy):
    
    # Define the two MA lags as *class variables*
    # for later optimization
    n1 = 10
    n2 = 20
    
    def init(self):
        # Precompute two moving averages
        self.sma1 = self.I(SMA, self.data.Close, self.n1)
        self.sma2 = self.I(SMA, self.data.Close, self.n2)
        
#         print (self.sma1)
#         print (self.sma2)
    
    def next(self):
        # If sma1 crosses above sma2, buy the asset
        if crossover(self.sma1, self.sma2):
            print ("\n")
            print (list((self.data.index))[-1])
            self.buy()

        # Else, if sma1 crosses below sma2, sell it
        elif crossover(self.sma2, self.sma1):
            self.sell()

# %%
bt = Backtest(MSFT, SmaCross, cash=10000, commission=.002)
bt.run()
# Out:
# 2002-01-31 00:00:00
#
#
# 2004-09-30 00:00:00
#
#
# 2006-03-31 00:00:00
#
#
# 2009-12-31 00:00:00
# Start                     1998-02-27 00:00:00
# End                       2019-07-26 00:00:00
# Duration                   7819 days 00:00:00
# Exposure [%]                          47.4869
# Equity Final [$]                      63341.1
# Equity Peak [$]                       63341.1
# Return [%]                            533.411
# Buy & Hold Return [%]                 67.8571
# Max. Drawdown [%]                    -51.6756
# Avg. Drawdown [%]                    -16.1966
# Max. Drawdown Duration     2253 days 00:00:00
# Avg. Drawdown Duration      420 days 00:00:00
# # Trades                                    8
# Win Rate [%]                               50
# Best Trade [%]                        46.1037
# Worst Trade [%]                      -20.9103
# Avg. Trade [%]                        5.45178
# Max. Trade Duration         882 days 00:00:00
# Avg. Trade Duration         465 days 00:00:00
# Expectancy [%]                         17.358
# SQN                                  0.475584
# Sharpe Ratio                         0.240413
# Sortino Ratio                        0.883279
# Calmar Ratio                           0.1055
# _strategy                            SmaCross
# dtype: object

# %%
bt.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-5ae8d19b00ab> in <module>
# ----> 1 bt.plot()
#
# ~/anaconda3/lib/python3.7/site-packages/backtesting/backtesting.py in plot(self, results, filename, plot_width, plot_equity, plot_pl, plot_volume, plot_drawdown, smooth_equity, relative_equity, omit_missing, superimpose, show_legend, open_browser)
#    1000             superimpose=superimpose,
#    1001             show_legend=show_legend,
# -> 1002             open_browser=open_browser)
#
# ~/anaconda3/lib/python3.7/site-packages/backtesting/_plotting.py in plot(results, df, indicators, filename, plot_width, plot_equity, plot_pl, plot_volume, plot_drawdown, smooth_equity, relative_equity, omit_missing, superimpose, show_legend, open_browser)
#     486
#     487     if superimpose and is_datetime_index:
# --> 488         _plot_superimposed_ohlc()
#     489
#     490     ohlc_bars = _plot_ohlc()
#
# ~/anaconda3/lib/python3.7/site-packages/backtesting/_plotting.py in _plot_superimposed_ohlc()
#     345         resample_freq = _data_period(df2)
#     346         if resample_freq < orig_freq:
# --> 347             raise ValueError('Invalid value for `superimpose`: Upsampling not supported.')
#     348         if resample_freq == orig_freq:
#     349             warnings.warn('Superimposed OHLC plot matches the original plot. Skipping.',
#
# ValueError: Invalid value for `superimpose`: Upsampling not supported.
